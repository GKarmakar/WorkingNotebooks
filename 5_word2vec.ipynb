# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'term', 'originated', 'anarchism', 'originated', 'as', 'of', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.940888
# Nearest to but: hoof, lichfield, canonization, viewers, reich, descriptive, ely, fuji,
# Nearest to history: sil, fes, geller, troglodytes, foy, pets, sec, discordianism,
# Nearest to see: cubism, squeak, conglomeration, phospholipids, blunt, erstwhile, resentful, officeholders,
# Nearest to of: techniques, spurious, knoll, peel, counsel, exonerated, loos, ao,
# Nearest to his: gwynedd, stepmania, factorial, hyderabad, agrippina, attitude, sociologist, ecologically,
# Nearest to eight: predisposition, durability, presupposition, recreationally, maya, kashima, mei, relatedness,
# Nearest to not: adaption, paso, kava, gatekeeper, cancers, hooking, nicola, inexperience,
# Nearest to other: natalie, antagonism, next, abba, disproved, deformity, boccaccio, suppressor,
# Nearest to an: viacom, forge, lederman, carcinogen, texcoco, distinctly, copland, wounds,
# Nearest to will: gigantic, puzzled, oilers, undeserved, machinist, hasn, overwritten, inviscid,
# Nearest to american: tiu, steer, surprised, dmoz, unethical, yemeni, provincia, gauge,
# Nearest to six: jubal, intermittent, wyche, allergic, bonzos, heapsort, cosmetics, replenish,
# Nearest to as: demonstrable, dost, meritocratic, stalactites, opportunities, harold, nancy, mechanistic,
# Nearest to they: varieties, plosive, adobe, reaffirming, walked, downloads, khmer, manufacturers,
# Nearest to at: bir, freshmen, thanksgiving, burnley, stylings, roaring, ideally, marion,
# Nearest to more: transuranic, disparities, ortelius, limehouse, morpheme, floors, paste, broader,
# Average loss at step 2000: 4.358217
# Average loss at step 4000: 3.868760
# Average loss at step 6000: 3.784333
# Average loss at step 8000: 3.683023
# Average loss at step 10000: 3.612032
# Nearest to but: lichfield, enrichment, and, satirizes, though, reich, are, marine,
# Nearest to history: secaucus, pets, troglodytes, palestine, polski, littlefield, confessions, litani,
# Nearest to see: cubism, refer, copyrighted, lycaon, divergences, painted, mania, dynamics,
# Nearest to of: in, mnism, appellation, loos, thoughts, balkans, linguistique, spurious,
# Nearest to his: their, her, the, s, stepmania, our, this, its,
# Nearest to eight: nine, five, six, seven, four, three, zero, two,
# Nearest to not: it, abydos, still, to, also, they, cancers, applicable,
# Nearest to other: natalie, alejandro, insulting, next, antagonism, tightened, nicaea, appropriateness,
# Nearest to an: the, musicologist, triggers, playing, reunions, viacom, liberian, abrahamic,
# Nearest to will: gigantic, should, would, mountaineering, may, nuova, puzzled, exploitation,
# Nearest to american: unethical, cheerleaders, steer, mack, interfered, iic, delicate, flaminius,
# Nearest to six: eight, four, five, seven, nine, three, zero, two,
# Nearest to as: demonstrable, humanly, chengdu, rural, transmitters, by, driver, dame,
# Nearest to they: he, we, who, it, not, manufacturers, inclusion, moldova,
# Nearest to at: in, by, on, from, instruments, rosenberg, att, windsurfing,
# Nearest to more: disparities, transuranic, radiotelephone, encodings, overrides, rimini, varese, ortelius,
# Average loss at step 12000: 3.602449
# Average loss at step 14000: 3.568531
# Average loss at step 16000: 3.405914
# Average loss at step 18000: 3.457842
# Average loss at step 20000: 3.543162
# Nearest to but: though, however, which, and, functionals, that, cyclical, is,
# Nearest to history: secaucus, pets, polski, stock, form, slots, littlefield, confessions,
# Nearest to see: refer, dynamics, cubism, gradients, allege, copyrighted, ellsworth, lycaon,
# Nearest to of: appellation, for, unesco, reuel, tactic, tenji, nne, merseburg,
# Nearest to his: their, her, its, our, the, digamma, stepmania, smyrna,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to not: still, to, it, they, kava, also, abydos, usually,
# Nearest to other: many, some, renounce, are, hennig, powers, various, nicaea,
# Nearest to an: the, viacom, customer, catalan, leftists, raccoons, albertine, purr,
# Nearest to will: would, should, may, could, can, to, gigantic, mountaineering,
# Nearest to american: french, british, unethical, russian, iic, english, bromide, interfered,
# Nearest to six: seven, eight, nine, four, five, three, zero, two,
# Nearest to as: demonstrable, humanly, nss, basque, by, mostly, fk, stalactites,
# Nearest to they: we, he, there, she, who, it, not, these,
# Nearest to at: in, on, from, ideally, fief, is, and, collectors,
# Nearest to more: less, rather, bardot, disparities, paste, transuranic, very, overrides,
# Average loss at step 22000: 3.502801
# Average loss at step 24000: 3.487810
# Average loss at step 26000: 3.482006
# Average loss at step 28000: 3.480744
# Average loss at step 30000: 3.499373
# Nearest to but: however, though, and, while, that, when, reich, which,
# Nearest to history: secaucus, ramsay, source, reign, stock, overgrown, slots, poetic,
# Nearest to see: refer, dynamics, cubism, gradients, enumerative, ellsworth, samadhi, fox,
# Nearest to of: in, entitles, for, and, uc, mnism, reuel, from,
# Nearest to his: her, their, its, the, our, s, my, cosmo,
# Nearest to eight: nine, six, four, seven, five, three, zero, two,
# Nearest to not: still, they, it, never, resupply, now, kava, generally,
# Nearest to other: these, various, renounce, such, recognizing, pseudopods, are, many,
# Nearest to an: viacom, interprets, celera, ashford, customer, reunions, kusanagi, mina,
# Nearest to will: would, can, should, may, could, cannot, to, must,
# Nearest to american: english, british, french, russian, bromide, interfered, unethical, flaminius,
# Nearest to six: four, eight, nine, seven, five, three, two, zero,
# Nearest to as: demonstrable, sailboat, trafford, crippled, endorse, wow, vicu, ibid,
# Nearest to they: there, we, he, it, she, who, these, not,
# Nearest to at: in, during, fief, rebus, since, reprised, theotokos, stylings,
# Nearest to more: less, very, most, rather, overrides, paste, transuranic, encodings,
# Average loss at step 32000: 3.501269
# Average loss at step 34000: 3.492221
# Average loss at step 36000: 3.455695
# Average loss at step 38000: 3.297676
# Average loss at step 40000: 3.423936
# Nearest to but: however, though, while, and, which, it, although, where,
# Nearest to history: ramsay, adam, overgrown, bornholm, alberto, list, form, pets,
# Nearest to see: refer, dynamics, list, enumerative, ulm, mala, gradients, fearing,
# Nearest to of: erg, in, linguistique, pants, waals, appellation, including, tenji,
# Nearest to his: their, her, its, our, my, the, s, your,
# Nearest to eight: nine, seven, six, four, five, one, three, two,
# Nearest to not: still, it, never, they, therefore, also, abydos, generally,
# Nearest to other: various, including, pseudopods, baraka, different, cavett, renounce, many,
# Nearest to an: viacom, reunions, interprets, playable, cores, informatique, postpartum, tib,
# Nearest to will: would, can, may, could, should, must, cannot, might,
# Nearest to american: british, russian, english, french, dutch, bromide, fritz, flaminius,
# Nearest to six: seven, five, eight, four, nine, three, one, two,
# Nearest to as: sailboat, demonstrable, when, wow, is, transmitters, constance, crippled,
# Nearest to they: we, he, there, it, she, you, these, who,
# Nearest to at: on, during, therefrom, fief, rebus, across, in, fixtures,
# Nearest to more: less, most, very, rather, overrides, paste, lonsdaleite, igor,
# Average loss at step 42000: 3.434236
# Average loss at step 44000: 3.449073
# Average loss at step 46000: 3.446617
# Average loss at step 48000: 3.350558
# Average loss at step 50000: 3.381078
# Nearest to but: however, though, while, although, and, where, when, which,
# Nearest to history: list, aix, bornholm, pets, narnia, cotangent, overgrown, adam,
# Nearest to see: refer, list, dynamics, fearing, gradients, unchanged, od, references,
# Nearest to of: in, qq, chorded, including, masurian, coupland, and, unesco,
# Nearest to his: her, their, its, my, your, our, him, adalbert,
# Nearest to eight: six, nine, seven, four, five, three, one, zero,
# Nearest to not: still, generally, never, now, therefore, who, actually, almost,
# Nearest to other: various, different, pseudopods, baraka, many, shogun, renounce, perverse,
# Nearest to an: viacom, carmichael, assoc, postpartum, albertine, another, dominates, interprets,
# Nearest to will: would, can, could, may, should, must, cannot, might,
# Nearest to american: english, european, russian, french, fritz, flaminius, dutch, british,
# Nearest to six: eight, seven, four, five, nine, three, two, zero,
# Nearest to as: fortnight, oration, became, humanly, crawl, demonstrable, egoist, lesser,
# Nearest to they: we, there, he, she, it, these, you, mtu,
# Nearest to at: during, on, in, under, across, near, nordic, fief,
# Nearest to more: less, most, very, rather, overrides, lonsdaleite, encodings, arrogance,
# Average loss at step 52000: 3.437294
# Average loss at step 54000: 3.421354
# Average loss at step 56000: 3.438845
# Average loss at step 58000: 3.399371
# Average loss at step 60000: 3.388721
# Nearest to but: however, though, and, although, while, see, necessarily, than,
# Nearest to history: list, ramsay, holistic, politics, pets, secaucus, definite, bornholm,
# Nearest to see: refer, but, list, gradients, include, dynamics, can, external,
# Nearest to of: in, for, including, chorded, adolescents, masurian, like, ufa,
# Nearest to his: her, their, its, my, our, your, digamma, the,
# Nearest to eight: seven, nine, six, four, five, three, zero, one,
# Nearest to not: still, now, never, actually, therefore, generally, they, usually,
# Nearest to other: various, different, including, pseudopods, many, baraka, renounce, subdued,
# Nearest to an: viacom, relinquishing, brigid, customer, purr, interprets, albertine, ashford,
# Nearest to will: would, may, could, can, should, must, cannot, might,
# Nearest to american: european, english, russian, dutch, british, bromide, dispersed, fritz,
# Nearest to six: eight, four, five, nine, seven, three, zero, two,
# Nearest to as: became, animalia, centaurs, egoist, sailboat, zeppelin, better, crawl,
# Nearest to they: we, there, he, she, you, these, it, stump,
# Nearest to at: signifying, during, in, fixtures, wrapper, fief, under, gareth,
# Nearest to more: less, rather, very, most, lonsdaleite, overrides, too, quite,
# Average loss at step 62000: 3.236729
# Average loss at step 64000: 3.252737
# Average loss at step 66000: 3.401983
# Average loss at step 68000: 3.394391
# Average loss at step 70000: 3.363132
# Nearest to but: however, though, while, which, and, although, see, reportedly,
# Nearest to history: list, stock, ramsay, pause, holistic, overgrown, definite, transplants,
# Nearest to see: refer, include, list, but, references, gradients, um, giulia,
# Nearest to of: including, for, appellation, include, hadassah, reuel, in, although,
# Nearest to his: her, their, my, its, your, our, adalbert, stepmania,
# Nearest to eight: nine, six, seven, four, five, three, zero, one,
# Nearest to not: still, never, now, generally, only, therefore, virtually, abydos,
# Nearest to other: various, different, many, pseudopods, including, older, baraka, subdued,
# Nearest to an: viacom, brigid, carmichael, the, ashford, imprint, albertine, purr,
# Nearest to will: would, could, may, can, must, should, cannot, might,
# Nearest to american: english, european, british, dispersed, flaminius, maldives, fritz, canadian,
# Nearest to six: eight, seven, four, five, nine, three, two, zero,
# Nearest to as: tuning, avoid, itch, nss, kaj, nafta, vicu, when,
# Nearest to they: we, there, he, she, you, it, these, stump,
# Nearest to at: during, fief, on, fixtures, signifying, across, in, flatly,
# Nearest to more: less, most, very, rather, quite, too, increasingly, further,
# Average loss at step 72000: 3.371830
# Average loss at step 74000: 3.346487
# Average loss at step 76000: 3.324462
# Average loss at step 78000: 3.348193
# Average loss at step 80000: 3.380253
# Nearest to but: however, though, although, while, reportedly, suspect, than, chronicling,
# Nearest to history: list, holistic, overgrown, yoshida, ramsay, pause, journal, narnia,
# Nearest to see: refer, include, but, um, marcos, enumerative, conses, hermit,
# Nearest to of: in, including, excel, erg, qq, appellation, adolescents, puritanism,
# Nearest to his: her, their, its, my, your, our, the, digamma,
# Nearest to eight: six, nine, seven, four, five, three, zero, two,
# Nearest to not: still, never, therefore, it, abydos, now, always, usually,
# Nearest to other: various, pseudopods, baraka, different, subdued, including, many, perverse,
# Nearest to an: viacom, workstations, reunions, another, claudius, brigid, the, purr,
# Nearest to will: would, can, could, may, should, must, might, cannot,
# Nearest to american: british, european, dispersed, canadian, fritz, english, bromide, iic,
# Nearest to six: four, eight, seven, five, three, nine, two, one,
# Nearest to as: egoist, crippled, tuning, doolittle, sailboat, when, fick, horthy,
# Nearest to they: we, he, there, she, you, it, these, not,
# Nearest to at: in, on, signifying, during, near, consulting, webelements, bv,
# Nearest to more: less, very, most, quite, rather, too, extremely, lonsdaleite,
# Average loss at step 82000: 3.405871
# Average loss at step 84000: 3.407904
# Average loss at step 86000: 3.388933
# Average loss at step 88000: 3.350127
# Average loss at step 90000: 3.365711
# Nearest to but: however, though, and, although, while, they, he, which,
# Nearest to history: list, politics, holistic, pause, yoshida, bentham, transplants, rst,
# Nearest to see: refer, list, references, include, marcos, footage, external, ulm,
# Nearest to of: including, for, in, chorded, and, erg, appellation, following,
# Nearest to his: her, their, my, its, your, our, the, whose,
# Nearest to eight: seven, six, nine, five, four, three, zero, two,
# Nearest to not: still, therefore, generally, helga, only, never, almost, they,
# Nearest to other: various, pseudopods, subdued, different, minor, renounce, baraka, including,
# Nearest to an: viacom, workstations, barrows, kusanagi, brigid, another, hirohito, enforceable,
# Nearest to will: would, could, can, must, should, may, might, cannot,
# Nearest to american: british, european, canadian, english, fritz, dispersed, russian, italian,
# Nearest to six: eight, seven, five, four, nine, two, zero, three,
# Nearest to as: sailboat, tuning, crippled, kaj, vicu, recife, zeppelin, denarius,
# Nearest to they: we, he, there, she, you, it, but, stump,
# Nearest to at: during, near, in, on, under, maratha, consulting, flatly,
# Nearest to more: less, very, quite, most, rather, increasingly, too, lonsdaleite,
# Average loss at step 92000: 3.398190
# Average loss at step 94000: 3.256913
# Average loss at step 96000: 3.357544
# Average loss at step 98000: 3.240086
# Average loss at step 100000: 3.352510
# Nearest to but: however, although, though, and, while, which, or, where,
# Nearest to history: list, holistic, pause, deluded, prostitute, transplants, yoshida, rancher,
# Nearest to see: refer, references, list, external, refers, include, pentateuch, gradients,
# Nearest to of: including, and, erg, in, excel, puritanism, locksmithing, jaeger,
# Nearest to his: her, their, my, your, our, the, its, whose,
# Nearest to eight: seven, nine, four, six, five, three, two, zero,
# Nearest to not: still, never, always, therefore, generally, almost, helga, resupply,
# Nearest to other: various, pseudopods, subdued, older, others, including, philibert, hennig,
# Nearest to an: viacom, another, workstations, albertine, relinquishing, microscopy, aluminum, catastrophe,
# Nearest to will: would, can, must, should, could, may, might, cannot,
# Nearest to american: british, canadian, fritz, english, european, italian, rescuers, rescuing,
# Nearest to six: seven, four, eight, five, nine, three, two, zero,
# Nearest to as: sailboat, tuning, wow, sotho, when, like, endorse, lesser,
# Nearest to they: we, he, there, you, she, it, i, hata,
# Nearest to at: on, during, in, flatly, near, aeolus, therefrom, consulting,
# Nearest to more: less, very, most, quite, increasingly, further, tacoma, extremely,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# For continuous bag of words, the train inputs are slightly different from the skip-gram:

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
    global data_index
    span = 2 * bag_window + 1 
    batch = np.ndarray(shape=(batch_size, span -1), dtype = np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
   
    for i in range(batch_size):
        #Just for testing
        buffer_list = list(buffer)
        labels[i, 0] = buffer_list.pop(bag_window)
        batch[i] = buffer_list
        #Iterate to the next buffer
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size = 4, bag_window=bag_window)
    print('\nwith bag_window = %d:' %(bag_window))
    print('   batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])
    print('  labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#    batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#   labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#    batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#   labels: ['as', 'a', 'term', 'of']

# %% [markdown]
# Instruction says use sum of all word vectors instead of reduce_mean

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
##skip_window = 1 # How many words to consider left and right.
##num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
bag_window = 2
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  # loss = tf.reduce_mean(
  #  tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
  #                             train_labels, num_sampled, vocabulary_size))
  loss = tf.reduce_mean(
      tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, tf.reduce_sum(embed, 1),
                                 train_labels, num_sampled, vocabulary_size))
  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.662783
# Nearest to by: rabi, literature, cognitivism, dilution, graces, cuauht, sealing, overworked,
# Nearest to of: escarpment, fertilisation, deemed, friesland, gomes, headers, glass, blackbeard,
# Nearest to five: splice, watts, demiurge, montane, haines, basses, essayists, coprophagia,
# Nearest to history: hamburger, gambling, injera, grocery, manors, proximal, ibu, agni,
# Nearest to time: melcher, domestically, holbein, ingenious, dish, dale, voltages, hitman,
# Nearest to american: rss, haunt, control, moonraker, chu, stitch, condemnation, ischemia,
# Nearest to no: conectiva, vim, automorphisms, architecture, worldcon, virtuous, indefinite, intensely,
# Nearest to years: painting, waking, ly, bland, detail, poet, episodes, revolving,
# Nearest to often: rcr, gray, roswell, jing, concave, roy, disparities, photoshop,
# Nearest to these: murphy, battalions, falwell, churchill, faa, silvio, defensible, hjalmar,
# Nearest to from: jude, hint, sofa, tales, cop, bulldogs, attractor, reside,
# Nearest to in: qualitative, insignificance, struggles, tribesmen, stwertka, burundi, bartholomew, ideographic,
# Nearest to UNK: barca, exhaustive, josephus, sodomy, stadium, appear, impeached, bjarne,
# Nearest to for: decedent, trombones, passing, metz, chen, apostol, handle, do,
# Nearest to he: eu, orbits, relentless, thirteenth, selamat, histology, magenta, doonesbury,
# Nearest to eight: mammoth, presbyters, exmouth, biro, kegan, konoe, unaspirated, novelist,
# Average loss at step 2000: 5.404165
# Average loss at step 4000: 4.273646
# Average loss at step 6000: 4.092925
# Average loss at step 8000: 3.718769
# Average loss at step 10000: 3.550396
# Nearest to by: density, he, from, sarmatian, lip, repellent, implausible, carbonic,
# Nearest to of: sunglasses, plant, gangsta, non, decapitation, davidian, for, among,
# Nearest to five: four, seven, zero, nine, three, six, eight, two,
# Nearest to history: contamination, determining, secrets, niklaus, masala, leucippus, inalienable, bolshevik,
# Nearest to time: melcher, caspar, conic, year, necks, least, cerium, realpolitik,
# Nearest to american: lodger, british, fawlty, enrich, fever, gilda, handicrafts, padding,
# Nearest to no: cinemas, cataclysmic, paget, hoppers, fourteenth, merovingian, any, shirley,
# Nearest to years: year, trowa, oprah, lawson, catchy, screename, decades, jagiello,
# Nearest to often: loyalists, anglican, fundamental, sometimes, goes, chords, bass, belt,
# Nearest to these: all, other, many, certain, several, some, havenco, webcam,
# Nearest to from: through, gchq, on, into, mumps, sergius, heraclius, academics,
# Nearest to in: among, on, pusc, through, pleasure, ignorant, during, prev,
# Nearest to UNK: solidly, motionless, volume, l, w, grafton, moat, e,
# Nearest to for: ob, before, constituted, spots, of, regionally, thrill, linger,
# Nearest to he: it, she, who, ocs, widen, vocational, clandestine, senussi,
# Nearest to eight: six, nine, seven, four, five, three, zero, apollo,
# Average loss at step 12000: 3.565142
# Average loss at step 14000: 3.495200
# Average loss at step 16000: 3.477739
# Average loss at step 18000: 3.520048
# Average loss at step 20000: 3.277456
# Nearest to by: sushi, mangeshkar, repellent, photons, highs, coleco, connell, prohibitions,
# Nearest to of: enquiries, ensign, however, hennepin, like, monosyllabic, wisely, glycine,
# Nearest to five: six, three, zero, seven, eight, nine, four, infallible,
# Nearest to history: kajang, leucippus, bolshevik, drake, majority, hebrew, ninja, tolson,
# Nearest to time: least, point, melcher, caspar, realpolitik, period, module, decade,
# Nearest to american: silvio, preoccupation, british, exposing, laurie, depository, melbourne, han,
# Nearest to no: kidder, still, rentals, any, somerset, arianespace, lapse, sealing,
# Nearest to years: days, centuries, year, decades, months, screename, pohjola, jagiello,
# Nearest to often: sometimes, usually, commonly, generally, still, also, stubbornly, widely,
# Nearest to these: many, other, various, all, several, some, there, different,
# Nearest to from: cyclades, into, through, outlived, confessed, childless, storming, widescreen,
# Nearest to in: during, since, rumford, purana, on, at, airbase, guile,
# Nearest to UNK: clue, custer, alright, lucia, welcomed, moore, mcdonough, cont,
# Nearest to for: lithium, episcopalians, after, obese, through, ness, spiritus, reliefs,
# Nearest to he: it, she, who, dagny, dell, they, picts, hutchison,
# Nearest to eight: nine, six, five, three, seven, zero, apollo, golovachev,
# Average loss at step 22000: 3.418933
# Average loss at step 24000: 3.319811
# Average loss at step 26000: 3.269330
# Average loss at step 28000: 3.306991
# Average loss at step 30000: 3.261380
# Nearest to by: highs, repellent, analyte, through, when, against, herrera, brumaire,
# Nearest to of: remixing, among, during, haas, monosyllabic, in, depicting, aristides,
# Nearest to five: four, six, seven, three, zero, eight, nine, two,
# Nearest to history: list, fluctuation, version, life, carmichael, analysis, individualistic, ninja,
# Nearest to time: realpolitik, point, least, period, cholas, end, melcher, times,
# Nearest to american: america, european, marcella, elias, british, logarithm, syn, international,
# Nearest to no: kidder, any, little, psychoacoustics, somerset, vg, neptunian, moslem,
# Nearest to years: days, decades, months, year, centuries, weeks, times, losses,
# Nearest to often: sometimes, commonly, widely, also, now, generally, frequently, usually,
# Nearest to these: different, certain, other, various, adjusted, some, frankel, those,
# Nearest to from: into, through, in, cyclades, telharmonium, artery, after, during,
# Nearest to in: during, within, throughout, on, through, rumford, since, until,
# Nearest to UNK: yun, maclennan, othniel, ccg, plated, rsync, trainers, politicians,
# Nearest to for: without, after, pei, guillaume, before, ob, through, appleby,
# Nearest to he: she, it, they, dell, illicit, arsenal, tucker, polypeptides,
# Nearest to eight: nine, seven, six, zero, five, four, three, hopkinson,
# Average loss at step 32000: 3.045609
# Average loss at step 34000: 3.226099
# Average loss at step 36000: 3.216587
# Average loss at step 38000: 3.442226
# Average loss at step 40000: 3.335731
# Nearest to by: repellent, against, when, chaff, highs, using, palatal, thus,
# Nearest to of: while, including, against, enquiries, although, and, however, in,
# Nearest to five: three, four, black, seven, p, zero, carthage, eight,
# Nearest to history: career, medieval, estas, carmichael, abdullah, alexandrine, miscarriage, daro,
# Nearest to time: point, least, reason, cease, cholas, period, realpolitik, end,
# Nearest to american: america, british, european, brilliantly, massimo, agincourt, wikipedia, endosymbiotic,
# Nearest to no: kidder, little, an, although, activision, merovingian, any, omnivores,
# Nearest to years: days, decades, months, times, weeks, centuries, minutes, year,
# Nearest to often: sometimes, usually, commonly, frequently, widely, generally, still, primarily,
# Nearest to these: various, several, those, different, gotthold, certain, many, both,
# Nearest to from: into, through, bukhari, despite, cel, storming, towards, in,
# Nearest to in: within, during, through, brahms, throughout, since, although, includes,
# Nearest to UNK: grafton, lee, r, cd, russia, belt, librarian, designs,
# Nearest to for: through, ob, without, guillaume, ness, appleby, progenitors, episcopalians,
# Nearest to he: she, it, they, ocs, gertrude, who, meditate, this,
# Nearest to eight: seven, four, zero, six, five, three, nine, adjusted,
# Average loss at step 42000: 3.295235
# Average loss at step 44000: 3.181052
# Average loss at step 46000: 3.176276
# Average loss at step 48000: 3.090502
# Average loss at step 50000: 3.091374
# Nearest to by: thus, repellent, across, bolstering, without, curbed, highs, eno,
# Nearest to of: including, enquiries, depicting, bowhunting, among, in, throughout, singly,
# Nearest to five: six, four, three, seven, nine, zero, eight, sixteen,
# Nearest to history: list, listing, luxuriant, medieval, career, modern, jsr, duodecimal,
# Nearest to time: period, least, cease, landing, point, museo, times, beginning,
# Nearest to american: british, australian, elias, jagger, america, harboring, discovers, hypothesized,
# Nearest to no: little, kidder, any, a, omnivores, greenblatt, christo, merovingian,
# Nearest to years: days, decades, months, centuries, minutes, times, year, hours,
# Nearest to often: sometimes, usually, commonly, still, frequently, generally, widely, rarely,
# Nearest to these: different, some, various, several, other, all, those, certain,
# Nearest to from: into, through, during, storming, in, telharmonium, hammerhead, cel,
# Nearest to in: during, throughout, on, shehhi, within, until, rumford, when,
# Nearest to UNK: bellows, molded, serviced, praia, midfielder, grafton, rack, maclennan,
# Nearest to for: without, ob, including, against, enrich, appleby, progenitors, finn,
# Nearest to he: she, it, they, who, arbitrate, arsenal, crandall, essence,
# Nearest to eight: nine, seven, six, three, five, four, zero, buckle,
# Average loss at step 52000: 3.114427
# Average loss at step 54000: 3.119934
# Average loss at step 56000: 2.938866
# Average loss at step 58000: 3.044621
# Average loss at step 60000: 3.068989
# Nearest to by: hg, under, via, greenaway, repellent, through, chaff, using,
# Nearest to of: enquiries, remixing, depicting, heritable, glycine, hennepin, in, bowhunting,
# Nearest to five: six, four, three, seven, eight, zero, nine, two,
# Nearest to history: religion, modern, career, list, origin, science, life, uncompromising,
# Nearest to time: point, least, landing, period, times, beginning, age, cholas,
# Nearest to american: america, australian, international, harboring, british, afghana, canadian, english,
# Nearest to no: little, any, still, christo, activision, another, vg, kidder,
# Nearest to years: days, decades, months, minutes, centuries, times, weeks, reasons,
# Nearest to often: commonly, usually, sometimes, frequently, generally, widely, rarely, still,
# Nearest to these: several, various, different, many, those, certain, other, their,
# Nearest to from: into, through, storming, bukhari, between, over, during, scalar,
# Nearest to in: within, throughout, during, groupoid, on, until, under, through,
# Nearest to UNK: afraid, plaid, thurgood, biologist, spies, hopkins, rehabilitated, l,
# Nearest to for: against, without, including, guillaume, wenceslaus, cricetulus, after, loach,
# Nearest to he: she, it, they, who, hauk, crandall, polymath, there,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Average loss at step 62000: 3.035218
# Average loss at step 64000: 2.930548
# Average loss at step 66000: 2.945502
# Average loss at step 68000: 3.004631
# Average loss at step 70000: 3.017269
# Nearest to by: when, through, via, highs, with, paraphyletic, consigned, repellent,
# Nearest to of: enquiries, including, depicting, for, in, glycine, ensign, remixing,
# Nearest to five: seven, six, three, four, zero, eight, two, pants,
# Nearest to history: origin, dictionary, nature, outcasts, development, jsr, culture, interpretation,
# Nearest to time: period, least, night, distance, age, melcher, pritchard, end,
# Nearest to american: australian, canadian, british, america, german, elias, irish, english,
# Nearest to no: somerset, ecstasy, gunmen, a, healed, eugenics, deterrence, pez,
# Nearest to years: days, decades, months, minutes, year, weeks, hours, centuries,
# Nearest to often: sometimes, commonly, frequently, generally, usually, widely, rarely, now,
# Nearest to these: those, various, several, different, certain, other, many, webcam,
# Nearest to from: through, into, cel, storming, bukhari, artery, telharmonium, proletarians,
# Nearest to in: within, during, throughout, through, outside, at, around, on,
# Nearest to UNK: waterfront, monopoles, metcalfe, cumin, corrie, mutualism, silurian, sadd,
# Nearest to for: after, uncontrollably, wenceslaus, guillaume, cricetulus, when, of, colonist,
# Nearest to he: she, it, who, they, chimneys, boas, agathocles, damon,
# Nearest to eight: nine, seven, six, three, zero, five, two, feet,
# Average loss at step 72000: 2.960061
# Average loss at step 74000: 2.873226
# Average loss at step 76000: 3.013690
# Average loss at step 78000: 3.011780
# Average loss at step 80000: 2.856012
# Nearest to by: without, highs, eno, who, mangeshkar, nauru, consigned, via,
# Nearest to of: including, depicting, enquiries, while, trentino, heritable, bowhunting, hennepin,
# Nearest to five: three, four, seven, six, eight, zero, two, nine,
# Nearest to history: conception, supporters, review, list, translations, aria, docking, concept,
# Nearest to time: decade, night, melcher, period, end, least, moment, beginning,
# Nearest to american: america, australian, canadian, indian, german, dutch, international, french,
# Nearest to no: any, little, a, dealt, pranksters, nothing, somerset, oxfordshire,
# Nearest to years: decades, minutes, months, days, hours, weeks, centuries, year,
# Nearest to often: sometimes, frequently, generally, commonly, usually, typically, still, rarely,
# Nearest to these: certain, other, those, whose, various, multiple, different, some,
# Nearest to from: through, into, including, across, bukhari, artery, childless, via,
# Nearest to in: within, during, outside, throughout, on, through, including, monotonicity,
# Nearest to UNK: tarot, des, posting, benhavn, sociologist, natal, campbell, patria,
# Nearest to for: uncontrollably, wenceslaus, without, abruzzo, giorgio, chen, hispania, ankh,
# Nearest to he: she, it, they, there, who, crandall, dostoyevsky, perk,
# Nearest to eight: nine, seven, six, five, four, three, zero, pdp,
# Average loss at step 82000: 2.948991
# Average loss at step 84000: 2.913454
# Average loss at step 86000: 2.919839
# Average loss at step 88000: 2.947300
# Average loss at step 90000: 2.842922
# Nearest to by: when, through, bolstering, via, mangeshkar, consigned, without, mosley,
# Nearest to of: enquiries, in, depicting, following, remixing, bowhunting, involves, including,
# Nearest to five: four, six, seven, three, zero, eight, minurso, rethinking,
# Nearest to history: list, medieval, origins, map, collection, development, conquest, kyrgyz,
# Nearest to time: period, least, night, end, decade, point, melcher, moment,
# Nearest to american: australian, canadian, america, indian, expert, amateur, european, americans,
# Nearest to no: any, somerset, kidder, little, greenblatt, fretted, oxfordshire, hypertension,
# Nearest to years: decades, days, months, minutes, centuries, weeks, hours, year,
# Nearest to often: sometimes, frequently, usually, generally, commonly, typically, rarely, still,
# Nearest to these: various, those, schoolchildren, several, bosses, certain, different, bartolom,
# Nearest to from: into, since, via, across, through, including, childless, storming,
# Nearest to in: during, within, throughout, on, of, outside, rumford, monotonicity,
# Nearest to UNK: sanford, der, kindly, warps, whistles, euskadi, almohades, disarmed,
# Nearest to for: although, namek, uncontrollably, bodkin, after, downer, ness, without,
# Nearest to he: she, it, they, mango, hauk, dagny, positives, crandall,
# Nearest to eight: seven, nine, four, zero, six, five, three, mig,
# Average loss at step 92000: 2.903218
# Average loss at step 94000: 2.893388
# Average loss at step 96000: 2.731400
# Average loss at step 98000: 2.460725
# Average loss at step 100000: 2.712055
# Nearest to by: consigned, repellent, without, mangeshkar, eno, bolstering, when, wyatt,
# Nearest to of: enquiries, bowhunting, represents, remixing, in, including, containing, monosyllabic,
# Nearest to five: six, four, three, seven, eight, zero, two, nine,
# Nearest to history: list, origin, career, invasion, geography, tradition, politics, origins,
# Nearest to time: night, decade, point, period, least, distance, bis, age,
# Nearest to american: english, australian, canadian, british, irish, indian, french, german,
# Nearest to no: little, any, somerset, kidder, nothing, greenblatt, hypertension, philemon,
# Nearest to years: decades, days, months, minutes, year, hours, weeks, centuries,
# Nearest to often: sometimes, frequently, generally, usually, commonly, typically, also, widely,
# Nearest to these: various, those, both, certain, all, some, many, their,
# Nearest to from: through, across, into, depicting, childless, cel, hammerhead, via,
# Nearest to in: during, within, throughout, outside, on, near, of, into,
# Nearest to UNK: literally, adornment, goldsmith, berle, dendrites, salamander, sphincter, incurable,
# Nearest to for: without, after, including, despite, potawatomi, hence, appleby, abruzzo,
# Nearest to he: she, it, they, who, meditate, ange, boas, gertrude,
# Nearest to eight: seven, six, nine, four, five, three, zero, st,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
