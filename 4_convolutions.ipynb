# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = './data/udacity/notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0 : 3.51275
# Minibatch accuracy: 6.2%
# Validation accuracy: 12.8%
# Minibatch loss at step 50 : 1.48703
# Minibatch accuracy: 43.8%
# Validation accuracy: 50.4%
# Minibatch loss at step 100 : 1.04377
# Minibatch accuracy: 68.8%
# Validation accuracy: 67.4%
# Minibatch loss at step 150 : 0.601682
# Minibatch accuracy: 68.8%
# Validation accuracy: 73.0%
# Minibatch loss at step 200 : 0.898649
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.8%
# Minibatch loss at step 250 : 1.3637
# Minibatch accuracy: 56.2%
# Validation accuracy: 75.4%
# Minibatch loss at step 300 : 1.41968
# Minibatch accuracy: 62.5%
# Validation accuracy: 76.0%
# Minibatch loss at step 350 : 0.300648
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.2%
# Minibatch loss at step 400 : 1.32092
# Minibatch accuracy: 56.2%
# Validation accuracy: 80.4%
# Minibatch loss at step 450 : 0.556701
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.4%
# Minibatch loss at step 500 : 1.65595
# Minibatch accuracy: 43.8%
# Validation accuracy: 79.6%
# Minibatch loss at step 550 : 1.06995
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.2%
# Minibatch loss at step 600 : 0.223684
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 650 : 0.619602
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.8%
# Minibatch loss at step 700 : 0.812091
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.4%
# Minibatch loss at step 750 : 0.276302
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.3%
# Minibatch loss at step 800 : 0.450241
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.3%
# Minibatch loss at step 850 : 0.137139
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.3%
# Minibatch loss at step 900 : 0.52664
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 950 : 0.623835
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.1%
# Minibatch loss at step 1000 : 0.243114
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.9%
# Test accuracy: 90.0%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
  tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv1 = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    bias1 = tf.nn.relu(conv1 + layer1_biases)
    pool1 = tf.nn.max_pool(bias1, [1,2,2,1], [1,2,2,1], padding='SAME')
    conv2 = tf.nn.conv2d(pool1, layer2_weights, [1,2,2,1], [1,2,2,1], padding='SAME')
    bias2 = tf.nn.relu(conv2 + layer2_biases)
    pool2 = tf.nn.max_pool(bias2, [1,2,2,1], [1,2,2,1], padding='SAME')
    shape = pool2.get_shape().as_list()
    reshape = tf.reshape(pool2, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.719304
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.976455
# Minibatch accuracy: 31.2%
# Validation accuracy: 39.6%
# Minibatch loss at step 100: 1.078661
# Minibatch accuracy: 56.2%
# Validation accuracy: 70.9%
# Minibatch loss at step 150: 0.872772
# Minibatch accuracy: 81.2%
# Validation accuracy: 75.4%
# Minibatch loss at step 200: 0.878361
# Minibatch accuracy: 81.2%
# Validation accuracy: 75.6%
# Minibatch loss at step 250: 0.160379
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.6%
# Minibatch loss at step 300: 1.764132
# Minibatch accuracy: 43.8%
# Validation accuracy: 77.5%
# Minibatch loss at step 350: 0.768295
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.8%
# Minibatch loss at step 400: 0.271198
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.2%
# Minibatch loss at step 450: 1.119801
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.3%
# Minibatch loss at step 500: 0.220673
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.6%
# Minibatch loss at step 550: 0.430333
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.6%
# Minibatch loss at step 600: 0.623791
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.0%
# Minibatch loss at step 650: 1.458998
# Minibatch accuracy: 62.5%
# Validation accuracy: 81.7%
# Minibatch loss at step 700: 0.650347
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.3%
# Minibatch loss at step 750: 0.686586
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.9%
# Minibatch loss at step 800: 0.711341
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.6%
# Minibatch loss at step 850: 0.874239
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.4%
# Minibatch loss at step 900: 0.721672
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.6%
# Minibatch loss at step 950: 0.386457
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.4%
# Minibatch loss at step 1000: 0.613139
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.1%
# Test accuracy: 89.5%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
  tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  size = ((image_size - patch_size + 1) // 2 - patch_size + 1) // 2
  layer3_weights = tf.Variable(tf.truncated_normal(
      [size * size * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    # C1 input 28 X 28
    conv1 = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='VALID')
    bias1 = tf.nn.relu(conv1 + layer1_biases)
    # S2 input 24 X 24
    pool1 = tf.nn.avg_pool(bias1, [1,2,2,1], [1,2,2,1], padding='VALID')
    # C3 input 12 X 12
    conv2 = tf.nn.conv2d(pool1, layer2_weights, [1,1,1,1], padding='VALID')
    bias2 = tf.nn.relu(conv2 + layer2_biases)
    # S4 input 8 X 8
    pool2 = tf.nn.avg_pool(bias2, [1,2,2,1], [1,2,2,1], padding='VALID')
    # F6 input 4 X 4
    shape = pool2.get_shape().as_list()
    reshape = tf.reshape(pool2, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.969307
# Minibatch accuracy: 25.0%
# Validation accuracy: 9.4%
# Minibatch loss at step 50: 1.616261
# Minibatch accuracy: 50.0%
# Validation accuracy: 51.8%
# Minibatch loss at step 100: 1.129324
# Minibatch accuracy: 43.8%
# Validation accuracy: 62.5%
# Minibatch loss at step 150: 0.968341
# Minibatch accuracy: 75.0%
# Validation accuracy: 68.0%
# Minibatch loss at step 200: 1.389865
# Minibatch accuracy: 50.0%
# Validation accuracy: 71.3%
# Minibatch loss at step 250: 0.334899
# Minibatch accuracy: 93.8%
# Validation accuracy: 75.5%
# Minibatch loss at step 300: 1.651469
# Minibatch accuracy: 43.8%
# Validation accuracy: 71.6%
# Minibatch loss at step 350: 0.874553
# Minibatch accuracy: 87.5%
# Validation accuracy: 74.9%
# Minibatch loss at step 400: 0.285694
# Minibatch accuracy: 87.5%
# Validation accuracy: 75.6%
# Minibatch loss at step 450: 1.024773
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.0%
# Minibatch loss at step 500: 0.238809
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.6%
# Minibatch loss at step 550: 0.373207
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.3%
# Minibatch loss at step 600: 0.851311
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.1%
# Minibatch loss at step 650: 1.444937
# Minibatch accuracy: 62.5%
# Validation accuracy: 78.9%
# Minibatch loss at step 700: 0.845407
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.3%
# Minibatch loss at step 750: 0.848566
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.0%
# Minibatch loss at step 800: 0.821271
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.0%
# Minibatch loss at step 850: 0.913260
# Minibatch accuracy: 62.5%
# Validation accuracy: 80.0%
# Minibatch loss at step 900: 0.852800
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.8%
# Minibatch loss at step 950: 0.663639
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.6%
# Minibatch loss at step 1000: 0.746314
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.3%
# Test accuracy: 87.3%

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64
beta_regul = 1e-3
drop_out = 0.5

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
  tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  global_step = tf.Variable(0)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  size = ((image_size - patch_size + 1) // 2 - patch_size + 1) // 2
  layer3_weights = tf.Variable(tf.truncated_normal(
      [size * size * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_hidden], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer5_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer5_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))

  
  # Model.
  def model(data, keep_prob):
    # C1 input 28 X 28
    conv1 = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='VALID')
    bias1 = tf.nn.relu(conv1 + layer1_biases)
    # S2 input 24 X 24
    pool1 = tf.nn.avg_pool(bias1, [1,2,2,1], [1,2,2,1], padding='VALID')
    # C3 input 12 X 12
    conv2 = tf.nn.conv2d(pool1, layer2_weights, [1,1,1,1], padding='VALID')
    bias2 = tf.nn.relu(conv2 + layer2_biases)
    # S4 input 8 X 8
    pool2 = tf.nn.avg_pool(bias2, [1,2,2,1], [1,2,2,1], padding='VALID')
    # F6 input 4 X 4
    shape = pool2.get_shape().as_list()
    reshape = tf.reshape(pool2, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden5 = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    # F6
    drop5 = tf.nn.dropout(hidden5, keep_prob)
    hidden6 = tf.nn.relu(tf.matmul(hidden5, layer4_weights) + layer4_biases)
    drop6 = tf.nn.dropout(hidden6, keep_prob)
    return tf.matmul(drop6, layer5_weights) + layer5_biases
  
  # Training computation.
  logits = model(tf_train_dataset, drop_out)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  learning_rate = tf.train.exponential_decay(0.05, global_step, 1000, 0.85, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset, 1.0))
  test_prediction = tf.nn.softmax(model(tf_test_dataset, 1.0))

# %%
num_steps =5001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.157207
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.056849
# Minibatch accuracy: 31.2%
# Validation accuracy: 29.8%
# Minibatch loss at step 100: 1.894912
# Minibatch accuracy: 50.0%
# Validation accuracy: 44.8%
# Minibatch loss at step 150: 1.304645
# Minibatch accuracy: 50.0%
# Validation accuracy: 45.9%
# Minibatch loss at step 200: 1.654961
# Minibatch accuracy: 18.8%
# Validation accuracy: 63.6%
# Minibatch loss at step 250: 0.705730
# Minibatch accuracy: 75.0%
# Validation accuracy: 69.8%
# Minibatch loss at step 300: 1.863491
# Minibatch accuracy: 43.8%
# Validation accuracy: 68.5%
# Minibatch loss at step 350: 1.554707
# Minibatch accuracy: 81.2%
# Validation accuracy: 71.3%
# Minibatch loss at step 400: 0.788997
# Minibatch accuracy: 75.0%
# Validation accuracy: 72.3%
# Minibatch loss at step 450: 1.162698
# Minibatch accuracy: 62.5%
# Validation accuracy: 72.3%
# Minibatch loss at step 500: 0.430620
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.1%
# Minibatch loss at step 550: 0.515533
# Minibatch accuracy: 81.2%
# Validation accuracy: 75.6%
# Minibatch loss at step 600: 1.494310
# Minibatch accuracy: 62.5%
# Validation accuracy: 76.1%
# Minibatch loss at step 650: 1.571673
# Minibatch accuracy: 56.2%
# Validation accuracy: 77.6%
# Minibatch loss at step 700: 1.130934
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.0%
# Minibatch loss at step 750: 0.488786
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.8%
# Minibatch loss at step 800: 0.858838
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.1%
# Minibatch loss at step 850: 0.867007
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.8%
# Minibatch loss at step 900: 1.048277
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.8%
# Minibatch loss at step 950: 0.832827
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.8%
# Minibatch loss at step 1000: 0.799525
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.7%
# Minibatch loss at step 1050: 1.141712
# Minibatch accuracy: 62.5%
# Validation accuracy: 79.7%
# Minibatch loss at step 1100: 0.876272
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.4%
# Minibatch loss at step 1150: 0.931397
# Minibatch accuracy: 62.5%
# Validation accuracy: 79.3%
# Minibatch loss at step 1200: 0.690798
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.0%
# Minibatch loss at step 1250: 0.958598
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.2%
# Minibatch loss at step 1300: 0.729288
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.9%
# Minibatch loss at step 1350: 0.707232
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.0%
# Minibatch loss at step 1400: 0.498032
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.6%
# Minibatch loss at step 1450: 0.761052
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.1%
# Minibatch loss at step 1500: 1.161281
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.4%
# Minibatch loss at step 1550: 1.058423
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.5%
# Minibatch loss at step 1600: 0.682660
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.4%
# Minibatch loss at step 1650: 0.884902
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.5%
# Minibatch loss at step 1700: 0.936253
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.5%
# Minibatch loss at step 1750: 0.704835
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.4%
# Minibatch loss at step 1800: 0.879664
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.1%
# Minibatch loss at step 1850: 1.103767
# Minibatch accuracy: 62.5%
# Validation accuracy: 82.0%
# Minibatch loss at step 1900: 0.403007
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.4%
# Minibatch loss at step 1950: 0.589052
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.7%
# Minibatch loss at step 2000: 0.246294
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.8%
# Minibatch loss at step 2050: 0.543417
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.3%
# Minibatch loss at step 2100: 0.854619
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 2150: 0.196825
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 2200: 0.655890
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.2%
# Minibatch loss at step 2250: 0.650388
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.2%
# Minibatch loss at step 2300: 0.731922
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.1%
# Minibatch loss at step 2350: 0.817734
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.0%
# Minibatch loss at step 2400: 0.332472
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.2%
# Minibatch loss at step 2450: 1.166827
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.7%
# Minibatch loss at step 2500: 0.359306
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.5%
# Minibatch loss at step 2550: 0.466958
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.5%
# Minibatch loss at step 2600: 0.580188
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.3%
# Minibatch loss at step 2650: 0.446079
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.7%
# Minibatch loss at step 2700: 0.217009
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.8%
# Minibatch loss at step 2750: 0.625734
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.5%
# Minibatch loss at step 2800: 0.656816
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.8%
# Minibatch loss at step 2850: 0.262553
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.5%
# Minibatch loss at step 2900: 0.402348
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.3%
# Minibatch loss at step 2950: 0.424462
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.0%
# Minibatch loss at step 3000: 0.554691
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.3%
# Minibatch loss at step 3050: 0.621692
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.3%
# Minibatch loss at step 3100: 0.301660
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.4%
# Minibatch loss at step 3150: 0.275826
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.3%
# Minibatch loss at step 3200: 0.513911
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.7%
# Minibatch loss at step 3250: 0.986017
# Minibatch accuracy: 56.2%
# Validation accuracy: 83.9%
# Minibatch loss at step 3300: 0.272393
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.7%
# Minibatch loss at step 3350: 0.410899
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.2%
# Minibatch loss at step 3400: 0.431519
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.3%
# Minibatch loss at step 3450: 0.492613
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.0%
# Minibatch loss at step 3500: 0.462384
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.7%
# Minibatch loss at step 3550: 0.710822
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.1%
# Minibatch loss at step 3600: 0.491744
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.0%
# Minibatch loss at step 3650: 0.373603
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.0%
# Minibatch loss at step 3700: 0.698525
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.5%
# Minibatch loss at step 3750: 0.232394
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.2%
# Minibatch loss at step 3800: 0.494451
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.8%
# Minibatch loss at step 3850: 0.427733
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.7%
# Minibatch loss at step 3900: 0.685195
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.7%
# Minibatch loss at step 3950: 0.390831
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.7%
# Minibatch loss at step 4000: 0.823935
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.4%
# Minibatch loss at step 4050: 0.319950
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.2%
# Minibatch loss at step 4100: 0.792224
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.1%
# Minibatch loss at step 4150: 0.543325
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.9%
# Minibatch loss at step 4200: 0.614276
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.4%
# Minibatch loss at step 4250: 0.791400
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.2%
# Minibatch loss at step 4300: 0.520824
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.2%
# Minibatch loss at step 4350: 0.495722
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.2%
# Minibatch loss at step 4400: 0.338378
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.0%
# Minibatch loss at step 4450: 0.709566
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.4%
# Minibatch loss at step 4500: 0.990977
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.1%
# Minibatch loss at step 4550: 0.155823
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.5%
# Minibatch loss at step 4600: 0.459204
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.4%
# Minibatch loss at step 4650: 0.347054
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.8%
# Minibatch loss at step 4700: 0.809680
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.2%
# Minibatch loss at step 4750: 0.303136
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.8%
# Minibatch loss at step 4800: 0.416434
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.9%
# Minibatch loss at step 4850: 0.956032
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.0%
# Minibatch loss at step 4900: 0.472018
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.1%
# Minibatch loss at step 4950: 0.154539
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 5000: 0.153959
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.2%
# Test accuracy: 91.6%

# %% [markdown]
# Accuracy isn't that great, recommendation is to make changes in the depth and increasing number of feature maps
