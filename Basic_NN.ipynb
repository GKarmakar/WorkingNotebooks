# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
#added some noise in the sine curve - 
n_observations = 1000
xs = np.linspace(-3, 3, n_observations)
ys = np.sin(xs) + np.random.uniform(-0.5, 0.5, n_observations)
plt.scatter(xs, ys, alpha = 0.15, marker='+')

# %%
import tensorflow as tf

# %%
see = tf.InteractiveSession()
n = tf.random_normal([1000]).eval()
plt.hist(n)
# Out:
# (array([   9.,   28.,   70.,  145.,  203.,  228.,  178.,   95.,   34.,   10.]),
#  array([-3.09484982, -2.49651134, -1.89817286, -1.29983437, -0.70149589,
#         -0.1031574 ,  0.49518108,  1.09351957,  1.69185805,  2.29019654,
#          2.88853502]),
#  <a list of 10 Patch objects>)

# %%
n = tf.random_normal([1000], stddev=0.1).eval()
plt.hist(n)
# Out:
# (array([  10.,   30.,   88.,  163.,  238.,  227.,  169.,   58.,   14.,    3.]),
#  array([-0.31465441, -0.24986346, -0.18507252, -0.12028157, -0.05549062,
#          0.00930032,  0.07409127,  0.13888221,  0.20367316,  0.26846411,
#          0.33325505]),
#  <a list of 10 Patch objects>)

# %%
X = n
W = tf.Variable(tf.random_normal([1], dtype=tf.float32, stddev=0.1), name='weight')
B = tf.Variable(tf.constant([1], dtype=tf.float32), name='bias')
y_pred = X * W + B

# %%
def distance(p1, p2):
    return tf.abs(p1 - p2)

# %%
cost = distance(y_pred, tf.sin(X))

# %%
cost = distance(y_pred, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-a3435808f91d> in <module>()
# ----> 1 cost = distance(y_pred, y)
#
# NameError: name 'y' is not defined

# %%
cost = tf.reduce_mean(distance(Y-pred, Y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01).minimize(cost)
n_iterations = 500
fig.ax = plt.subplots(1,1)
ax.scatter(xs,ys,alpha=0.5,marker='+')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-dbe6836200b4> in <module>()
# ----> 1 cost = tf.reduce_mean(distance(Y-pred, Y))
#       2 optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01).minimize(cost)
#       3 n_iterations = 500
#       4 fig.ax = plt.subplots(1,1)
#       5 ax.scatter(xs,ys,alpha=0.5,marker='+')
#
# NameError: name 'distance' is not defined

# %%
#
