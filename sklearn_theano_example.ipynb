# %%
# %matplotlib inline
from __future__ import print_function
import numpy as np
import theano
import wget
from PIL import Image
from scipy.misc import imresize, imread
import matplotlib.pyplot as plt

# %%
w = np.random.rand(3,2)
W = theano.shared(np.zeros((3,2)))
print(W.get_value())
W.set_value(w)
print(W.get_value())
# Out:
# [[ 0.  0.]
#  [ 0.  0.]
#  [ 0.  0.]]
# [[ 0.25223665  0.93729367]
#  [ 0.08610789  0.65164927]
#  [ 0.64474607  0.52664754]]

# %%
#Classifying with sklearn-theano and overfeat
url1= "https://www.petfinder.com/wp-content/uploads/2012/11/100691619-what-is-cat-fostering-632x475.jpg"
url2 = "https://upload.wikimedia.org/wikipedia/commons/thumb/3/33/Siberian_Husky_sable.jpg/220px-Siberian_Husky_sable.jpg"
catfile = wget.download(url1)
dogfile = wget.download(url2)
cat = imresize(imread(catfile), [231, 231])
dog = imresize(imread(dogfile), [231, 231])
plt.subplot(121)
plt.imshow(cat)
plt.subplot(122)
plt.imshow(dog)

# %%
from sklearn_theano.feature_extraction import OverfeatClassifier
clf = OverfeatClassfier(top_n=5)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-03b878d3842c> in <module>()
# ----> 1 from sklearn_theano.feature_extraction import OverfeatClassifier
#       2 clf = OverfeatClassfier(top_n=5)
#
# ImportError: No module named sklearn_theano.feature_extraction

# %%
clf.predict(cat)

# %%
clf.predict(dog)
