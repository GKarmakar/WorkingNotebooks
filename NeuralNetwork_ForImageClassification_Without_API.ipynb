# %% [markdown]
# Image classification on CIFAR-10 image dataset using multi-layer perceptrons in python without using any API.

# %%
import cPickle
import numpy as np

# %%
#unpickle the pickled data
def unpickle(file):
    with open(file, 'rb') as f:
        dict = cPickle.load(f)
    return dict

# %%
"""
Merge batches from CIFAR-10 pickled data
Input: num_to_load - number of batches of CIFAR-10 to load and merge
output: merged features and labels from specified no. of batches of CIFAR-10  
"""
def merge_batches(num_to_load=1):
    for i in range(num_to_load):
        path = "/Users/trinakarmakar/downloads/cifar-10-batches-py/"
        filename = "data_batch_" + str(i + 1)
        file = path+filename
        data = unpickle(file)
        if i == 0:
            features = data["data"]
            labels = np.array(data['labels'])
        else:
            features = np.append(features, data["data"], axis=0)
            labels = np.append(labels, data["labels"], axis=0)
    return features, labels

# %%
def one_hot_encode(data):
    """
    Encode target label IDs to one hot vecotr of size L where 
    L is the number of unique labels
    Params: List of label IDs
    Output: List of one hot vectors
    """
    one_hot = np.zeros((data.shape[0], 10))
    one_hot[np.arange(data.shape[0]), data] = 1
    return one_hot

# %%
def normalize(data):
    #Normalize the image pixels
    return data / 255.0

# %%
def preprocess(num_to_load=1):
    #Helper function to load and preprocess cifar-10 data
    X, y = merge_batches(num_to_load=1)
    X = normalize(X)
    X = X.reshape(-1, 3072, 1)
    y = one_hot_encode(y)
    y = y.reshape(-1,10,1)
    return X, y

# %%
def dataset_split(X, y, ratio=0.8):
    split = int(ratio * X.shape[0])
    indices = np.random.permutation(X.shape[0])
    training_idx, val_idx = indices[:split], indices[split:]
    X_train, X_val = X[training_idx, :], X[val_idx, :]
    y_train, y_val = y[training_idx, :], y[val_idx, :]
    print("Records in training dataset", X_train.shape[0])
    print("Records in validation dataset", X_val.shape[0])
    return X_train, y_train, X_val, y_val

# %%
def sigmoid(out):
    return 1.0 / (1.0 + np.exp(-out))

# %%
def delta_sigmoid(out):
    #Derivative of sigmoid activation
    return sigmoid(out) * (1 - sigmoid(out))

# %%
def sigmoidcrossentropyloss(a, y):
    #calculate sigmoid cross entropy loss
    return np.sum(np.nan_to_num(-y*np.log(a)-(1-y)*np.log(1-a)))

# %%
class DNN(object):
    '''
    class to define neural network
    '''
    def __init__(self, sizes):
        '''
        initialize bias and weight using Gausian distribution with mean = 0 and variance = 1
        '''
        self.num_layers = len(sizes)
        #setting appropriate dimensions for weights and biases
        self.biases = [np.random.randn(y, 1) for y in sizes[1:]]
        self.weights = [np.random.randn(y,x) for x, y in zip(sizes[:-1], sizes[1:])]
    def feedforward(self, x):
        '''
        Forward passes an image feature matrix through the deep network
        params: x is image features
        '''
        activation = x
        activations = [x] #list to store activations of every layers
        outs = [] # list to store vectors for every layers
        for b, w in zip(self.biases, self.weights):
            out = np.dot(w, activation) + b
            outs.append(out)
            activation = sigmoid(out)
            activations.append(activation)
        return outs, activations
    def get_batch(self, X, y, batch_size):
        '''
        A data iterator for batching image features and labels
        '''
        for batch_idx in range(0, X.shape[0], batch_size):
            batch = zip(X[batch_idx:batch_idx+batch_size],
                       y[batch_idx:batch_idx + batch_size])
            yield batch
    def train(self, X, y, batch_size = 100, learning_rate = 0.2, epochs = 2):
        '''
        Train neural netwrok by batches of images. The weights and biases are updated through 
        backpropagation on batches using SGD. 
        Params: X, y = Image observation and labels
        batch_size =size of batch of input data
        learning_rate = eta; control the update rate of model parameters
        epochs = no. of times of iteration to train the model
        '''
        n_batches = X.shape[0] / batch_size
        for j in xrange(epochs):
            batch_iter = self.get_batch(X, y, batch_size)
            for i in range(n_batches):
                batch = batch_iter.next()
                del_b = [np.zeros(b.shape) for b in self.biases]
                del_w = [np.zeros(w.shape) for w in self.weights]
                for batch_X, batch_y in batch:
                    loss, delta_del_b, delta_del_w = self.backpropagation(
                         batch_X, batch_y)
                    del_b = [db + ddb for db, ddb in zip(del_b, delta_del_b)]
                    del_w = [dw + ddw for dw, ddw in zip(del_w, delta_del_w)]
                    self.weights = [w - (learning_rate / batch_size) * delw for w, delw in zip(self.weights, del_w)]
                    self.biases = [b - (learning_rate / batch_size) * delb for b, delb in zip(self.biases, del_b)]
                    print("\n Epoch %d complete\tLoss: %f\n"%(j, loss))
    def backpropagation(self, X, y):
        '''
        Using derivative gradient of cost function is calculated
        '''
        del_b = [np.zeros(b.shape) for b in self.biases]
        del_w = [np.zeros(w.shape) for w in self.weights]
        
        outs, activations = self.feedforward(X) # feedforward to compute output to calculate loss
        loss = sigmoidcrossentropyloss(activations[-1],y)
        delta_cost = activations[-1] - y # cost to be mininmized
        delta = delta_cost
        del_b[-1] = delta
        del_w[-1] = np.dot(delta, activations[-2].T)
        #propagate gradients backward 
        for k in xrange(2, self.num_layers):
            out = outs[-k]
            delta_activation = delta_sigmoid(out)
            delta = np.dot(self.weights[-k + 1].T, delta) * delta_activation
            del_b[-k] = delta
            del_w[-k] = np.dot(delta, activations[-k - 1].T)
        return (loss, del_b, del_w)
        
    def eval(self, X, y):
        #Predic the label and compare the model accuracy
        
        count = 0
        for x, _y in zip(X, y):
            outs, activations = self.feedforward(X)
            #position of maximum value is the predicted labels
            if np.argmax(activations[-1]) == np.argmax(_y):
                count += 1
        print("Accuracy: %f" %(float(count) / X.shape[0] * 100))
        
    def predict(self, X):
        
        labels = unpickle(path+"batches.meta")["label_names"]
        preds = np.array([])
        for x in X:
            outs, activations = self.feedforward(x)
            preds = np.append(preds, np.argmax(activations[-1]))
        preds = np.array([labels[int(p)] for p in preds])
        return preds
    
    
def main():
    X, y = preprocess(num_to_load=1)
    X_train, y_train, X_val, y_val = dataset_split(X, y)
    model = DNN([3072, 50, 30, 10]) # Initialize the model using 32*32*3 image 
    model.train(X_train, y_train, epochs=15)
    model.eval(X_val, y_val)
    test_X = unpickle(path+"test_batch")["data"] / 255.0
    test_X = test_X.reshape(-1, 3072, 1)
    print(model.predict(test_X))  
main()
# Out:
# ('Records in training dataset', 8000)
# ('Records in validation dataset', 2000)
#
#  Epoch 0 complete	Loss: 19.902027
#
#
#  Epoch 0 complete	Loss: 10.134308
#
#
#  Epoch 0 complete	Loss: 16.009127
#
#
#  Epoch 0 complete	Loss: 9.231338
#
#
#  Epoch 0 complete	Loss: 13.922058
#
#
#  Epoch 0 complete	Loss: 9.848298
#
#
#  Epoch 0 complete	Loss: 12.201828
#
#
#  Epoch 0 complete	Loss: 13.371090
#
#
#  Epoch 0 complete	Loss: 9.356876
#
#
#  Epoch 0 complete	Loss: 6.030037
#
#
#  Epoch 0 complete	Loss: 4.924358
#
#
#  Epoch 0 complete	Loss: 6.238110
#
#
#  Epoch 0 complete	Loss: 3.628627
#
#
#  Epoch 0 complete	Loss: 6.410789
#
#
#  Epoch 0 complete	Loss: 1.593625
#
#
#  Epoch 0 complete	Loss: 7.929324
#
#
#  Epoch 0 complete	Loss: 4.777761
#
#
#  Epoch 0 complete	Loss: 4.239056
#
#
#  Epoch 0 complete	Loss: 5.359840
#
#
#  Epoch 0 complete	Loss: 2.591541
#
#
#  Epoch 0 complete	Loss: 2.754243
#
#
#  Epoch 0 complete	Loss: 4.396471
#
#
#  Epoch 0 complete	Loss: 4.402387
#
#
#  Epoch 0 complete	Loss: 5.313846
#
#
#  Epoch 0 complete	Loss: 3.373975
#
#
#  Epoch 0 complete	Loss: 4.311851
#
#
#  Epoch 0 complete	Loss: 3.103221
#
#
#  Epoch 0 complete	Loss: 5.778396
#
#
#  Epoch 0 complete	Loss: 6.069938
#
#
#  Epoch 0 complete	Loss: 4.443596
#
#
#  Epoch 0 complete	Loss: 3.667648
#
#
#  Epoch 0 complete	Loss: 7.599006
#
#
#  Epoch 0 complete	Loss: 1.917010
#
#
#  Epoch 0 complete	Loss: 5.678557
#
#
#  Epoch 0 complete	Loss: 5.168586
#
#
#  Epoch 0 complete	Loss: 4.845260
#
#
#  Epoch 0 complete	Loss: 5.751777
#
#
#  Epoch 0 complete	Loss: 6.630605
#
#
#  Epoch 0 complete	Loss: 4.072088
#
#
#  Epoch 0 complete	Loss: 5.287125
#
#
#  Epoch 0 complete	Loss: 7.143110
#
#
#  Epoch 0 complete	Loss: 1.572902
#
#
#  Epoch 0 complete	Loss: 4.765524
#
#
#  Epoch 0 complete	Loss: 9.002205
#
#
#  Epoch 0 complete	Loss: 9.328656
#
#
#  Epoch 0 complete	Loss: 2.920615
#
#
#  Epoch 0 complete	Loss: 8.337811
#
#
#  Epoch 0 complete	Loss: 10.778425
#
#
#  Epoch 0 complete	Loss: 10.519873
#
#
#  Epoch 0 complete	Loss: 5.965014
#
#
#  Epoch 0 complete	Loss: 5.100210
#
#
#  Epoch 0 complete	Loss: 4.293935
#
#
#  Epoch 0 complete	Loss: 5.115335
#
#
#  Epoch 0 complete	Loss: 7.245783
#
#
#  Epoch 0 complete	Loss: 3.284666
#
#
#  Epoch 0 complete	Loss: 11.586189
#
#
#  Epoch 0 complete	Loss: 3.620594
#
#
#  Epoch 0 complete	Loss: 2.878430
#
#
#  Epoch 0 complete	Loss: 5.925509
#
#
#  Epoch 0 complete	Loss: 9.166638
#
#
#  Epoch 0 complete	Loss: 12.843857
#
#
#  Epoch 0 complete	Loss: 1.703376
#
#
#  Epoch 0 complete	Loss: 9.167928
#
#
#  Epoch 0 complete	Loss: 5.181965
#
#
#  Epoch 0 complete	Loss: 1.905098
#
#
#  Epoch 0 complete	Loss: 11.098476
#
#
#  Epoch 0 complete	Loss: 2.558365
#
#
#  Epoch 0 complete	Loss: 2.568968
#
#
#  Epoch 0 complete	Loss: 9.337824
#
#
#  Epoch 0 complete	Loss: 12.409938
#
#
#  Epoch 0 complete	Loss: 9.553684
#
#
#  Epoch 0 complete	Loss: 3.042826
#
#
#  Epoch 0 complete	Loss: 10.336452
#
#
#  Epoch 0 complete	Loss: 2.513225
#
#
#  Epoch 0 complete	Loss: 14.146713
#
#
#  Epoch 0 complete	Loss: 8.013930
#
#
#  Epoch 0 complete	Loss: 2.151677
#
#
#  Epoch 0 complete	Loss: 6.977878
#
#
#  Epoch 0 complete	Loss: 11.769527
#
#
#  Epoch 0 complete	Loss: 4.662442
#
#
#  Epoch 0 complete	Loss: 2.596823
#
#
#  Epoch 0 complete	Loss: 7.123764
#
#
#  Epoch 0 complete	Loss: 4.388197
#
#
#  Epoch 0 complete	Loss: 4.469900
#
#
#  Epoch 0 complete	Loss: 3.847365
#
#
#  Epoch 0 complete	Loss: 4.952148
#
#
#  Epoch 0 complete	Loss: 4.300196
#
#
#  Epoch 0 complete	Loss: 1.060159
#
#
#  Epoch 0 complete	Loss: 13.982316
#
#
#  Epoch 0 complete	Loss: 6.742502
#
#
#  Epoch 0 complete	Loss: 11.430343
#
#
#  Epoch 0 complete	Loss: 4.087570
#
#
#  Epoch 0 complete	Loss: 8.149143
#
#
#  Epoch 0 complete	Loss: 3.303502
#
#
#  Epoch 0 complete	Loss: 5.918647
#
#
#  Epoch 0 complete	Loss: 2.027964
#
#
#  Epoch 0 complete	Loss: 11.734539
#
#
#  Epoch 0 complete	Loss: 11.559552
#
#
#  Epoch 0 complete	Loss: 2.091298
#
#
#  Epoch 0 complete	Loss: 13.105969
#
#
#  Epoch 0 complete	Loss: 5.631872
#
#
#  Epoch 0 complete	Loss: 13.299339
#
#
#  Epoch 0 complete	Loss: 1.714683
#
#
#  Epoch 0 complete	Loss: 6.517282
#
#
#  Epoch 0 complete	Loss: 14.400045
#
#
#  Epoch 0 complete	Loss: 12.500199
#
#
#  Epoch 0 complete	Loss: 4.476023
#
#
#  Epoch 0 complete	Loss: 2.816618
#
#
#  Epoch 0 complete	Loss: 6.614197
#
#
#  Epoch 0 complete	Loss: 4.593108
#
#
#  Epoch 0 complete	Loss: 11.416721
#
#
#  Epoch 0 complete	Loss: 4.509929
#
#
#  Epoch 0 complete	Loss: 5.160181
#
#
#  Epoch 0 complete	Loss: 5.674699
#
#
#  Epoch 0 complete	Loss: 4.085825
#
#
#  Epoch 0 complete	Loss: 13.610833
#
#
#  Epoch 0 complete	Loss: 14.046889
#
#
#  Epoch 0 complete	Loss: 5.270015
#
#
#  Epoch 0 complete	Loss: 12.300925
#
#
#  Epoch 0 complete	Loss: 13.095424
#
#
#  Epoch 0 complete	Loss: 11.255242
#
#
#  Epoch 0 complete	Loss: 10.384461
#
#
#  Epoch 0 complete	Loss: 3.528724
#
#
#  Epoch 0 complete	Loss: 11.524301
#
#
#  Epoch 0 complete	Loss: 5.806403
#
#
#  Epoch 0 complete	Loss: 12.454266
#
#
#  Epoch 0 complete	Loss: 4.620304
#
#
#  Epoch 0 complete	Loss: 10.223315
#
#
#  Epoch 0 complete	Loss: 12.940117
#
#
#  Epoch 0 complete	Loss: 9.283392
#
#
#  Epoch 0 complete	Loss: 5.103309
#
#
#  Epoch 0 complete	Loss: 8.472557
#
#
#  Epoch 0 complete	Loss: 2.261037
#
#
#  Epoch 0 complete	Loss: 5.156355
#
#
#  Epoch 0 complete	Loss: 4.743521
#
#
#  Epoch 0 complete	Loss: 2.927977
#
#
#  Epoch 0 complete	Loss: 3.327597
#
#
#  Epoch 0 complete	Loss: 8.548900
#
#
#  Epoch 0 complete	Loss: 12.561299
#
#
#  Epoch 0 complete	Loss: 4.630027
#
#
#  Epoch 0 complete	Loss: 3.423212
#
#
#  Epoch 0 complete	Loss: 5.258529
#
#
#  Epoch 0 complete	Loss: 7.294496
#
#
#  Epoch 0 complete	Loss: 2.865999
#
#
#  Epoch 0 complete	Loss: 5.290091
#
#
#  Epoch 0 complete	Loss: 2.300352
#
#
#  Epoch 0 complete	Loss: 5.774729
#
#
#  Epoch 0 complete	Loss: 2.615038
#
#
#  Epoch 0 complete	Loss: 3.921044
#
#
#  Epoch 0 complete	Loss: 2.430440
#
#
#  Epoch 0 complete	Loss: 11.977046
#
#
#  Epoch 0 complete	Loss: 4.834092
#
#
#  Epoch 0 complete	Loss: 3.607795
#
#
#  Epoch 0 complete	Loss: 4.423523
#
#
#  Epoch 0 complete	Loss: 2.636784
#
#
#  Epoch 0 complete	Loss: 10.954950
#
#
#  Epoch 0 complete	Loss: 2.425717
#
#
#  Epoch 0 complete	Loss: 4.834605
#
#
#  Epoch 0 complete	Loss: 2.899585
#
#
#  Epoch 0 complete	Loss: 3.597771
#
#
#  Epoch 0 complete	Loss: 4.540868
#
#
#  Epoch 0 complete	Loss: 9.726142
#
#
#  Epoch 0 complete	Loss: 3.425850
#
#
#  Epoch 0 complete	Loss: 5.452821
#
#
#  Epoch 0 complete	Loss: 2.933074
#
#
#  Epoch 0 complete	Loss: 2.619098
#
#
#  Epoch 0 complete	Loss: 2.932344
#
#
#  Epoch 0 complete	Loss: 3.113875
#
#
#  Epoch 0 complete	Loss: 1.882841
#
#
#  Epoch 0 complete	Loss: 2.053362
#
#
#  Epoch 0 complete	Loss: 7.529668
#
#
#  Epoch 0 complete	Loss: 2.535298
#
#
#  Epoch 0 complete	Loss: 3.555377
#
#
#  Epoch 0 complete	Loss: 3.810461
#
#
#  Epoch 0 complete	Loss: 8.943948
#
#
#  Epoch 0 complete	Loss: 8.672164
#
#
#  Epoch 0 complete	Loss: 7.470946
#
#
#  Epoch 0 complete	Loss: 3.805934
#
#
#  Epoch 0 complete	Loss: 2.871892
#
#
#  Epoch 0 complete	Loss: 5.874163
#
#
#  Epoch 0 complete	Loss: 3.941499
#
#
#  Epoch 0 complete	Loss: 4.434266
#
#
#  Epoch 0 complete	Loss: 3.551107
#
#
#  Epoch 0 complete	Loss: 3.166114
#
#
#  Epoch 0 complete	Loss: 8.628836
#
#
#  Epoch 0 complete	Loss: 7.236118
#
#
#  Epoch 0 complete	Loss: 8.792180
#
#
#  Epoch 0 complete	Loss: 7.714047
#
#
#  Epoch 0 complete	Loss: 2.279635
#
#
#  Epoch 0 complete	Loss: 4.937495
#
#
#  Epoch 0 complete	Loss: 3.129458
#
#
#  Epoch 0 complete	Loss: 7.371590
#
#
#  Epoch 0 complete	Loss: 2.532723
#
#
#  Epoch 0 complete	Loss: 7.769771
#
#
#  Epoch 0 complete	Loss: 8.404060
#
#
#  Epoch 0 complete	Loss: 8.600068
#
#
#  Epoch 0 complete	Loss: 3.848446
#
#
#  Epoch 0 complete	Loss: 3.942792
#
#
#  Epoch 0 complete	Loss: 4.806465
#
#
#  Epoch 0 complete	Loss: 3.586752
#
#
#  Epoch 0 complete	Loss: 3.985476
#
#
#  Epoch 0 complete	Loss: 4.006879
#
#
#  Epoch 0 complete	Loss: 1.873392
#
#
#  Epoch 0 complete	Loss: 4.456443
#
#
#  Epoch 0 complete	Loss: 5.519826
#
#
#  Epoch 0 complete	Loss: 3.074557
#
#
#  Epoch 0 complete	Loss: 5.368756
#
#
#  Epoch 0 complete	Loss: 3.498271
#
#
#  Epoch 0 complete	Loss: 4.108902
#
#
#  Epoch 0 complete	Loss: 3.194904
#
#
#  Epoch 0 complete	Loss: 3.933757
#
#
#  Epoch 0 complete	Loss: 3.357796
#
#
#  Epoch 0 complete	Loss: 3.424053
#
#
#  Epoch 0 complete	Loss: 3.969784
#
#
#  Epoch 0 complete	Loss: 3.398703
#
#
#  Epoch 0 complete	Loss: 3.265820
#
#
#  Epoch 0 complete	Loss: 3.344946
#
#
#  Epoch 0 complete	Loss: 3.238224
#
#
#  Epoch 0 complete	Loss: 3.140048
#
#
#  Epoch 0 complete	Loss: 7.332459
#
#
#  Epoch 0 complete	Loss: 4.610016
#
#
#  Epoch 0 complete	Loss: 2.558324
#
#
#  Epoch 0 complete	Loss: 6.980992
#
#
#  Epoch 0 complete	Loss: 4.062407
#
#
#  Epoch 0 complete	Loss: 5.479786
#
#
#  Epoch 0 complete	Loss: 9.572075
#
#
#  Epoch 0 complete	Loss: 2.580930
#
#
#  Epoch 0 complete	Loss: 3.003242
#
#
#  Epoch 0 complete	Loss: 4.181632
#
#
#  Epoch 0 complete	Loss: 2.713753
#
#
#  Epoch 0 complete	Loss: 2.849696
#
#
#  Epoch 0 complete	Loss: 4.237743
#
#
#  Epoch 0 complete	Loss: 2.424987
#
#
#  Epoch 0 complete	Loss: 3.051844
#
#
#  Epoch 0 complete	Loss: 4.108117
#
#
#  Epoch 0 complete	Loss: 3.087741
#
#
#  Epoch 0 complete	Loss: 1.709741
#
#
#  Epoch 0 complete	Loss: 5.010540
#
#
#  Epoch 0 complete	Loss: 3.006556
#
#
#  Epoch 0 complete	Loss: 5.400114
#
#
#  Epoch 0 complete	Loss: 2.945218
#
#
#  Epoch 0 complete	Loss: 2.665352
#
#
#  Epoch 0 complete	Loss: 2.905110
#
#
#  Epoch 0 complete	Loss: 2.453668
#
#
#  Epoch 0 complete	Loss: 3.049727
#
#
#  Epoch 0 complete	Loss: 3.767056
#
#
#  Epoch 0 complete	Loss: 2.542903
#
#
#  Epoch 0 complete	Loss: 2.525618
#
#
#  Epoch 0 complete	Loss: 3.084157
#
#
#  Epoch 0 complete	Loss: 3.686405
#
#
#  Epoch 0 complete	Loss: 2.375978
#
#
#  Epoch 0 complete	Loss: 2.503979
#
#
#  Epoch 0 complete	Loss: 3.430522
#
#
#  Epoch 0 complete	Loss: 4.452806
#
#
#  Epoch 0 complete	Loss: 3.514198
#
#
#  Epoch 0 complete	Loss: 7.684517
#
#
#  Epoch 0 complete	Loss: 3.805802
#
#
#  Epoch 0 complete	Loss: 2.322994
#
#
#  Epoch 0 complete	Loss: 2.174127
#
#
#  Epoch 0 complete	Loss: 8.388199
#
#
#  Epoch 0 complete	Loss: 3.216811
#
#
#  Epoch 0 complete	Loss: 2.273366
#
#
#  Epoch 0 complete	Loss: 3.923938
#
#
#  Epoch 0 complete	Loss: 2.623800
#
#
#  Epoch 0 complete	Loss: 4.039643
#
#
#  Epoch 0 complete	Loss: 1.883629
#
#
#  Epoch 0 complete	Loss: 2.194092
#
#
#  Epoch 0 complete	Loss: 4.431696
#
#
#  Epoch 0 complete	Loss: 4.813685
#
#
#  Epoch 0 complete	Loss: 4.799170
#
#
#  Epoch 0 complete	Loss: 2.820301
#
#
#  Epoch 0 complete	Loss: 2.306986
#
#
#  Epoch 0 complete	Loss: 4.026194
#
#
#  Epoch 0 complete	Loss: 7.538599
#
#
#  Epoch 0 complete	Loss: 7.112393
#
#
#  Epoch 0 complete	Loss: 2.367192
#
#
#  Epoch 0 complete	Loss: 10.219531
#
#
#  Epoch 0 complete	Loss: 4.443855
#
#
#  Epoch 0 complete	Loss: 10.383310
#
#
#  Epoch 0 complete	Loss: 7.918381
#
#
#  Epoch 0 complete	Loss: 10.040299
#
#
#  Epoch 0 complete	Loss: 2.485307
#
#
#  Epoch 0 complete	Loss: 10.721099
#
#
#  Epoch 0 complete	Loss: 2.959440
#
#
#  Epoch 0 complete	Loss: 4.201016
#
#
#  Epoch 0 complete	Loss: 3.953613
#
#
#  Epoch 0 complete	Loss: 4.334493
#
#
#  Epoch 0 complete	Loss: 8.467811
#
#
#  Epoch 0 complete	Loss: 10.962250
#
#
#  Epoch 0 complete	Loss: 3.865656
#
#
#  Epoch 0 complete	Loss: 2.194898
#
#
#  Epoch 0 complete	Loss: 7.403124
#
#
#  Epoch 0 complete	Loss: 3.035300
#
#
#  Epoch 0 complete	Loss: 1.536463
#
#
#  Epoch 0 complete	Loss: 2.797180
#
#
#  Epoch 0 complete	Loss: 11.199212
#
#
#  Epoch 0 complete	Loss: 4.345794
#
#
#  Epoch 0 complete	Loss: 4.554874
#
#
#  Epoch 0 complete	Loss: 4.390336
#
#
#  Epoch 0 complete	Loss: 4.779700
#
#
#  Epoch 0 complete	Loss: 4.269423
#
#
#  Epoch 0 complete	Loss: 4.517469
#
#
#  Epoch 0 complete	Loss: 4.361714
#
#
#  Epoch 0 complete	Loss: 4.530849
#
#
#  Epoch 0 complete	Loss: 6.351998
#
#
#  Epoch 0 complete	Loss: 2.481974
#
#
#  Epoch 0 complete	Loss: 11.123206
#
#
#  Epoch 0 complete	Loss: 2.736298
#
#
#  Epoch 0 complete	Loss: 5.365076
#
#
#  Epoch 0 complete	Loss: 2.660427
#
#
#  Epoch 0 complete	Loss: 1.521482
#
#
#  Epoch 0 complete	Loss: 2.587073
#
#
#  Epoch 0 complete	Loss: 3.028967
#
#
#  Epoch 0 complete	Loss: 3.516340
#
#
#  Epoch 0 complete	Loss: 11.261946
#
#
#  Epoch 0 complete	Loss: 7.638288
#
#
#  Epoch 0 complete	Loss: 2.532057
#
#
#  Epoch 0 complete	Loss: 4.202104
#
#
#  Epoch 0 complete	Loss: 2.552293
#
#
#  Epoch 0 complete	Loss: 3.107336
#
#
#  Epoch 0 complete	Loss: 3.722766
#
#
#  Epoch 0 complete	Loss: 2.327859
#
#
#  Epoch 0 complete	Loss: 3.774342
#
#
#  Epoch 0 complete	Loss: 2.753166
#
#
#  Epoch 0 complete	Loss: 2.945532
#
#
#  Epoch 0 complete	Loss: 2.797749
#
#
#  Epoch 0 complete	Loss: 2.363538
#
#
#  Epoch 0 complete	Loss: 8.389587
#
#
#  Epoch 0 complete	Loss: 2.878506
#
#
#  Epoch 0 complete	Loss: 2.414156
#
#
#  Epoch 0 complete	Loss: 3.374874
#
#
#  Epoch 0 complete	Loss: 2.441965
#
#
#  Epoch 0 complete	Loss: 3.007887
#
#
#  Epoch 0 complete	Loss: 10.237379
#
#
#  Epoch 0 complete	Loss: 2.796550
#
#
#  Epoch 0 complete	Loss: 3.170319
#
#
#  Epoch 0 complete	Loss: 3.637727
#
#
#  Epoch 0 complete	Loss: 4.172214
#
#
#  Epoch 0 complete	Loss: 2.814398
#
#
#  Epoch 0 complete	Loss: 2.681612
#
#
#  Epoch 0 complete	Loss: 3.093258
#
#
#  Epoch 0 complete	Loss: 3.186307
#
#
#  Epoch 0 complete	Loss: 3.257922
#
#
#  Epoch 0 complete	Loss: 2.363591
#
#
#  Epoch 0 complete	Loss: 9.944982
#
#
#  Epoch 0 complete	Loss: 2.341453
#
#
#  Epoch 0 complete	Loss: 2.950097
#
#
#  Epoch 0 complete	Loss: 3.616254
#
#
#  Epoch 0 complete	Loss: 4.093193
#
#
#  Epoch 0 complete	Loss: 2.499080
#
#
#  Epoch 0 complete	Loss: 4.180208
#
#
#  Epoch 0 complete	Loss: 3.276267
#
#
#  Epoch 0 complete	Loss: 3.649282
#
#
#  Epoch 0 complete	Loss: 9.288595
#
#
#  Epoch 0 complete	Loss: 2.700375
#
#
#  Epoch 0 complete	Loss: 7.586143
#
#
#  Epoch 0 complete	Loss: 9.601365
#
#
#  Epoch 0 complete	Loss: 2.682100
#
#
#  Epoch 0 complete	Loss: 3.709069
#
#
#  Epoch 0 complete	Loss: 2.533502
#
#
#  Epoch 0 complete	Loss: 3.421267
#
#
#  Epoch 0 complete	Loss: 2.381246
#
#
#  Epoch 0 complete	Loss: 3.058956
#
#
#  Epoch 0 complete	Loss: 7.095356
#
#
#  Epoch 0 complete	Loss: 4.041702
#
#
#  Epoch 0 complete	Loss: 3.807353
#
#
#  Epoch 0 complete	Loss: 8.333844
#
#
#  Epoch 0 complete	Loss: 3.917209
#
#
#  Epoch 0 complete	Loss: 3.565631
#
#
#  Epoch 0 complete	Loss: 2.798095
#
#
#  Epoch 0 complete	Loss: 4.105847
#
#
#  Epoch 0 complete	Loss: 2.651236
#
#
#  Epoch 0 complete	Loss: 7.842631
#
#
#  Epoch 0 complete	Loss: 3.637163
#
#
#  Epoch 0 complete	Loss: 2.953627
#
#
#  Epoch 0 complete	Loss: 4.126747
#
#
#  Epoch 0 complete	Loss: 2.784077
#
#
#  Epoch 0 complete	Loss: 2.554062
#
#
#  Epoch 0 complete	Loss: 3.494335
#
#
#  Epoch 0 complete	Loss: 3.875118
#
#
#  Epoch 0 complete	Loss: 3.970666
#
#
#  Epoch 0 complete	Loss: 2.638166
#
#
#  Epoch 0 complete	Loss: 2.732031
#
#
#  Epoch 0 complete	Loss: 2.969743
#
#
#  Epoch 0 complete	Loss: 2.743759
#
#
#  Epoch 0 complete	Loss: 3.776715
#
#
#  Epoch 0 complete	Loss: 3.802350
#
#
#  Epoch 0 complete	Loss: 3.774297
#
#
#  Epoch 0 complete	Loss: 3.583034
#
#
#  Epoch 0 complete	Loss: 2.557643
#
#
#  Epoch 0 complete	Loss: 2.598388
#
#
#  Epoch 0 complete	Loss: 5.822023
#
#
#  Epoch 0 complete	Loss: 5.705239
#
#
#  Epoch 0 complete	Loss: 2.697699
#
#
#  Epoch 0 complete	Loss: 4.722862
#
#
#  Epoch 0 complete	Loss: 3.227627
#
#
#  Epoch 0 complete	Loss: 2.602422
#
#
#  Epoch 0 complete	Loss: 4.328138
#
#
#  Epoch 0 complete	Loss: 4.278635
#
#
#  Epoch 0 complete	Loss: 3.054358
#
#
#  Epoch 0 complete	Loss: 2.586768
#
#
#  Epoch 0 complete	Loss: 4.476212
#
#
#  Epoch 0 complete	Loss: 2.250835
#
#
#  Epoch 0 complete	Loss: 2.461292
#
#
#  Epoch 0 complete	Loss: 4.438254
#
#
#  Epoch 0 complete	Loss: 2.752678
#
#
#  Epoch 0 complete	Loss: 4.062511
#
#
#  Epoch 0 complete	Loss: 2.267602
#
#
#  Epoch 0 complete	Loss: 3.865084
#
#
#  Epoch 0 complete	Loss: 3.289027
#
#
#  Epoch 0 complete	Loss: 3.242423
#
#
#  Epoch 0 complete	Loss: 2.608865
#
#
#  Epoch 0 complete	Loss: 2.995108
#
#
#  Epoch 0 complete	Loss: 2.544662
#
#
#  Epoch 0 complete	Loss: 3.894652
#
#
#  Epoch 0 complete	Loss: 2.432975
#
#
#  Epoch 0 complete	Loss: 3.256823
#
#
#  Epoch 0 complete	Loss: 3.682802
#
#
#  Epoch 0 complete	Loss: 3.607726
#
#
#  Epoch 0 complete	Loss: 2.478998
#
#
#  Epoch 0 complete	Loss: 2.355154
#
#
#  Epoch 0 complete	Loss: 2.495080
#
#
#  Epoch 0 complete	Loss: 2.729757
#
#
#  Epoch 0 complete	Loss: 4.021518
#
#
#  Epoch 0 complete	Loss: 3.235158
#
#
#  Epoch 0 complete	Loss: 4.152102
#
#
#  Epoch 0 complete	Loss: 2.644993
#
#
#  Epoch 0 complete	Loss: 3.548084
#
#
#  Epoch 0 complete	Loss: 4.010212
#
#
#  Epoch 0 complete	Loss: 2.664090
#
#
#  Epoch 0 complete	Loss: 3.233209
#
#
#  Epoch 0 complete	Loss: 3.379222
#
#
#  Epoch 0 complete	Loss: 3.206863
#
#
#  Epoch 0 complete	Loss: 3.050233
#
#
#  Epoch 0 complete	Loss: 3.181225
#
#
#  Epoch 0 complete	Loss: 3.593525
#
#
#  Epoch 0 complete	Loss: 3.184057
#
#
#  Epoch 0 complete	Loss: 3.198824
#
#
#  Epoch 0 complete	Loss: 3.891680
#
#
#  Epoch 0 complete	Loss: 3.233953
#
#
#  Epoch 0 complete	Loss: 3.192833
#
#
#  Epoch 0 complete	Loss: 3.011199
#
#
#  Epoch 0 complete	Loss: 4.121363
#
#
#  Epoch 0 complete	Loss: 2.653666
#
#
#  Epoch 0 complete	Loss: 3.089467
#
#
#  Epoch 0 complete	Loss: 3.625253
#
#
#  Epoch 0 complete	Loss: 2.815197
#
#
#  Epoch 0 complete	Loss: 2.700489
#
#
#  Epoch 0 complete	Loss: 3.827674
#
#
#  Epoch 0 complete	Loss: 2.195279
#
#
#  Epoch 0 complete	Loss: 3.282756
#
#
#  Epoch 0 complete	Loss: 2.917591
#
#
#  Epoch 0 complete	Loss: 4.684661
#
#
#  Epoch 0 complete	Loss: 4.745978
#
#
#  Epoch 0 complete	Loss: 3.928888
#
#
#  Epoch 0 complete	Loss: 2.038358
#
#
#  Epoch 0 complete	Loss: 3.845625
#
#
#  Epoch 0 complete	Loss: 3.578509
#
#
#  Epoch 0 complete	Loss: 1.956421
#
#
#  Epoch 0 complete	Loss: 3.603758
#
#
#  Epoch 0 complete	Loss: 5.218259
#
#
#  Epoch 0 complete	Loss: 3.887221
#
#
#  Epoch 0 complete	Loss: 3.798203
#
#
#  Epoch 0 complete	Loss: 2.871414
#
#
#  Epoch 0 complete	Loss: 3.906178
#
#
#  Epoch 0 complete	Loss: 1.758750
#
#
#  Epoch 0 complete	Loss: 2.735867
#
#
#  Epoch 0 complete	Loss: 2.830079
#
#
#  Epoch 0 complete	Loss: 3.712185
#
#
#  Epoch 0 complete	Loss: 3.694359
#
#
#  Epoch 0 complete	Loss: 4.346330
#
#
#  Epoch 0 complete	Loss: 4.441743
#
#
#  Epoch 0 complete	Loss: 3.759059
#
#
#  Epoch 0 complete	Loss: 3.493692
#
#
#  Epoch 0 complete	Loss: 1.701356
#
#
#  Epoch 0 complete	Loss: 5.062673
#
#
#  Epoch 0 complete	Loss: 3.362858
#
#
#  Epoch 0 complete	Loss: 2.633795
#
#
#  Epoch 0 complete	Loss: 3.881453
#
#
#  Epoch 0 complete	Loss: 5.565608
#
#
#  Epoch 0 complete	Loss: 4.719364
#
#
#  Epoch 0 complete	Loss: 4.880654
#
#
#  Epoch 0 complete	Loss: 2.550744
#
#
#  Epoch 0 complete	Loss: 5.073307
#
#
#  Epoch 0 complete	Loss: 4.779066
#
#
#  Epoch 0 complete	Loss: 3.446812
#
#
#  Epoch 0 complete	Loss: 3.254285
#
#
#  Epoch 0 complete	Loss: 3.456176
#
#
#  Epoch 0 complete	Loss: 3.375055
#
#
#  Epoch 0 complete	Loss: 2.224125
#
#
#  Epoch 0 complete	Loss: 4.494821
#
#
#  Epoch 0 complete	Loss: 3.356351
#
#
#  Epoch 0 complete	Loss: 2.556487
#
#
#  Epoch 0 complete	Loss: 3.523319
#
#
#  Epoch 0 complete	Loss: 2.491478
#
#
#  Epoch 0 complete	Loss: 2.542930
#
#
#  Epoch 0 complete	Loss: 3.215443
#
#
#  Epoch 0 complete	Loss: 3.643472
#
#
#  Epoch 0 complete	Loss: 2.734137
#
#
#  Epoch 0 complete	Loss: 5.180929
#
#
#  Epoch 0 complete	Loss: 5.421317
#
#
#  Epoch 0 complete	Loss: 2.234973
#
#
#  Epoch 0 complete	Loss: 3.143670
#
#
#  Epoch 0 complete	Loss: 5.046905
#
#
#  Epoch 0 complete	Loss: 2.935593
#
#
#  Epoch 0 complete	Loss: 4.669687
#
#
#  Epoch 0 complete	Loss: 2.434859
#
#
#  Epoch 0 complete	Loss: 2.303425
#
#
#  Epoch 0 complete	Loss: 2.058687
#
#
#  Epoch 0 complete	Loss: 5.375132
#
#
#  Epoch 0 complete	Loss: 2.260994
#
#
#  Epoch 0 complete	Loss: 5.378599
#
#
#  Epoch 0 complete	Loss: 4.209135
#
#
#  Epoch 0 complete	Loss: 4.146113
#
#
#  Epoch 0 complete	Loss: 4.054622
#
#
#  Epoch 0 complete	Loss: 2.931296
#
#
#  Epoch 0 complete	Loss: 5.290972
#
#
#  Epoch 0 complete	Loss: 2.525977
#
#
#  Epoch 0 complete	Loss: 3.181095
#
#
#  Epoch 0 complete	Loss: 3.829461
#
#
#  Epoch 0 complete	Loss: 4.693354
#
#
#  Epoch 0 complete	Loss: 5.084142
#
#
#  Epoch 0 complete	Loss: 4.729645
#
#
#  Epoch 0 complete	Loss: 3.607391
#
#
#  Epoch 0 complete	Loss: 2.955130
#
#
#  Epoch 0 complete	Loss: 2.941769
#
#
#  Epoch 0 complete	Loss: 2.198360
#
#
#  Epoch 0 complete	Loss: 1.435405
#
#
#  Epoch 0 complete	Loss: 4.646867
#
#
#  Epoch 0 complete	Loss: 4.577809
#
#
#  Epoch 0 complete	Loss: 3.508745
#
#
#  Epoch 0 complete	Loss: 4.148037
#
#
#  Epoch 0 complete	Loss: 2.252968
#
#
#  Epoch 0 complete	Loss: 2.989979
#
#
#  Epoch 0 complete	Loss: 3.157387
#
#
#  Epoch 0 complete	Loss: 2.864699
#
#
#  Epoch 0 complete	Loss: 4.712598
#
#
#  Epoch 0 complete	Loss: 3.903126
#
#
#  Epoch 0 complete	Loss: 4.685623
#
#
#  Epoch 0 complete	Loss: 4.642662
#
#
#  Epoch 0 complete	Loss: 3.554874
#
#
#  Epoch 0 complete	Loss: 3.917213
#
#
#  Epoch 0 complete	Loss: 3.413547
#
#
#  Epoch 0 complete	Loss: 3.602344
#
#
#  Epoch 0 complete	Loss: 3.474230
#
#
#  Epoch 0 complete	Loss: 3.919580
#
#
#  Epoch 0 complete	Loss: 4.312865
#
#
#  Epoch 0 complete	Loss: 4.202407
#
#
#  Epoch 0 complete	Loss: 2.265956
#
#
#  Epoch 0 complete	Loss: 4.222726
#
#
#  Epoch 0 complete	Loss: 3.614634
#
#
#  Epoch 0 complete	Loss: 4.400258
#
#
#  Epoch 0 complete	Loss: 2.888559
#
#
#  Epoch 0 complete	Loss: 2.799740
#
#
#  Epoch 0 complete	Loss: 3.480506
#
#
#  Epoch 0 complete	Loss: 2.859501
#
#
#  Epoch 0 complete	Loss: 3.840869
#
#
#  Epoch 0 complete	Loss: 3.922696
#
#
#  Epoch 0 complete	Loss: 2.665837
#
#
#  Epoch 0 complete	Loss: 3.607815
#
#
#  Epoch 0 complete	Loss: 3.882809
#
#
#  Epoch 0 complete	Loss: 3.553448
#
#
#  Epoch 0 complete	Loss: 3.923199
#
#
#  Epoch 0 complete	Loss: 2.364404
#
#
#  Epoch 0 complete	Loss: 3.913033
#
#
#  Epoch 0 complete	Loss: 2.167560
#
#
#  Epoch 0 complete	Loss: 3.404927
#
#
#  Epoch 0 complete	Loss: 3.412385
#
#
#  Epoch 0 complete	Loss: 3.047158
#
#
#  Epoch 0 complete	Loss: 3.389152
#
#
#  Epoch 0 complete	Loss: 2.851118
#
#
#  Epoch 0 complete	Loss: 2.938058
#
#
#  Epoch 0 complete	Loss: 2.447593
#
#
#  Epoch 0 complete	Loss: 5.473736
#
#
#  Epoch 0 complete	Loss: 4.407805
#
#
#  Epoch 0 complete	Loss: 5.584527
#
#
#  Epoch 0 complete	Loss: 3.193894
#
#
#  Epoch 0 complete	Loss: 4.624773
#
#
#  Epoch 0 complete	Loss: 4.013146
#
#
#  Epoch 0 complete	Loss: 2.073186
#
#
#  Epoch 0 complete	Loss: 5.143863
#
#
#  Epoch 0 complete	Loss: 4.825582
#
#
#  Epoch 0 complete	Loss: 2.198830
#
#
#  Epoch 0 complete	Loss: 4.852912
#
#
#  Epoch 0 complete	Loss: 5.766430
#
#
#  Epoch 0 complete	Loss: 3.213743
#
#
#  Epoch 0 complete	Loss: 3.378420
#
#
#  Epoch 0 complete	Loss: 5.897312
#
#
#  Epoch 0 complete	Loss: 5.919213
#
#
#  Epoch 0 complete	Loss: 5.107034
#
#
#  Epoch 0 complete	Loss: 1.960829
#
#
#  Epoch 0 complete	Loss: 5.452543
#
#
#  Epoch 0 complete	Loss: 2.419269
#
#
#  Epoch 0 complete	Loss: 6.032383
#
#
#  Epoch 0 complete	Loss: 5.154675
#
#
#  Epoch 0 complete	Loss: 2.438684
#
#
#  Epoch 0 complete	Loss: 3.749594
#
#
#  Epoch 0 complete	Loss: 5.393359
#
#
#  Epoch 0 complete	Loss: 2.481945
#
#
#  Epoch 0 complete	Loss: 4.112860
#
#
#  Epoch 0 complete	Loss: 2.912567
#
#
#  Epoch 0 complete	Loss: 5.196863
#
#
#  Epoch 0 complete	Loss: 4.842205
#
#
#  Epoch 0 complete	Loss: 3.741320
#
#
#  Epoch 0 complete	Loss: 5.275671
#
#
#  Epoch 0 complete	Loss: 2.483944
#
#
#  Epoch 0 complete	Loss: 2.893908
#
#
#  Epoch 0 complete	Loss: 4.789334
#
#
#  Epoch 0 complete	Loss: 2.882043
#
#
#  Epoch 0 complete	Loss: 2.955996
#
#
#  Epoch 0 complete	Loss: 3.543851
#
#
#  Epoch 0 complete	Loss: 4.668041
#
#
#  Epoch 0 complete	Loss: 5.344679
#
#
#  Epoch 0 complete	Loss: 2.061669
#
#
#  Epoch 0 complete	Loss: 3.315967
#
#
#  Epoch 0 complete	Loss: 2.492146
#
#
#  Epoch 0 complete	Loss: 5.135123
#
#
#  Epoch 0 complete	Loss: 4.198507
#
#
#  Epoch 0 complete	Loss: 4.098012
#
#
#  Epoch 0 complete	Loss: 2.383129
#
#
#  Epoch 0 complete	Loss: 4.026508
#
#
#  Epoch 0 complete	Loss: 3.941747
#
#
#  Epoch 0 complete	Loss: 2.655903
#
#
#  Epoch 0 complete	Loss: 3.844206
#
#
#  Epoch 0 complete	Loss: 2.837199
#
#
#  Epoch 0 complete	Loss: 3.627871
#
#
#  Epoch 0 complete	Loss: 2.469684
#
#
#  Epoch 0 complete	Loss: 2.428921
#
#
#  Epoch 0 complete	Loss: 2.455345
#
#
#  Epoch 0 complete	Loss: 3.353580
#
#
#  Epoch 0 complete	Loss: 3.268008
#
#
#  Epoch 0 complete	Loss: 4.441435
#
#
#  Epoch 0 complete	Loss: 2.370317
#
#
#  Epoch 0 complete	Loss: 3.450340
#
#
#  Epoch 0 complete	Loss: 5.135726
#
#
#  Epoch 0 complete	Loss: 3.620881
#
#
#  Epoch 0 complete	Loss: 4.146106
#
#
#  Epoch 0 complete	Loss: 4.004573
#
#
#  Epoch 0 complete	Loss: 2.823705
#
#
#  Epoch 0 complete	Loss: 4.005216
#
#
#  Epoch 0 complete	Loss: 4.014417
#
#
#  Epoch 0 complete	Loss: 2.784502
#
#
#  Epoch 0 complete	Loss: 5.049985
#
#
#  Epoch 0 complete	Loss: 3.447351
#
#
#  Epoch 0 complete	Loss: 2.899910
#
#
#  Epoch 0 complete	Loss: 3.327023
#
#
#  Epoch 0 complete	Loss: 3.438756
#
#
#  Epoch 0 complete	Loss: 4.833733
#
#
#  Epoch 0 complete	Loss: 2.367963
#
#
#  Epoch 0 complete	Loss: 3.752201
#
#
#  Epoch 0 complete	Loss: 2.306086
#
#
#  Epoch 0 complete	Loss: 5.424510
#
#
#  Epoch 0 complete	Loss: 5.544384
#
#
#  Epoch 0 complete	Loss: 3.412048
#
#
#  Epoch 0 complete	Loss: 2.155518
#
#
#  Epoch 0 complete	Loss: 3.259565
#
#
#  Epoch 0 complete	Loss: 3.196001
#
#
#  Epoch 0 complete	Loss: 3.661695
#
#
#  Epoch 0 complete	Loss: 3.297064
#
#
#  Epoch 0 complete	Loss: 3.289968
#
#
#  Epoch 0 complete	Loss: 1.934592
#
#
#  Epoch 0 complete	Loss: 3.319958
#
#
#  Epoch 0 complete	Loss: 3.224942
#
#
#  Epoch 0 complete	Loss: 3.268424
#
#
#  Epoch 0 complete	Loss: 6.652019
#
#
#  Epoch 0 complete	Loss: 3.727659
#
#
#  Epoch 0 complete	Loss: 3.669689
#
#
#  Epoch 0 complete	Loss: 4.426640
#
#
#  Epoch 0 complete	Loss: 4.289045
#
#
#  Epoch 0 complete	Loss: 3.919356
#
#
#  Epoch 0 complete	Loss: 2.683539
#
#
#  Epoch 0 complete	Loss: 3.095608
#
#
#  Epoch 0 complete	Loss: 4.242479
#
#
#  Epoch 0 complete	Loss: 3.087299
#
#
#  Epoch 0 complete	Loss: 2.474514
#
#
#  Epoch 0 complete	Loss: 3.194799
#
#
#  Epoch 0 complete	Loss: 3.178878
#
#
#  Epoch 0 complete	Loss: 3.491797
#
#
#  Epoch 0 complete	Loss: 3.150437
#
#
#  Epoch 0 complete	Loss: 2.971290
#
#
#  Epoch 0 complete	Loss: 3.372832
#
#
#  Epoch 0 complete	Loss: 2.215002
#
#
#  Epoch 0 complete	Loss: 3.352160
#
#
#  Epoch 0 complete	Loss: 5.280725
#
#
#  Epoch 0 complete	Loss: 2.891910
#
#
#  Epoch 0 complete	Loss: 5.277273
#
#
#  Epoch 0 complete	Loss: 3.837007
#
#
#  Epoch 0 complete	Loss: 2.619734
#
#
#  Epoch 0 complete	Loss: 2.981749
#
#
#  Epoch 0 complete	Loss: 2.732836
#
#
#  Epoch 0 complete	Loss: 4.690453
#
#
#  Epoch 0 complete	Loss: 2.050544
#
#
#  Epoch 0 complete	Loss: 2.867298
#
#
#  Epoch 0 complete	Loss: 5.095392
#
#
#  Epoch 0 complete	Loss: 5.788554
#
#
#  Epoch 0 complete	Loss: 3.558077
#
#
#  Epoch 0 complete	Loss: 3.491361
#
#
#  Epoch 0 complete	Loss: 5.845954
#
#
#  Epoch 0 complete	Loss: 5.237301
#
#
#  Epoch 0 complete	Loss: 2.406010
#
#
#  Epoch 0 complete	Loss: 3.489127
#
#
#  Epoch 0 complete	Loss: 2.950241
#
#
#  Epoch 0 complete	Loss: 9.613213
#
#
#  Epoch 0 complete	Loss: 3.300338
#
#
#  Epoch 0 complete	Loss: 5.296971
#
#
#  Epoch 0 complete	Loss: 5.294167
#
#
#  Epoch 0 complete	Loss: 3.341371
#
#
#  Epoch 0 complete	Loss: 3.190269
#
#
#  Epoch 0 complete	Loss: 2.878104
#
#
#  Epoch 0 complete	Loss: 9.574050
#
#
#  Epoch 0 complete	Loss: 3.210896
#
#
#  Epoch 0 complete	Loss: 5.865849
#
#
#  Epoch 0 complete	Loss: 2.707359
#
#
#  Epoch 0 complete	Loss: 4.769780
#
#
#  Epoch 0 complete	Loss: 2.643974
#
#
#  Epoch 0 complete	Loss: 2.827453
#
#
#  Epoch 0 complete	Loss: 2.623518
#
#
#  Epoch 0 complete	Loss: 5.503533
#
#
#  Epoch 0 complete	Loss: 2.777782
#
#
#  Epoch 0 complete	Loss: 8.913529
#
#
#  Epoch 0 complete	Loss: 2.947489
#
#
#  Epoch 0 complete	Loss: 2.887812
#
#
#  Epoch 0 complete	Loss: 2.777254
#
#
#  Epoch 0 complete	Loss: 2.900392
#
#
#  Epoch 0 complete	Loss: 9.282935
#
#
#  Epoch 0 complete	Loss: 8.516165
#
#
#  Epoch 0 complete	Loss: 2.518415
#
#
#  Epoch 0 complete	Loss: 5.058548
#
#
#  Epoch 0 complete	Loss: 8.339437
#
#
#  Epoch 0 complete	Loss: 4.475837
#
#
#  Epoch 0 complete	Loss: 2.615253
#
#
#  Epoch 0 complete	Loss: 4.842662
#
#
#  Epoch 0 complete	Loss: 4.144527
#
#
#  Epoch 0 complete	Loss: 2.554394
#
#
#  Epoch 0 complete	Loss: 2.162411
#
#
#  Epoch 0 complete	Loss: 4.628605
#
#
#  Epoch 0 complete	Loss: 4.317754
#
#
#  Epoch 0 complete	Loss: 3.948251
#
#
#  Epoch 0 complete	Loss: 3.278969
#
#
#  Epoch 0 complete	Loss: 3.166075
#
#
#  Epoch 0 complete	Loss: 3.430081
#
#
#  Epoch 0 complete	Loss: 3.764918
#
#
#  Epoch 0 complete	Loss: 3.902821
#
#
#  Epoch 0 complete	Loss: 2.345726
#
#
#  Epoch 0 complete	Loss: 2.308540
#
#
#  Epoch 0 complete	Loss: 4.047723
#
#
#  Epoch 0 complete	Loss: 3.715027
#
#
#  Epoch 0 complete	Loss: 3.383391
#
#
#  Epoch 0 complete	Loss: 3.571727
#
#
#  Epoch 0 complete	Loss: 3.653671
#
#
#  Epoch 0 complete	Loss: 2.431965
#
#
#  Epoch 0 complete	Loss: 6.124413
#
#
#  Epoch 0 complete	Loss: 3.721779
#
#
#  Epoch 0 complete	Loss: 3.358622
#
#
#  Epoch 0 complete	Loss: 3.595125
#
#
#  Epoch 0 complete	Loss: 4.723332
#
#
#  Epoch 0 complete	Loss: 3.569499
#
#
#  Epoch 0 complete	Loss: 4.402263
#
#
#  Epoch 0 complete	Loss: 2.213332
#
#
#  Epoch 0 complete	Loss: 3.892277
#
#
#  Epoch 0 complete	Loss: 2.988354
#
#
#  Epoch 0 complete	Loss: 3.933032
#
#
#  Epoch 0 complete	Loss: 3.180270
#
#
#  Epoch 0 complete	Loss: 3.026268
#
#
#  Epoch 0 complete	Loss: 4.776254
#
#
#  Epoch 0 complete	Loss: 3.111557
#
#
#  Epoch 0 complete	Loss: 4.876981
#
#
#  Epoch 0 complete	Loss: 2.789667
#
#
#  Epoch 0 complete	Loss: 4.063921
#
#
#  Epoch 0 complete	Loss: 3.956855
#
#
#  Epoch 0 complete	Loss: 4.032820
#
#
#  Epoch 0 complete	Loss: 4.133229
#
#
#  Epoch 0 complete	Loss: 2.121471
#
#
#  Epoch 0 complete	Loss: 5.944255
#
#
#  Epoch 0 complete	Loss: 3.659724
#
#
#  Epoch 0 complete	Loss: 3.995135
#
#
#  Epoch 0 complete	Loss: 2.849726
#
#
#  Epoch 0 complete	Loss: 3.819544
#
#
#  Epoch 0 complete	Loss: 4.108188
#
#
#  Epoch 0 complete	Loss: 3.933618
#
#
#  Epoch 0 complete	Loss: 6.406737
#
#
#  Epoch 0 complete	Loss: 2.817095
#
#
#  Epoch 0 complete	Loss: 3.925687
#
#
#  Epoch 0 complete	Loss: 4.087887
#
#
#  Epoch 0 complete	Loss: 2.747415
#
#
#  Epoch 0 complete	Loss: 4.237620
#
#
#  Epoch 0 complete	Loss: 3.723162
#
#
#  Epoch 0 complete	Loss: 4.063077
#
#
#  Epoch 0 complete	Loss: 6.889373
#
#
#  Epoch 0 complete	Loss: 3.806010
#
#
#  Epoch 0 complete	Loss: 4.103185
#
#
#  Epoch 0 complete	Loss: 7.011270
#
#
#  Epoch 0 complete	Loss: 4.019538
#
#
#  Epoch 0 complete	Loss: 3.188816
#
#
#  Epoch 0 complete	Loss: 6.479158
#
#
#  Epoch 0 complete	Loss: 4.016327
#
#
#  Epoch 0 complete	Loss: 2.711660
#
#
#  Epoch 0 complete	Loss: 6.275332
#
#
#  Epoch 0 complete	Loss: 3.043798
#
#
#  Epoch 0 complete	Loss: 4.248083
#
#
#  Epoch 0 complete	Loss: 7.172640
#
#
#  Epoch 0 complete	Loss: 3.124702
#
#
#  Epoch 0 complete	Loss: 2.651922
#
#
#  Epoch 0 complete	Loss: 2.725691
#
#
#  Epoch 0 complete	Loss: 4.036066
#
#
#  Epoch 0 complete	Loss: 2.941099
#
#
#  Epoch 0 complete	Loss: 2.961217
#
#
#  Epoch 0 complete	Loss: 2.900121
#
#
#  Epoch 0 complete	Loss: 2.570057
#
#
#  Epoch 0 complete	Loss: 2.642649
#
#
#  Epoch 0 complete	Loss: 4.181701
#
#
#  Epoch 0 complete	Loss: 4.519393
#
#
#  Epoch 0 complete	Loss: 3.195185
#
#
#  Epoch 0 complete	Loss: 2.312742
#
#
#  Epoch 0 complete	Loss: 6.162575
#
#
#  Epoch 0 complete	Loss: 3.761886
#
#
#  Epoch 0 complete	Loss: 4.259172
#
#
#  Epoch 0 complete	Loss: 7.202200
#
#
#  Epoch 0 complete	Loss: 2.664937
#
#
#  Epoch 0 complete	Loss: 6.085466
#
#
#  Epoch 0 complete	Loss: 3.053823
#
#
#  Epoch 0 complete	Loss: 6.563659
#
#
#  Epoch 0 complete	Loss: 2.627911
#
#
#  Epoch 0 complete	Loss: 4.128561
#
#
#  Epoch 0 complete	Loss: 2.790434
#
#
#  Epoch 0 complete	Loss: 2.914699
#
#
#  Epoch 0 complete	Loss: 2.936665
#
#
#  Epoch 0 complete	Loss: 3.961548
#
#
#  Epoch 0 complete	Loss: 3.148020
#
#
#  Epoch 0 complete	Loss: 5.492365
#
#
#  Epoch 0 complete	Loss: 5.433361
#
#
#  Epoch 0 complete	Loss: 2.394642
#
#
#  Epoch 0 complete	Loss: 2.279132
#
#
#  Epoch 0 complete	Loss: 3.289772
#
#
#  Epoch 0 complete	Loss: 3.247235
#
#
#  Epoch 0 complete	Loss: 2.367730
#
#
#  Epoch 0 complete	Loss: 2.791619
#
#
#  Epoch 0 complete	Loss: 3.340474
#
#
#  Epoch 0 complete	Loss: 3.749906
#
#
#  Epoch 0 complete	Loss: 3.307920
#
#
#  Epoch 0 complete	Loss: 3.498743
#
#
#  Epoch 0 complete	Loss: 5.424540
#
#
#  Epoch 0 complete	Loss: 3.560276
#
#
#  Epoch 0 complete	Loss: 3.042262
#
#
#  Epoch 0 complete	Loss: 2.277618
#
#
#  Epoch 0 complete	Loss: 3.609192
#
#
#  Epoch 0 complete	Loss: 5.092831
#
#
#  Epoch 0 complete	Loss: 3.701496
#
#
#  Epoch 0 complete	Loss: 3.219562
#
#
#  Epoch 0 complete	Loss: 3.470151
#
#
#  Epoch 0 complete	Loss: 3.702763
#
#
#  Epoch 0 complete	Loss: 2.290369
#
#
#  Epoch 0 complete	Loss: 3.710727
#
#
#  Epoch 0 complete	Loss: 3.747632
#
#
#  Epoch 0 complete	Loss: 4.007049
#
#
#  Epoch 0 complete	Loss: 3.805521
#
#
#  Epoch 0 complete	Loss: 3.940111
#
#
#  Epoch 0 complete	Loss: 2.816826
#
#
#  Epoch 0 complete	Loss: 2.366695
#
#
#  Epoch 0 complete	Loss: 1.821132
#
#
#  Epoch 0 complete	Loss: 4.163202
#
#
#  Epoch 0 complete	Loss: 3.989650
#
#
#  Epoch 0 complete	Loss: 2.839331
#
#
#  Epoch 0 complete	Loss: 2.431607
#
#
#  Epoch 0 complete	Loss: 3.345913
#
#
#  Epoch 0 complete	Loss: 3.751150
#
#
#  Epoch 0 complete	Loss: 3.201570
#
#
#  Epoch 0 complete	Loss: 3.916624
#
#
#  Epoch 0 complete	Loss: 3.720022
#
#
#  Epoch 0 complete	Loss: 5.446888
#
#
#  Epoch 0 complete	Loss: 4.473957
#
#
#  Epoch 0 complete	Loss: 2.646547
#
#
#  Epoch 0 complete	Loss: 4.204545
#
#
#  Epoch 0 complete	Loss: 3.379202
#
#
#  Epoch 0 complete	Loss: 4.117288
#
#
#  Epoch 0 complete	Loss: 2.759648
#
#
#  Epoch 0 complete	Loss: 2.643293
#
#
#  Epoch 0 complete	Loss: 3.137229
#
#
#  Epoch 0 complete	Loss: 4.169898
#
#
#  Epoch 0 complete	Loss: 4.311431
#
#
#  Epoch 0 complete	Loss: 3.039448
#
#
#  Epoch 0 complete	Loss: 4.776824
#
#
#  Epoch 0 complete	Loss: 4.400188
#
#
#  Epoch 0 complete	Loss: 3.171828
#
#
#  Epoch 0 complete	Loss: 3.164430
#
#
#  Epoch 0 complete	Loss: 4.648165
#
#
#  Epoch 0 complete	Loss: 5.221463
#
#
#  Epoch 0 complete	Loss: 2.731857
#
#
#  Epoch 0 complete	Loss: 2.972232
#
#
#  Epoch 0 complete	Loss: 2.516274
#
#
#  Epoch 0 complete	Loss: 4.795058
#
#
#  Epoch 0 complete	Loss: 4.675043
#
#
#  Epoch 0 complete	Loss: 4.862387
#
#
#  Epoch 0 complete	Loss: 5.402129
#
#
#  Epoch 0 complete	Loss: 4.373218
#
#
#  Epoch 0 complete	Loss: 2.125512
#
#
#  Epoch 0 complete	Loss: 4.656823
#
#
#  Epoch 0 complete	Loss: 4.709363
#
#
#  Epoch 0 complete	Loss: 4.393093
#
#
#  Epoch 0 complete	Loss: 3.222841
#
#
#  Epoch 0 complete	Loss: 3.688635
#
#
#  Epoch 0 complete	Loss: 3.098427
#
#
#  Epoch 0 complete	Loss: 2.310759
#
#
#  Epoch 0 complete	Loss: 3.607828
#
#
#  Epoch 0 complete	Loss: 4.742521
#
#
#  Epoch 0 complete	Loss: 4.305977
#
#
#  Epoch 0 complete	Loss: 4.536388
#
#
#  Epoch 0 complete	Loss: 2.704014
#
#
#  Epoch 0 complete	Loss: 4.233837
#
#
#  Epoch 0 complete	Loss: 2.660786
#
#
#  Epoch 0 complete	Loss: 4.424155
#
#
#  Epoch 0 complete	Loss: 5.421777
#
#
#  Epoch 0 complete	Loss: 4.501626
#
#
#  Epoch 0 complete	Loss: 2.348612
#
#
#  Epoch 0 complete	Loss: 4.219735
#
#
#  Epoch 0 complete	Loss: 4.339348
#
#
#  Epoch 0 complete	Loss: 4.068299
#
#
#  Epoch 0 complete	Loss: 4.557210
#
#
#  Epoch 0 complete	Loss: 2.025279
#
#
#  Epoch 0 complete	Loss: 2.692140
#
#
#  Epoch 0 complete	Loss: 1.934993
#
#
#  Epoch 0 complete	Loss: 4.473542
#
#
#  Epoch 0 complete	Loss: 3.557664
#
#
#  Epoch 0 complete	Loss: 5.689523
#
#
#  Epoch 0 complete	Loss: 1.377972
#
#
#  Epoch 0 complete	Loss: 5.738218
#
#
#  Epoch 0 complete	Loss: 1.273623
#
#
#  Epoch 0 complete	Loss: 3.271276
#
#
#  Epoch 0 complete	Loss: 5.613779
#
#
#  Epoch 0 complete	Loss: 4.002618
#
#
#  Epoch 0 complete	Loss: 3.701936
#
#
#  Epoch 0 complete	Loss: 3.961275
#
#
#  Epoch 0 complete	Loss: 3.129816
#
#
#  Epoch 0 complete	Loss: 5.137998
#
#
#  Epoch 0 complete	Loss: 1.319624
#
#
#  Epoch 0 complete	Loss: 4.650389
#
#
#  Epoch 0 complete	Loss: 4.458150
#
#
#  Epoch 0 complete	Loss: 3.680344
#
#
#  Epoch 0 complete	Loss: 4.322652
#
#
#  Epoch 0 complete	Loss: 4.047874
#
#
#  Epoch 0 complete	Loss: 1.901826
#
#
#  Epoch 0 complete	Loss: 3.609832
#
#
#  Epoch 0 complete	Loss: 4.287986
#
#
#  Epoch 0 complete	Loss: 5.084055
#
#
#  Epoch 0 complete	Loss: 4.308091
#
#
#  Epoch 0 complete	Loss: 4.515328
#
#
#  Epoch 0 complete	Loss: 4.957775
#
#
#  Epoch 0 complete	Loss: 4.719903
#
#
#  Epoch 0 complete	Loss: 3.061191
#
#
#  Epoch 0 complete	Loss: 4.151574
#
#
#  Epoch 0 complete	Loss: 2.243238
#
#
#  Epoch 0 complete	Loss: 1.561078
#
#
#  Epoch 0 complete	Loss: 4.698040
#
#
#  Epoch 0 complete	Loss: 2.667726
#
#
#  Epoch 0 complete	Loss: 4.510815
#
#
#  Epoch 0 complete	Loss: 5.253508
#
#
#  Epoch 0 complete	Loss: 1.854701
#
#
#  Epoch 0 complete	Loss: 4.364089
#
#
#  Epoch 0 complete	Loss: 2.558720
#
#
#  Epoch 0 complete	Loss: 3.928679
#
#
#  Epoch 0 complete	Loss: 2.487466
#
#
#  Epoch 0 complete	Loss: 3.911341
#
#
#  Epoch 0 complete	Loss: 2.281926
#
#
#  Epoch 0 complete	Loss: 3.944345
#
#
#  Epoch 0 complete	Loss: 2.854677
#
#
#  Epoch 0 complete	Loss: 3.221801
#
#
#  Epoch 0 complete	Loss: 3.987965
#
#
#  Epoch 0 complete	Loss: 2.066499
#
#
#  Epoch 0 complete	Loss: 1.935019
#
#
#  Epoch 0 complete	Loss: 4.894233
#
#
#  Epoch 0 complete	Loss: 4.031597
#
#
#  Epoch 0 complete	Loss: 2.771080
#
#
#  Epoch 0 complete	Loss: 4.110742
#
#
#  Epoch 0 complete	Loss: 5.147362
#
#
#  Epoch 0 complete	Loss: 4.229239
#
#
#  Epoch 0 complete	Loss: 2.450838
#
#
#  Epoch 0 complete	Loss: 2.580522
#
#
#  Epoch 0 complete	Loss: 1.698447
#
#
#  Epoch 0 complete	Loss: 6.441368
#
#
#  Epoch 0 complete	Loss: 2.673267
#
#
#  Epoch 0 complete	Loss: 3.001495
#
#
#  Epoch 0 complete	Loss: 4.352925
#
#
#  Epoch 0 complete	Loss: 6.654280
#
#
#  Epoch 0 complete	Loss: 5.396258
#
#
#  Epoch 0 complete	Loss: 5.401253
#
#
#  Epoch 0 complete	Loss: 1.702073
#
#
#  Epoch 0 complete	Loss: 7.490896
#
#
#  Epoch 0 complete	Loss: 2.985840
#
#
#  Epoch 0 complete	Loss: 3.005228
#
#
#  Epoch 0 complete	Loss: 2.582109
#
#
#  Epoch 0 complete	Loss: 1.698218
#
#
#  Epoch 0 complete	Loss: 3.195210
#
#
#  Epoch 0 complete	Loss: 4.291015
#
#
#  Epoch 0 complete	Loss: 7.672996
#
#
#  Epoch 0 complete	Loss: 8.246108
#
#
#  Epoch 0 complete	Loss: 7.694757
#
#
#  Epoch 0 complete	Loss: 6.053472
#
#
#  Epoch 0 complete	Loss: 7.638868
#
#
#  Epoch 0 complete	Loss: 1.888910
#
#
#  Epoch 0 complete	Loss: 3.071820
#
#
#  Epoch 0 complete	Loss: 3.162098
#
#
#  Epoch 0 complete	Loss: 3.306482
#
#
#  Epoch 0 complete	Loss: 7.351048
#
#
#  Epoch 0 complete	Loss: 3.081535
#
#
#  Epoch 0 complete	Loss: 7.272318
#
#
#  Epoch 0 complete	Loss: 3.944567
#
#
#  Epoch 0 complete	Loss: 2.932614
#
#
#  Epoch 0 complete	Loss: 6.932114
#
#
#  Epoch 0 complete	Loss: 4.950910
#
#
#  Epoch 0 complete	Loss: 3.842612
#
#
#  Epoch 0 complete	Loss: 4.916195
#
#
#  Epoch 0 complete	Loss: 2.728842
#
#
#  Epoch 0 complete	Loss: 4.822480
#
#
#  Epoch 0 complete	Loss: 3.679380
#
#
#  Epoch 0 complete	Loss: 3.348121
#
#
#  Epoch 0 complete	Loss: 6.582618
#
#
#  Epoch 0 complete	Loss: 2.488764
#
#
#  Epoch 0 complete	Loss: 7.255676
#
#
#  Epoch 0 complete	Loss: 2.497421
#
#
#  Epoch 0 complete	Loss: 3.493966
#
#
#  Epoch 0 complete	Loss: 2.918152
#
#
#  Epoch 0 complete	Loss: 4.294856
#
#
#  Epoch 0 complete	Loss: 3.095107
#
#
#  Epoch 0 complete	Loss: 6.318448
#
#
#  Epoch 0 complete	Loss: 6.210535
#
#
#  Epoch 0 complete	Loss: 2.821562
#
#
#  Epoch 0 complete	Loss: 2.907112
#
#
#  Epoch 0 complete	Loss: 2.953848
#
#
#  Epoch 0 complete	Loss: 5.974647
#
#
#  Epoch 0 complete	Loss: 2.831997
#
#
#  Epoch 0 complete	Loss: 5.824553
#
#
#  Epoch 0 complete	Loss: 3.125644
#
#
#  Epoch 0 complete	Loss: 5.879322
#
#
#  Epoch 0 complete	Loss: 5.548677
#
#
#  Epoch 0 complete	Loss: 3.361827
#
#
#  Epoch 0 complete	Loss: 3.418080
#
#
#  Epoch 0 complete	Loss: 3.402255
#
#
#  Epoch 0 complete	Loss: 5.226788
#
#
#  Epoch 0 complete	Loss: 3.624750
#
#
#  Epoch 0 complete	Loss: 3.287766
#
#
#  Epoch 0 complete	Loss: 5.532877
#
#
#  Epoch 0 complete	Loss: 5.130593
#
#
#  Epoch 0 complete	Loss: 5.478572
#
#
#  Epoch 0 complete	Loss: 3.679081
#
#
#  Epoch 0 complete	Loss: 3.796895
#
#
#  Epoch 0 complete	Loss: 4.782010
#
#
#  Epoch 0 complete	Loss: 2.904620
#
#
#  Epoch 0 complete	Loss: 3.814540
#
#
#  Epoch 0 complete	Loss: 3.937297
#
#
#  Epoch 0 complete	Loss: 2.782538
#
#
#  Epoch 0 complete	Loss: 4.267807
#
#
#  Epoch 0 complete	Loss: 4.041729
#
#
#  Epoch 0 complete	Loss: 2.789888
#
#
#  Epoch 0 complete	Loss: 4.933677
#
#
#  Epoch 0 complete	Loss: 5.010346
#
#
#  Epoch 0 complete	Loss: 3.864675
#
#
#  Epoch 0 complete	Loss: 4.720110
#
#
#  Epoch 0 complete	Loss: 3.045929
#
#
#  Epoch 0 complete	Loss: 4.394951
#
#
#  Epoch 0 complete	Loss: 4.640592
#
#
#  Epoch 0 complete	Loss: 4.615036
#
#
#  Epoch 0 complete	Loss: 2.653182
#
#
#  Epoch 0 complete	Loss: 4.518677
#
#
#  Epoch 0 complete	Loss: 3.534507
#
#
#  Epoch 0 complete	Loss: 4.835730
#
#
#  Epoch 0 complete	Loss: 4.587001
#
#
#  Epoch 0 complete	Loss: 3.893573
#
#
#  Epoch 0 complete	Loss: 2.854162
#
#
#  Epoch 0 complete	Loss: 3.830941
#
#
#  Epoch 0 complete	Loss: 3.666675
#
#
#  Epoch 0 complete	Loss: 4.955770
#
#
#  Epoch 0 complete	Loss: 5.204296
#
#
#  Epoch 0 complete	Loss: 3.388493
#
#
#  Epoch 0 complete	Loss: 3.835129
#
#
#  Epoch 0 complete	Loss: 4.038085
#
#
#  Epoch 0 complete	Loss: 2.325935
#
#
#  Epoch 0 complete	Loss: 2.228150
#
#
#  Epoch 0 complete	Loss: 2.373516
#
#
#  Epoch 0 complete	Loss: 2.138724
#
#
#  Epoch 0 complete	Loss: 5.641653
#
#
#  Epoch 0 complete	Loss: 5.615168
#
#
#  Epoch 0 complete	Loss: 5.671380
#
#
#  Epoch 0 complete	Loss: 4.865676
#
#
#  Epoch 0 complete	Loss: 3.044152
#
#
#  Epoch 0 complete	Loss: 2.013192
#
#
#  Epoch 0 complete	Loss: 5.726451
#
#
#  Epoch 0 complete	Loss: 2.853481
#
#
#  Epoch 0 complete	Loss: 1.852187
#
#
#  Epoch 0 complete	Loss: 4.255001
#
#
#  Epoch 0 complete	Loss: 2.974203
#
#
#  Epoch 0 complete	Loss: 6.041387
#
#
#  Epoch 0 complete	Loss: 2.645646
#
#
#  Epoch 0 complete	Loss: 1.861864
#
#
#  Epoch 0 complete	Loss: 3.343346
#
#
#  Epoch 0 complete	Loss: 2.836743
#
#
#  Epoch 0 complete	Loss: 3.147275
#
#
#  Epoch 0 complete	Loss: 2.659474
#
#
#  Epoch 0 complete	Loss: 6.950519
#
#
#  Epoch 0 complete	Loss: 1.851507
#
#
#  Epoch 0 complete	Loss: 1.851132
#
#
#  Epoch 0 complete	Loss: 3.934740
#
#
#  Epoch 0 complete	Loss: 5.050456
#
#
#  Epoch 0 complete	Loss: 5.212410
#
#
#  Epoch 0 complete	Loss: 3.605464
#
#
#  Epoch 0 complete	Loss: 3.203528
#
#
#  Epoch 0 complete	Loss: 3.382146
#
#
#  Epoch 0 complete	Loss: 6.185886
#
#
#  Epoch 0 complete	Loss: 6.888251
#
#
#  Epoch 0 complete	Loss: 4.879257
#
#
#  Epoch 0 complete	Loss: 1.893470
#
#
#  Epoch 0 complete	Loss: 2.878478
#
#
#  Epoch 0 complete	Loss: 4.800723
#
#
#  Epoch 0 complete	Loss: 5.768706
#
#
#  Epoch 0 complete	Loss: 5.930287
#
#
#  Epoch 0 complete	Loss: 5.673937
#
#
#  Epoch 0 complete	Loss: 2.723209
#
#
#  Epoch 0 complete	Loss: 2.071648
#
#
#  Epoch 0 complete	Loss: 2.677815
#
#
#  Epoch 0 complete	Loss: 2.785909
#
#
#  Epoch 0 complete	Loss: 2.440161
#
#
#  Epoch 0 complete	Loss: 2.328793
#
#
#  Epoch 0 complete	Loss: 5.120433
#
#
#  Epoch 0 complete	Loss: 4.988170
#
#
#  Epoch 0 complete	Loss: 2.224251
#
#
#  Epoch 0 complete	Loss: 1.885588
#
#
#  Epoch 0 complete	Loss: 3.216572
#
#
#  Epoch 0 complete	Loss: 2.045301
#
#
#  Epoch 0 complete	Loss: 3.173482
#
#
#  Epoch 0 complete	Loss: 3.042533
#
#
#  Epoch 0 complete	Loss: 4.025965
#
#
#  Epoch 0 complete	Loss: 4.624508
#
#
#  Epoch 0 complete	Loss: 4.321304
#
#
#  Epoch 0 complete	Loss: 3.315546
#
#
#  Epoch 0 complete	Loss: 3.380019
#
#
#  Epoch 0 complete	Loss: 5.213580
#
#
#  Epoch 0 complete	Loss: 3.617952
#
#
#  Epoch 0 complete	Loss: 3.577869
#
#
#  Epoch 0 complete	Loss: 1.719628
#
#
#  Epoch 0 complete	Loss: 3.931841
#
#
#  Epoch 0 complete	Loss: 2.896199
#
#
#  Epoch 0 complete	Loss: 4.026887
#
#
#  Epoch 0 complete	Loss: 1.723555
#
#
#  Epoch 0 complete	Loss: 3.388822
#
#
#  Epoch 0 complete	Loss: 4.691413
#
#
#  Epoch 0 complete	Loss: 1.740234
#
#
#  Epoch 0 complete	Loss: 4.323742
#
#
#  Epoch 0 complete	Loss: 4.894396
#
#
#  Epoch 0 complete	Loss: 2.340325
#
#
#  Epoch 0 complete	Loss: 3.200334
#
#
#  Epoch 0 complete	Loss: 3.873634
#
#
#  Epoch 0 complete	Loss: 3.078933
#
#
#  Epoch 0 complete	Loss: 4.610800
#
#
#  Epoch 0 complete	Loss: 5.315868
#
#
#  Epoch 0 complete	Loss: 4.892629
#
#
#  Epoch 0 complete	Loss: 2.246983
#
#
#  Epoch 0 complete	Loss: 4.712059
#
#
#  Epoch 0 complete	Loss: 4.755026
#
#
#  Epoch 0 complete	Loss: 3.273927
#
#
#  Epoch 0 complete	Loss: 5.947420
#
#
#  Epoch 0 complete	Loss: 3.465022
#
#
#  Epoch 0 complete	Loss: 4.774872
#
#
#  Epoch 0 complete	Loss: 4.173232
#
#
#  Epoch 0 complete	Loss: 3.506251
#
#
#  Epoch 0 complete	Loss: 4.525944
#
#
#  Epoch 0 complete	Loss: 4.272825
#
#
#  Epoch 0 complete	Loss: 4.299393
#
#
#  Epoch 0 complete	Loss: 2.726985
#
#
#  Epoch 0 complete	Loss: 2.172629
#
#
#  Epoch 0 complete	Loss: 3.013927
#
#
#  Epoch 0 complete	Loss: 6.620637
#
#
#  Epoch 0 complete	Loss: 2.345085
#
#
#  Epoch 0 complete	Loss: 6.189258
#
#
#  Epoch 0 complete	Loss: 6.754930
#
#
#  Epoch 0 complete	Loss: 1.982257
#
#
#  Epoch 0 complete	Loss: 2.464355
#
#
#  Epoch 0 complete	Loss: 6.506018
#
#
#  Epoch 0 complete	Loss: 6.637160
#
#
#  Epoch 0 complete	Loss: 6.628861
#
#
#  Epoch 0 complete	Loss: 2.549341
#
#
#  Epoch 0 complete	Loss: 7.260388
#
#
#  Epoch 0 complete	Loss: 7.143993
#
#
#  Epoch 0 complete	Loss: 3.135171
#
#
#  Epoch 0 complete	Loss: 6.326565
#
#
#  Epoch 0 complete	Loss: 3.192212
#
#
#  Epoch 0 complete	Loss: 3.305093
#
#
#  Epoch 0 complete	Loss: 2.744923
#
#
#  Epoch 0 complete	Loss: 6.977741
#
#
#  Epoch 0 complete	Loss: 7.045089
#
#
#  Epoch 0 complete	Loss: 2.166803
#
#
#  Epoch 0 complete	Loss: 7.099337
#
#
#  Epoch 0 complete	Loss: 7.104083
#
#
#  Epoch 0 complete	Loss: 2.953395
#
#
#  Epoch 0 complete	Loss: 6.756763
#
#
#  Epoch 0 complete	Loss: 2.792870
#
#
#  Epoch 0 complete	Loss: 2.977489
#
#
#  Epoch 0 complete	Loss: 2.840262
#
#
#  Epoch 0 complete	Loss: 5.063585
#
#
#  Epoch 0 complete	Loss: 7.506947
#
#
#  Epoch 0 complete	Loss: 2.871741
#
#
#  Epoch 0 complete	Loss: 2.328217
#
#
#  Epoch 0 complete	Loss: 3.121016
#
#
#  Epoch 0 complete	Loss: 3.102703
#
#
#  Epoch 0 complete	Loss: 3.337325
#
#
#  Epoch 0 complete	Loss: 2.793670
#
#
#  Epoch 0 complete	Loss: 7.111679
#
#
#  Epoch 0 complete	Loss: 2.611552
#
#
#  Epoch 0 complete	Loss: 2.735621
#
#
#  Epoch 0 complete	Loss: 2.771557
#
#
#  Epoch 0 complete	Loss: 2.750153
#
#
#  Epoch 0 complete	Loss: 2.940357
#
#
#  Epoch 0 complete	Loss: 2.923293
#
#
#  Epoch 0 complete	Loss: 2.656352
#
#
#  Epoch 0 complete	Loss: 3.251710
#
#
#  Epoch 0 complete	Loss: 7.094053
#
#
#  Epoch 0 complete	Loss: 7.434806
#
#
#  Epoch 0 complete	Loss: 7.409772
#
#
#  Epoch 0 complete	Loss: 3.151178
#
#
#  Epoch 0 complete	Loss: 5.146863
#
#
#  Epoch 0 complete	Loss: 7.312727
#
#
#  Epoch 0 complete	Loss: 2.498571
#
#
#  Epoch 0 complete	Loss: 5.239603
#
#
#  Epoch 0 complete	Loss: 2.864708
#
#
#  Epoch 0 complete	Loss: 2.404763
#
#
#  Epoch 0 complete	Loss: 2.776417
#
#
#  Epoch 0 complete	Loss: 3.437917
#
#
#  Epoch 0 complete	Loss: 2.950596
#
#
#  Epoch 0 complete	Loss: 3.032168
#
#
#  Epoch 0 complete	Loss: 7.296556
#
#
#  Epoch 0 complete	Loss: 2.858251
#
#
#  Epoch 0 complete	Loss: 2.872526
#
#
#  Epoch 0 complete	Loss: 6.667612
#
#
#  Epoch 0 complete	Loss: 2.234954
#
#
#  Epoch 0 complete	Loss: 2.825629
#
#
#  Epoch 0 complete	Loss: 4.786233
#
#
#  Epoch 0 complete	Loss: 6.223323
#
#
#  Epoch 0 complete	Loss: 6.363381
#
#
#  Epoch 0 complete	Loss: 2.951724
#
#
#  Epoch 0 complete	Loss: 6.230095
#
#
#  Epoch 0 complete	Loss: 2.394592
#
#
#  Epoch 0 complete	Loss: 2.402717
#
#
#  Epoch 0 complete	Loss: 2.189619
#
#
#  Epoch 0 complete	Loss: 4.001678
#
#
#  Epoch 0 complete	Loss: 2.864856
#
#
#  Epoch 0 complete	Loss: 3.637690
#
#
#  Epoch 0 complete	Loss: 2.781325
#
#
#  Epoch 0 complete	Loss: 2.610402
#
#
#  Epoch 0 complete	Loss: 2.247940
#
#
#  Epoch 0 complete	Loss: 5.948773
#
#
#  Epoch 0 complete	Loss: 3.318264
#
#
#  Epoch 0 complete	Loss: 2.736076
#
#
#  Epoch 0 complete	Loss: 2.335168
#
#
#  Epoch 0 complete	Loss: 2.404993
#
#
#  Epoch 0 complete	Loss: 4.004171
#
#
#  Epoch 0 complete	Loss: 2.593562
#
#
#  Epoch 0 complete	Loss: 2.364771
#
#
#  Epoch 0 complete	Loss: 2.532892
#
#
#  Epoch 0 complete	Loss: 3.998179
#
#
#  Epoch 0 complete	Loss: 2.452478
#
#
#  Epoch 0 complete	Loss: 2.414170
#
#
#  Epoch 0 complete	Loss: 2.404845
#
#
#  Epoch 0 complete	Loss: 2.460891
#
#
#  Epoch 0 complete	Loss: 2.353163
#
#
#  Epoch 0 complete	Loss: 3.625323
#
#
#  Epoch 0 complete	Loss: 4.273879
#
#
#  Epoch 0 complete	Loss: 4.453631
#
#
#  Epoch 0 complete	Loss: 4.119249
#
#
#  Epoch 0 complete	Loss: 2.814295
#
#
#  Epoch 0 complete	Loss: 2.815533
#
#
#  Epoch 0 complete	Loss: 5.794118
#
#
#  Epoch 0 complete	Loss: 5.677844
#
#
#  Epoch 0 complete	Loss: 5.945888
#
#
#  Epoch 0 complete	Loss: 2.744567
#
#
#  Epoch 0 complete	Loss: 6.041779
#
#
#  Epoch 0 complete	Loss: 3.484229
#
#
#  Epoch 0 complete	Loss: 2.845843
#
#
#  Epoch 0 complete	Loss: 4.861236
#
#
#  Epoch 0 complete	Loss: 4.894835
#
#
#  Epoch 0 complete	Loss: 4.905029
#
#
#  Epoch 0 complete	Loss: 3.396684
#
#
#  Epoch 0 complete	Loss: 4.933042
#
#
#  Epoch 0 complete	Loss: 1.865691
#
#
#  Epoch 0 complete	Loss: 2.867752
#
#
#  Epoch 0 complete	Loss: 4.888627
#
#
#  Epoch 0 complete	Loss: 6.548199
#
#
#  Epoch 0 complete	Loss: 2.600354
#
#
#  Epoch 0 complete	Loss: 4.917081
#
#
#  Epoch 0 complete	Loss: 1.907173
#
#
#  Epoch 0 complete	Loss: 5.375401
#
#
#  Epoch 0 complete	Loss: 4.873411
#
#
#  Epoch 0 complete	Loss: 4.096275
#
#
#  Epoch 0 complete	Loss: 4.269675
#
#
#  Epoch 0 complete	Loss: 4.816497
#
#
#  Epoch 0 complete	Loss: 4.380014
#
#
#  Epoch 0 complete	Loss: 4.704787
#
#
#  Epoch 0 complete	Loss: 5.041058
#
#
#  Epoch 0 complete	Loss: 2.184242
#
#
#  Epoch 0 complete	Loss: 3.765057
#
#
#  Epoch 0 complete	Loss: 2.267570
#
#
#  Epoch 0 complete	Loss: 3.195337
#
#
#  Epoch 0 complete	Loss: 3.094921
#
#
#  Epoch 0 complete	Loss: 4.759625
#
#
#  Epoch 0 complete	Loss: 1.725387
#
#
#  Epoch 0 complete	Loss: 2.906307
#
#
#  Epoch 0 complete	Loss: 2.372654
#
#
#  Epoch 0 complete	Loss: 3.914643
#
#
#  Epoch 0 complete	Loss: 2.354258
#
#
#  Epoch 0 complete	Loss: 1.737359
#
#
#  Epoch 0 complete	Loss: 4.313453
#
#
#  Epoch 0 complete	Loss: 7.224357
#
#
#  Epoch 0 complete	Loss: 4.874092
#
#
#  Epoch 0 complete	Loss: 4.599204
#
#
#  Epoch 0 complete	Loss: 4.883486
#
#
#  Epoch 0 complete	Loss: 4.221403
#
#
#  Epoch 0 complete	Loss: 2.591873
#
#
#  Epoch 0 complete	Loss: 3.027872
#
#
#  Epoch 0 complete	Loss: 4.086023
#
#
#  Epoch 0 complete	Loss: 4.079504
#
#
#  Epoch 0 complete	Loss: 4.365489
#
#
#  Epoch 0 complete	Loss: 3.376219
#
#
#  Epoch 0 complete	Loss: 4.251783
#
#
#  Epoch 0 complete	Loss: 3.843316
#
#
#  Epoch 0 complete	Loss: 3.732388
#
#
#  Epoch 0 complete	Loss: 2.774059
#
#
#  Epoch 0 complete	Loss: 3.663770
#
#
#  Epoch 0 complete	Loss: 3.597398
#
#
#  Epoch 0 complete	Loss: 2.261484
#
#
#  Epoch 0 complete	Loss: 2.453971
#
#
#  Epoch 0 complete	Loss: 6.673073
#
#
#  Epoch 0 complete	Loss: 4.215091
#
#
#  Epoch 0 complete	Loss: 2.475837
#
#
#  Epoch 0 complete	Loss: 2.649745
#
#
#  Epoch 0 complete	Loss: 2.578286
#
#
#  Epoch 0 complete	Loss: 3.346180
#
#
#  Epoch 0 complete	Loss: 2.957819
#
#
#  Epoch 0 complete	Loss: 3.498475
#
#
#  Epoch 0 complete	Loss: 4.035082
#
#
#  Epoch 0 complete	Loss: 2.739110
#
#
#  Epoch 0 complete	Loss: 3.343915
#
#
#  Epoch 0 complete	Loss: 3.324012
#
#
#  Epoch 0 complete	Loss: 3.034344
#
#
#  Epoch 0 complete	Loss: 3.298766
#
#
#  Epoch 0 complete	Loss: 4.574595
#
#
#  Epoch 0 complete	Loss: 3.246595
#
#
#  Epoch 0 complete	Loss: 3.308668
#
#
#  Epoch 0 complete	Loss: 6.236988
#
#
#  Epoch 0 complete	Loss: 6.193234
#
#
#  Epoch 0 complete	Loss: 3.520370
#
#
#  Epoch 0 complete	Loss: 3.564993
#
#
#  Epoch 0 complete	Loss: 6.099039
#
#
#  Epoch 0 complete	Loss: 3.101485
#
#
#  Epoch 0 complete	Loss: 4.704054
#
#
#  Epoch 0 complete	Loss: 3.873062
#
#
#  Epoch 0 complete	Loss: 4.707704
#
#
#  Epoch 0 complete	Loss: 3.048447
#
#
#  Epoch 0 complete	Loss: 3.939747
#
#
#  Epoch 0 complete	Loss: 1.903800
#
#
#  Epoch 0 complete	Loss: 5.695457
#
#
#  Epoch 0 complete	Loss: 3.474060
#
#
#  Epoch 0 complete	Loss: 3.215208
#
#
#  Epoch 0 complete	Loss: 4.206867
#
#
#  Epoch 0 complete	Loss: 4.150213
#
#
#  Epoch 0 complete	Loss: 2.669659
#
#
#  Epoch 0 complete	Loss: 4.632571
#
#
#  Epoch 0 complete	Loss: 5.286734
#
#
#  Epoch 0 complete	Loss: 2.617396
#
#
#  Epoch 0 complete	Loss: 3.215213
#
#
#  Epoch 0 complete	Loss: 4.615550
#
#
# ...
#
#
#  Epoch 3 complete	Loss: 4.649136
#
#
#  Epoch 3 complete	Loss: 3.369745
#
#
#  Epoch 3 complete	Loss: 3.355530
#
#
#  Epoch 3 complete	Loss: 3.912101
#
#
#  Epoch 3 complete	Loss: 3.323553
#
#
#  Epoch 3 complete	Loss: 3.087490
#
#
#  Epoch 3 complete	Loss: 3.907093
#
#
#  Epoch 3 complete	Loss: 3.990058
#
#
#  Epoch 3 complete	Loss: 3.080351
#
#
#  Epoch 3 complete	Loss: 4.590085
#
#
#  Epoch 3 complete	Loss: 2.486264
#
#
#  Epoch 3 complete	Loss: 4.565859
#
#
#  Epoch 3 complete	Loss: 3.928022
#
#
#  Epoch 3 complete	Loss: 2.492797
#
#
#  Epoch 3 complete	Loss: 3.073780
#
#
#  Epoch 3 complete	Loss: 2.515379
#
#
#  Epoch 3 complete	Loss: 3.782881
#
#
#  Epoch 3 complete	Loss: 3.053874
#
#
#  Epoch 3 complete	Loss: 3.027314
#
#
#  Epoch 3 complete	Loss: 3.722845
#
#
#  Epoch 3 complete	Loss: 2.684271
#
#
#  Epoch 3 complete	Loss: 4.399299
#
#
#  Epoch 3 complete	Loss: 3.005231
#
#
#  Epoch 3 complete	Loss: 3.908300
#
#
#  Epoch 3 complete	Loss: 2.987469
#
#
#  Epoch 3 complete	Loss: 3.047925
#
#
#  Epoch 3 complete	Loss: 3.062986
#
#
#  Epoch 3 complete	Loss: 4.272519
#
#
#  Epoch 3 complete	Loss: 3.875957
#
#
#  Epoch 3 complete	Loss: 2.977756
#
#
#  Epoch 3 complete	Loss: 4.143659
#
#
#  Epoch 3 complete	Loss: 3.849028
#
#
#  Epoch 3 complete	Loss: 3.476751
#
#
#  Epoch 3 complete	Loss: 2.908315
#
#
#  Epoch 3 complete	Loss: 3.017464
#
#
#  Epoch 3 complete	Loss: 2.832458
#
#
#  Epoch 3 complete	Loss: 3.823312
#
#
#  Epoch 3 complete	Loss: 2.866141
#
#
#  Epoch 3 complete	Loss: 3.930311
#
#
#  Epoch 3 complete	Loss: 3.855169
#
#
#  Epoch 3 complete	Loss: 3.373366
#
#
#  Epoch 3 complete	Loss: 3.756094
#
#
#  Epoch 3 complete	Loss: 3.001452
#
#
#  Epoch 3 complete	Loss: 3.018908
#
#
#  Epoch 3 complete	Loss: 2.722455
#
#
#  Epoch 3 complete	Loss: 3.165106
#
#
#  Epoch 3 complete	Loss: 2.979869
#
#
#  Epoch 3 complete	Loss: 3.095624
#
#
#  Epoch 3 complete	Loss: 3.562663
#
#
#  Epoch 3 complete	Loss: 2.647101
#
#
#  Epoch 3 complete	Loss: 3.677425
#
#
#  Epoch 3 complete	Loss: 3.724286
#
#
#  Epoch 3 complete	Loss: 2.998953
#
#
#  Epoch 3 complete	Loss: 3.323331
#
#
#  Epoch 3 complete	Loss: 3.741733
#
#
#  Epoch 3 complete	Loss: 2.520780
#
#
#  Epoch 3 complete	Loss: 3.642407
#
#
#  Epoch 3 complete	Loss: 3.631657
#
#
#  Epoch 3 complete	Loss: 2.996937
#
#
#  Epoch 3 complete	Loss: 3.590870
#
#
#  Epoch 3 complete	Loss: 2.498544
#
#
#  Epoch 3 complete	Loss: 3.000261
#
#
#  Epoch 3 complete	Loss: 3.146339
#
#
#  Epoch 3 complete	Loss: 4.375911
#
#
#  Epoch 3 complete	Loss: 2.991395
#
#
#  Epoch 3 complete	Loss: 3.438226
#
#
#  Epoch 3 complete	Loss: 3.436237
#
#
#  Epoch 3 complete	Loss: 2.972952
#
#
#  Epoch 3 complete	Loss: 3.814234
#
#
#  Epoch 3 complete	Loss: 2.963514
#
#
#  Epoch 3 complete	Loss: 3.320165
#
#
#  Epoch 3 complete	Loss: 2.421694
#
#
#  Epoch 3 complete	Loss: 2.418327
#
#
#  Epoch 3 complete	Loss: 3.663134
#
#
#  Epoch 3 complete	Loss: 3.723748
#
#
#  Epoch 3 complete	Loss: 4.074476
#
#
#  Epoch 3 complete	Loss: 3.994126
#
#
#  Epoch 3 complete	Loss: 4.044064
#
#
#  Epoch 3 complete	Loss: 2.971708
#
#
#  Epoch 3 complete	Loss: 1.769815
#
#
#  Epoch 3 complete	Loss: 2.935314
#
#
#  Epoch 3 complete	Loss: 4.887136
#
#
#  Epoch 3 complete	Loss: 2.707192
#
#
#  Epoch 3 complete	Loss: 4.210815
#
#
#  Epoch 3 complete	Loss: 4.876053
#
#
#  Epoch 3 complete	Loss: 4.427103
#
#
#  Epoch 3 complete	Loss: 4.496997
#
#
#  Epoch 3 complete	Loss: 2.613950
#
#
#  Epoch 3 complete	Loss: 4.371463
#
#
#  Epoch 3 complete	Loss: 4.525488
#
#
#  Epoch 3 complete	Loss: 2.569156
#
#
#  Epoch 3 complete	Loss: 4.553989
#
#
#  Epoch 3 complete	Loss: 5.043385
#
#
#  Epoch 3 complete	Loss: 4.469770
#
#
#  Epoch 3 complete	Loss: 2.767260
#
#
#  Epoch 3 complete	Loss: 4.322278
#
#
#  Epoch 3 complete	Loss: 3.074620
#
#
#  Epoch 3 complete	Loss: 3.766184
#
#
#  Epoch 3 complete	Loss: 2.511844
#
#
#  Epoch 3 complete	Loss: 4.630487
#
#
#  Epoch 3 complete	Loss: 3.107556
#
#
#  Epoch 3 complete	Loss: 4.527770
#
#
#  Epoch 3 complete	Loss: 3.094791
#
#
#  Epoch 3 complete	Loss: 4.513492
#
#
#  Epoch 3 complete	Loss: 5.103201
#
#
#  Epoch 3 complete	Loss: 2.644277
#
#
#  Epoch 3 complete	Loss: 2.402268
#
#
#  Epoch 3 complete	Loss: 3.084787
#
#
#  Epoch 3 complete	Loss: 3.053242
#
#
#  Epoch 3 complete	Loss: 4.615769
#
#
#  Epoch 3 complete	Loss: 3.004848
#
#
#  Epoch 3 complete	Loss: 5.046417
#
#
#  Epoch 3 complete	Loss: 2.667882
#
#
#  Epoch 3 complete	Loss: 5.040247
#
#
#  Epoch 3 complete	Loss: 2.439700
#
#
#  Epoch 3 complete	Loss: 4.334091
#
#
#  Epoch 3 complete	Loss: 4.312269
#
#
#  Epoch 3 complete	Loss: 2.649267
#
#
#  Epoch 3 complete	Loss: 2.351938
#
#
#  Epoch 3 complete	Loss: 2.844926
#
#
#  Epoch 3 complete	Loss: 2.448098
#
#
#  Epoch 3 complete	Loss: 4.495792
#
#
#  Epoch 3 complete	Loss: 4.802408
#
#
#  Epoch 3 complete	Loss: 2.776438
#
#
#  Epoch 3 complete	Loss: 4.414986
#
#
#  Epoch 3 complete	Loss: 2.809109
#
#
#  Epoch 3 complete	Loss: 2.713599
#
#
#  Epoch 3 complete	Loss: 2.665556
#
#
#  Epoch 3 complete	Loss: 2.495021
#
#
#  Epoch 3 complete	Loss: 3.970850
#
#
#  Epoch 3 complete	Loss: 2.506932
#
#
#  Epoch 3 complete	Loss: 2.602261
#
#
#  Epoch 3 complete	Loss: 3.195972
#
#
#  Epoch 3 complete	Loss: 2.555063
#
#
#  Epoch 3 complete	Loss: 4.320775
#
#
#  Epoch 3 complete	Loss: 2.525735
#
#
#  Epoch 3 complete	Loss: 2.752598
#
#
#  Epoch 3 complete	Loss: 4.240044
#
#
#  Epoch 3 complete	Loss: 4.183626
#
#
#  Epoch 3 complete	Loss: 3.249786
#
#
#  Epoch 3 complete	Loss: 4.349678
#
#
#  Epoch 3 complete	Loss: 2.771751
#
#
#  Epoch 3 complete	Loss: 2.210587
#
#
#  Epoch 3 complete	Loss: 3.285800
#
#
#  Epoch 3 complete	Loss: 3.586306
#
#
#  Epoch 3 complete	Loss: 3.295002
#
#
#  Epoch 3 complete	Loss: 2.594384
#
#
#  Epoch 3 complete	Loss: 2.278368
#
#
#  Epoch 3 complete	Loss: 4.146847
#
#
#  Epoch 3 complete	Loss: 2.628195
#
#
#  Epoch 3 complete	Loss: 2.847040
#
#
#  Epoch 3 complete	Loss: 4.037717
#
#
#  Epoch 3 complete	Loss: 3.986803
#
#
#  Epoch 3 complete	Loss: 4.064686
#
#
#  Epoch 3 complete	Loss: 2.189546
#
#
#  Epoch 3 complete	Loss: 3.351302
#
#
#  Epoch 3 complete	Loss: 3.829854
#
#
#  Epoch 3 complete	Loss: 4.288974
#
#
#  Epoch 3 complete	Loss: 3.251299
#
#
#  Epoch 3 complete	Loss: 3.737777
#
#
#  Epoch 3 complete	Loss: 2.132258
#
#
#  Epoch 3 complete	Loss: 4.146409
#
#
#  Epoch 3 complete	Loss: 3.015711
#
#
#  Epoch 3 complete	Loss: 3.807527
#
#
#  Epoch 3 complete	Loss: 3.049560
#
#
#  Epoch 3 complete	Loss: 3.807476
#
#
#  Epoch 3 complete	Loss: 4.151554
#
#
#  Epoch 3 complete	Loss: 4.093249
#
#
#  Epoch 3 complete	Loss: 3.096482
#
#
#  Epoch 3 complete	Loss: 2.977626
#
#
#  Epoch 3 complete	Loss: 2.105203
#
#
#  Epoch 3 complete	Loss: 3.783103
#
#
#  Epoch 3 complete	Loss: 4.379092
#
#
#  Epoch 3 complete	Loss: 3.138163
#
#
#  Epoch 3 complete	Loss: 3.130247
#
#
#  Epoch 3 complete	Loss: 4.483536
#
#
#  Epoch 3 complete	Loss: 3.834984
#
#
#  Epoch 3 complete	Loss: 3.977542
#
#
#  Epoch 3 complete	Loss: 3.651239
#
#
#  Epoch 3 complete	Loss: 4.169315
#
#
#  Epoch 3 complete	Loss: 4.616077
#
#
#  Epoch 3 complete	Loss: 3.468802
#
#
#  Epoch 3 complete	Loss: 3.244562
#
#
#  Epoch 3 complete	Loss: 3.817783
#
#
#  Epoch 3 complete	Loss: 3.334732
#
#
#  Epoch 3 complete	Loss: 3.403858
#
#
#  Epoch 3 complete	Loss: 2.916778
#
#
#  Epoch 3 complete	Loss: 4.894906
#
#
#  Epoch 3 complete	Loss: 3.249822
#
#
#  Epoch 3 complete	Loss: 3.261788
#
#
#  Epoch 3 complete	Loss: 3.320971
#
#
#  Epoch 3 complete	Loss: 3.364778
#
#
#  Epoch 3 complete	Loss: 2.864629
#
#
#  Epoch 3 complete	Loss: 3.457355
#
#
#  Epoch 3 complete	Loss: 2.818193
#
#
#  Epoch 3 complete	Loss: 3.373695
#
#
#  Epoch 3 complete	Loss: 2.634392
#
#
#  Epoch 3 complete	Loss: 3.426350
#
#
#  Epoch 3 complete	Loss: 3.215670
#
#
#  Epoch 3 complete	Loss: 4.217170
#
#
#  Epoch 3 complete	Loss: 4.825943
#
#
#  Epoch 3 complete	Loss: 3.611178
#
#
#  Epoch 3 complete	Loss: 4.806628
#
#
#  Epoch 3 complete	Loss: 2.691201
#
#
#  Epoch 3 complete	Loss: 2.522833
#
#
#  Epoch 3 complete	Loss: 3.027848
#
#
#  Epoch 3 complete	Loss: 4.920889
#
#
#  Epoch 3 complete	Loss: 3.717939
#
#
#  Epoch 3 complete	Loss: 4.178624
#
#
#  Epoch 3 complete	Loss: 2.817408
#
#
#  Epoch 3 complete	Loss: 3.376257
#
#
#  Epoch 3 complete	Loss: 3.398824
#
#
#  Epoch 3 complete	Loss: 2.645245
#
#
#  Epoch 3 complete	Loss: 3.456176
#
#
#  Epoch 3 complete	Loss: 2.526252
#
#
#  Epoch 3 complete	Loss: 2.576279
#
#
#  Epoch 3 complete	Loss: 2.729319
#
#
#  Epoch 3 complete	Loss: 2.827639
#
#
#  Epoch 3 complete	Loss: 2.712800
#
#
#  Epoch 3 complete	Loss: 3.776988
#
#
#  Epoch 3 complete	Loss: 3.489423
#
#
#  Epoch 3 complete	Loss: 2.756066
#
#
#  Epoch 3 complete	Loss: 3.309975
#
#
#  Epoch 3 complete	Loss: 4.091393
#
#
#  Epoch 3 complete	Loss: 3.492273
#
#
#  Epoch 3 complete	Loss: 4.121817
#
#
#  Epoch 3 complete	Loss: 4.124771
#
#
#  Epoch 3 complete	Loss: 2.533477
#
#
#  Epoch 3 complete	Loss: 2.733930
#
#
#  Epoch 3 complete	Loss: 4.396861
#
#
#  Epoch 3 complete	Loss: 4.081192
#
#
#  Epoch 3 complete	Loss: 3.245477
#
#
#  Epoch 3 complete	Loss: 2.710132
#
#
#  Epoch 3 complete	Loss: 3.094023
#
#
#  Epoch 3 complete	Loss: 2.734715
#
#
#  Epoch 3 complete	Loss: 3.026640
#
#
#  Epoch 3 complete	Loss: 2.927215
#
#
#  Epoch 3 complete	Loss: 4.475632
#
#
#  Epoch 3 complete	Loss: 2.977803
#
#
#  Epoch 3 complete	Loss: 2.592456
#
#
#  Epoch 3 complete	Loss: 3.008133
#
#
#  Epoch 3 complete	Loss: 4.517047
#
#
#  Epoch 3 complete	Loss: 3.026091
#
#
#  Epoch 3 complete	Loss: 3.189282
#
#
#  Epoch 3 complete	Loss: 3.661331
#
#
#  Epoch 3 complete	Loss: 3.124355
#
#
#  Epoch 3 complete	Loss: 3.152455
#
#
#  Epoch 3 complete	Loss: 3.144699
#
#
#  Epoch 3 complete	Loss: 2.658289
#
#
#  Epoch 3 complete	Loss: 3.260643
#
#
#  Epoch 3 complete	Loss: 3.090033
#
#
#  Epoch 3 complete	Loss: 2.649262
#
#
#  Epoch 3 complete	Loss: 3.095623
#
#
#  Epoch 3 complete	Loss: 2.961304
#
#
#  Epoch 3 complete	Loss: 4.174768
#
#
#  Epoch 3 complete	Loss: 2.696366
#
#
#  Epoch 3 complete	Loss: 3.335820
#
#
#  Epoch 3 complete	Loss: 3.043614
#
#
#  Epoch 3 complete	Loss: 4.666332
#
#
#  Epoch 3 complete	Loss: 3.121173
#
#
#  Epoch 3 complete	Loss: 4.119276
#
#
#  Epoch 3 complete	Loss: 2.830319
#
#
#  Epoch 3 complete	Loss: 2.606262
#
#
#  Epoch 3 complete	Loss: 2.776007
#
#
#  Epoch 3 complete	Loss: 3.001334
#
#
#  Epoch 3 complete	Loss: 4.252295
#
#
#  Epoch 3 complete	Loss: 2.935401
#
#
#  Epoch 3 complete	Loss: 2.979528
#
#
#  Epoch 3 complete	Loss: 5.447064
#
#
#  Epoch 3 complete	Loss: 3.104712
#
#
#  Epoch 3 complete	Loss: 3.115114
#
#
#  Epoch 3 complete	Loss: 2.594583
#
#
#  Epoch 3 complete	Loss: 2.937198
#
#
#  Epoch 3 complete	Loss: 3.021007
#
#
#  Epoch 3 complete	Loss: 3.658792
#
#
#  Epoch 3 complete	Loss: 3.653312
#
#
#  Epoch 3 complete	Loss: 3.644457
#
#
#  Epoch 3 complete	Loss: 4.066129
#
#
#  Epoch 3 complete	Loss: 3.387834
#
#
#  Epoch 3 complete	Loss: 2.827146
#
#
#  Epoch 3 complete	Loss: 2.224525
#
#
#  Epoch 3 complete	Loss: 3.890896
#
#
#  Epoch 3 complete	Loss: 2.998294
#
#
#  Epoch 3 complete	Loss: 2.944479
#
#
#  Epoch 3 complete	Loss: 3.739122
#
#
#  Epoch 3 complete	Loss: 3.872268
#
#
#  Epoch 3 complete	Loss: 2.269293
#
#
#  Epoch 3 complete	Loss: 3.248335
#
#
#  Epoch 3 complete	Loss: 3.399319
#
#
#  Epoch 3 complete	Loss: 2.119438
#
#
#  Epoch 3 complete	Loss: 4.713579
#
#
#  Epoch 3 complete	Loss: 3.323662
#
#
#  Epoch 3 complete	Loss: 4.115055
#
#
#  Epoch 3 complete	Loss: 3.976614
#
#
#  Epoch 3 complete	Loss: 2.406210
#
#
#  Epoch 3 complete	Loss: 4.200164
#
#
#  Epoch 3 complete	Loss: 1.680164
#
#
#  Epoch 3 complete	Loss: 2.119532
#
#
#  Epoch 3 complete	Loss: 3.763316
#
#
#  Epoch 3 complete	Loss: 3.521038
#
#
#  Epoch 3 complete	Loss: 4.139238
#
#
#  Epoch 3 complete	Loss: 3.895017
#
#
#  Epoch 3 complete	Loss: 3.512878
#
#
#  Epoch 3 complete	Loss: 4.599030
#
#
#  Epoch 3 complete	Loss: 3.561866
#
#
#  Epoch 3 complete	Loss: 2.374413
#
#
#  Epoch 3 complete	Loss: 3.091085
#
#
#  Epoch 3 complete	Loss: 4.275472
#
#
#  Epoch 3 complete	Loss: 4.294393
#
#
#  Epoch 3 complete	Loss: 3.082187
#
#
#  Epoch 3 complete	Loss: 3.073903
#
#
#  Epoch 3 complete	Loss: 3.389561
#
#
#  Epoch 3 complete	Loss: 3.085290
#
#
#  Epoch 3 complete	Loss: 3.986380
#
#
#  Epoch 3 complete	Loss: 3.457233
#
#
#  Epoch 3 complete	Loss: 3.154512
#
#
#  Epoch 3 complete	Loss: 3.148465
#
#
#  Epoch 3 complete	Loss: 3.967061
#
#
#  Epoch 3 complete	Loss: 3.060901
#
#
#  Epoch 3 complete	Loss: 3.092635
#
#
#  Epoch 3 complete	Loss: 3.656526
#
#
#  Epoch 3 complete	Loss: 3.644884
#
#
#  Epoch 3 complete	Loss: 3.544130
#
#
#  Epoch 3 complete	Loss: 2.969393
#
#
#  Epoch 3 complete	Loss: 2.261266
#
#
#  Epoch 3 complete	Loss: 3.406739
#
#
#  Epoch 3 complete	Loss: 1.914587
#
#
#  Epoch 3 complete	Loss: 3.505607
#
#
#  Epoch 3 complete	Loss: 3.040407
#
#
#  Epoch 3 complete	Loss: 2.589788
#
#
#  Epoch 3 complete	Loss: 3.432909
#
#
#  Epoch 3 complete	Loss: 3.886959
#
#
#  Epoch 3 complete	Loss: 5.286229
#
#
#  Epoch 3 complete	Loss: 3.043910
#
#
#  Epoch 3 complete	Loss: 3.329964
#
#
#  Epoch 3 complete	Loss: 4.135408
#
#
#  Epoch 3 complete	Loss: 3.301252
#
#
#  Epoch 3 complete	Loss: 3.434729
#
#
#  Epoch 3 complete	Loss: 2.868513
#
#
#  Epoch 3 complete	Loss: 2.963913
#
#
#  Epoch 3 complete	Loss: 3.546887
#
#
#  Epoch 3 complete	Loss: 2.955216
#
#
#  Epoch 3 complete	Loss: 2.894958
#
#
#  Epoch 3 complete	Loss: 2.379115
#
#
#  Epoch 3 complete	Loss: 2.718172
#
#
#  Epoch 3 complete	Loss: 2.795631
#
#
#  Epoch 3 complete	Loss: 3.005420
#
#
#  Epoch 3 complete	Loss: 2.956866
#
#
#  Epoch 3 complete	Loss: 2.919791
#
#
#  Epoch 3 complete	Loss: 2.749214
#
#
#  Epoch 3 complete	Loss: 2.790069
#
#
#  Epoch 3 complete	Loss: 3.059331
#
#
#  Epoch 3 complete	Loss: 3.728882
#
#
#  Epoch 3 complete	Loss: 2.994693
#
#
#  Epoch 3 complete	Loss: 2.977136
#
#
#  Epoch 3 complete	Loss: 2.548541
#
#
#  Epoch 3 complete	Loss: 2.849528
#
#
#  Epoch 3 complete	Loss: 2.830254
#
#
#  Epoch 3 complete	Loss: 3.008963
#
#
#  Epoch 3 complete	Loss: 2.696858
#
#
#  Epoch 3 complete	Loss: 3.054005
#
#
#  Epoch 3 complete	Loss: 2.839501
#
#
#  Epoch 3 complete	Loss: 4.098428
#
#
#  Epoch 3 complete	Loss: 4.588982
#
#
#  Epoch 3 complete	Loss: 3.729677
#
#
#  Epoch 3 complete	Loss: 2.631936
#
#
#  Epoch 3 complete	Loss: 2.185167
#
#
#  Epoch 3 complete	Loss: 1.630767
#
#
#  Epoch 3 complete	Loss: 4.055733
#
#
#  Epoch 3 complete	Loss: 3.166128
#
#
#  Epoch 3 complete	Loss: 3.334770
#
#
#  Epoch 3 complete	Loss: 3.224525
#
#
#  Epoch 3 complete	Loss: 2.876611
#
#
#  Epoch 3 complete	Loss: 3.140557
#
#
#  Epoch 3 complete	Loss: 3.138520
#
#
#  Epoch 3 complete	Loss: 3.127998
#
#
#  Epoch 3 complete	Loss: 3.016310
#
#
#  Epoch 3 complete	Loss: 4.347602
#
#
#  Epoch 3 complete	Loss: 3.253566
#
#
#  Epoch 3 complete	Loss: 2.965381
#
#
#  Epoch 3 complete	Loss: 3.341502
#
#
#  Epoch 3 complete	Loss: 3.253161
#
#
#  Epoch 3 complete	Loss: 3.120445
#
#
#  Epoch 3 complete	Loss: 2.851613
#
#
#  Epoch 3 complete	Loss: 2.228089
#
#
#  Epoch 3 complete	Loss: 3.647935
#
#
#  Epoch 3 complete	Loss: 3.430504
#
#
#  Epoch 3 complete	Loss: 2.139027
#
#
#  Epoch 3 complete	Loss: 3.386122
#
#
#  Epoch 3 complete	Loss: 3.426841
#
#
#  Epoch 3 complete	Loss: 2.790136
#
#
#  Epoch 3 complete	Loss: 3.883509
#
#
#  Epoch 3 complete	Loss: 3.601461
#
#
#  Epoch 3 complete	Loss: 5.186078
#
#
#  Epoch 3 complete	Loss: 2.991581
#
#
#  Epoch 3 complete	Loss: 3.201890
#
#
#  Epoch 3 complete	Loss: 3.078628
#
#
#  Epoch 3 complete	Loss: 4.909303
#
#
#  Epoch 3 complete	Loss: 3.168308
#
#
#  Epoch 3 complete	Loss: 2.275988
#
#
#  Epoch 3 complete	Loss: 4.162632
#
#
#  Epoch 3 complete	Loss: 3.610061
#
#
#  Epoch 3 complete	Loss: 3.174349
#
#
#  Epoch 3 complete	Loss: 4.127093
#
#
#  Epoch 3 complete	Loss: 2.875771
#
#
#  Epoch 3 complete	Loss: 2.727991
#
#
#  Epoch 3 complete	Loss: 2.369100
#
#
#  Epoch 3 complete	Loss: 3.927551
#
#
#  Epoch 3 complete	Loss: 4.979268
#
#
#  Epoch 3 complete	Loss: 1.194961
#
#
#  Epoch 3 complete	Loss: 2.316713
#
#
#  Epoch 3 complete	Loss: 3.190205
#
#
#  Epoch 3 complete	Loss: 0.943383
#
#
#  Epoch 3 complete	Loss: 2.692436
#
#
#  Epoch 3 complete	Loss: 2.677091
#
#
#  Epoch 3 complete	Loss: 3.857567
#
#
#  Epoch 3 complete	Loss: 4.913337
#
#
#  Epoch 3 complete	Loss: 2.597872
#
#
#  Epoch 3 complete	Loss: 3.123895
#
#
#  Epoch 3 complete	Loss: 3.373400
#
#
#  Epoch 3 complete	Loss: 2.539721
#
#
#  Epoch 3 complete	Loss: 3.710254
#
#
#  Epoch 3 complete	Loss: 3.756329
#
#
#  Epoch 3 complete	Loss: 2.663618
#
#
#  Epoch 3 complete	Loss: 4.142639
#
#
#  Epoch 3 complete	Loss: 2.595600
#
#
#  Epoch 3 complete	Loss: 3.640828
#
#
#  Epoch 3 complete	Loss: 3.024368
#
#
#  Epoch 3 complete	Loss: 3.297440
#
#
#  Epoch 3 complete	Loss: 4.608653
#
#
#  Epoch 3 complete	Loss: 4.967183
#
#
#  Epoch 3 complete	Loss: 4.565230
#
#
#  Epoch 3 complete	Loss: 3.307073
#
#
#  Epoch 3 complete	Loss: 3.760521
#
#
#  Epoch 3 complete	Loss: 4.039138
#
#
#  Epoch 3 complete	Loss: 3.272368
#
#
#  Epoch 3 complete	Loss: 3.315329
#
#
#  Epoch 3 complete	Loss: 3.526151
#
#
#  Epoch 3 complete	Loss: 3.015211
#
#
#  Epoch 3 complete	Loss: 3.703821
#
#
#  Epoch 3 complete	Loss: 3.629645
#
#
#  Epoch 3 complete	Loss: 3.541298
#
#
#  Epoch 3 complete	Loss: 5.407930
#
#
#  Epoch 3 complete	Loss: 3.344655
#
#
#  Epoch 3 complete	Loss: 3.632565
#
#
#  Epoch 3 complete	Loss: 2.038472
#
#
#  Epoch 3 complete	Loss: 2.034775
#
#
#  Epoch 3 complete	Loss: 5.519661
#
#
#  Epoch 3 complete	Loss: 2.018367
#
#
#  Epoch 3 complete	Loss: 3.540418
#
#
#  Epoch 3 complete	Loss: 4.911447
#
#
#  Epoch 3 complete	Loss: 3.500569
#
#
#  Epoch 3 complete	Loss: 3.217899
#
#
#  Epoch 3 complete	Loss: 3.580459
#
#
#  Epoch 3 complete	Loss: 3.233442
#
#
#  Epoch 3 complete	Loss: 1.985539
#
#
#  Epoch 3 complete	Loss: 3.566904
