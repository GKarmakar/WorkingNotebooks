# %%
#Importing keras packages
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense

from keras import backend as K
K.set_image_dim_ordering('tf')

# %%
#Building a CNN Architecture

classifier = Sequential()
classifier.add(Convolution2D(32, 3, 3, input_shape = (64, 64, 3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))
classifier.add(Flatten())
classifier.add(Dense(output_dim = 128, activation = 'relu'))
classifier.add(Dense(output_dim = 1, activation = 'sigmoid'))
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics=['accuracy'])

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

trainng_set = train_datagen.flow_from_directory(
        './data/dataset/training_set',
        target_size=(64, 64),
        batch_size=32,
        class_mode='binary')

testing_set = test_datagen.flow_from_directory(
        './data/dataset/testing_set',
        target_size=(64, 64),
        batch_size=32,
        class_mode='binary')

classifier.fit_generator(
        training_set,
        steps_per_epoch=8000,
        epochs=25,
        validation_data=testing_set,
        nb_val_samples=2000)

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
training_set = train_datagen.flow_from_directory(
        './data/dataset/training_set',
        target_size=(64, 64),
        batch_size=32,
        class_mode='binary')
# Out:
# Found 8000 images belonging to 2 classes.

# %%
testing_set = test_datagen.flow_from_directory(
        './data/dataset/test_set',
        target_size=(64, 64),
        batch_size=32,
        class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %%
classifier.fit_generator(training_set,
        samples_per_epoch=8000,
        nb_epoch=25,
        validation_data=testing_set,
        nb_val_samples=2000)
# Out:
# Epoch 1/25
# 8000/8000 [==============================] - 141s - loss: 0.6831 - acc: 0.5850 - val_loss: 0.6403 - val_acc: 0.6005
# Epoch 2/25
# 8000/8000 [==============================] - 137s - loss: 0.6091 - acc: 0.6668 - val_loss: 0.5944 - val_acc: 0.6780
# Epoch 3/25
# 8000/8000 [==============================] - 136s - loss: 0.5838 - acc: 0.6867 - val_loss: 0.5631 - val_acc: 0.7130
# Epoch 4/25
# 8000/8000 [==============================] - 121s - loss: 0.5583 - acc: 0.7149 - val_loss: 0.5633 - val_acc: 0.7020
# Epoch 5/25
# 8000/8000 [==============================] - 118s - loss: 0.5498 - acc: 0.7206 - val_loss: 0.5590 - val_acc: 0.7205
# Epoch 6/25
# 8000/8000 [==============================] - 7342s - loss: 0.5304 - acc: 0.7331 - val_loss: 0.5470 - val_acc: 0.7210
# Epoch 7/25
# 8000/8000 [==============================] - 145s - loss: 0.5232 - acc: 0.7361 - val_loss: 0.5323 - val_acc: 0.7490
# Epoch 8/25
# ...

# %%
#Lets make architecture more deep to get more accuracy - added one more Convolution2D and MaxPooling2D layer

#Building a CNN Architecture

classifier = Sequential()
classifier.add(Convolution2D(32, 3, 3, input_shape = (64, 64, 3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))
classifier.add(Convolution2D(32, 3, 3, activation='relu')
classifier.add(MaxPooling2D(pool_size=(2,2)))
classifier.add(Flatten())
classifier.add(Dense(output_dim = 128, activation = 'relu'))
classifier.add(Dense(output_dim = 1, activation = 'sigmoid'))
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics=['accuracy'])

# %%
#Run this piece of code again -
#Note that making target size bigger also can improve accuracy

from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

trainng_set = train_datagen.flow_from_directory(
        './data/dataset/training_set',
        target_size=(64, 64),
        batch_size=32,
        class_mode='binary')

testing_set = test_datagen.flow_from_directory(
        './data/dataset/testing_set',
        target_size=(64, 64),
        batch_size=32,
        class_mode='binary')

classifier.fit_generator(
        training_set,
        steps_per_epoch=8000,
        epochs=25,
        validation_data=testing_set,
        nb_val_samples=2000)

# %%
#Making new prediction - on single data point

import numpy as np

from keras.preprocessing import image
test_image = image.load_img("./data/dataset/single_prediction/cat_or_dog_1.jpg", (64, 64)) #Load image
test_image = image.img_to_array(test_image) # Convert image to a array

#Predict method expects to have 4th dimension, so we need to add one more dimension (for batch even if it is just 1)
test_image = np.expand_dims(test_image, axis=0)
test_image.shape
prediction_1 = classifier.predict(test_image)
#Now see the class for the prediction
training_set.class_indices

if prediction_1[0][0] == 1:
    pred_class = 'Dog'
else:
    pred_class = 'Cat'

print(pred_class)
test_image = image.load_img("./data/dataset/single_prediction/cat_or_dog_2.jpg", (64, 64)) #Load image
test_image = image.img_to_array(test_image) # Convert image to a array

#Predict method expects to have 4th dimension, so we need to add one more dimension (for batch even if it is just 1)
test_image = np.expand_dims(test_image, axis=0)
test_image.shape
prediction_2 = classifier.predict(test_image)
#Now see the class for the prediction
training_set.class_indices

if prediction_2[0][0] == 1:
    pred_class = 'Dog'
else:
    pred_class = 'Cat'
print(pred_class)
