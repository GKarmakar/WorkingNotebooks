# %%
# %pylab

# %%
import tensorflow as tf
import numpy as np

# %%
from six.moves import urllib

# %%
f, _ = urllib.request.urlretrieve("http://www.gutenberg.org/cache/epub/28885/pg28885.txt", 'alice.txt')

# %%
with open(f, 'r') as fp:
    text = fp.read()

# %%
print(text[:100])
# Out:
# ﻿Project Gutenberg's Alice's Adventures in Wonderland, by Lewis Carroll
#
# This eBook is for the u

# %%
vocab = list(set(text))

# %%
len(vocab), len(text)
# Out:
# (93, 177428)

# %%
encoder = dict(zip(vocab, range(len(vocab))))

# %%
decoder = dict(zip(range(len(vocab)), vocab))

# %%
batch_size=100
seq_len = 100
n_layers = 2
n_chars = len(vocab)
n_cells = 256

# %%
X = tf.placeholder(tf.int32, [None, seq_len], name='X')
Y = tf.placeholder(tf.int32, [None, seq_len], name='Y')

# %%
# we first create a variable to take us from our one-hot representation to our LSTM cells
embedding = tf.get_variable("embedding", [n_chars, n_cells])

# And then use tensorflow's embedding lookup to look up the ids in X
Xs = tf.nn.embedding_lookup(embedding, X)

# The resulting lookups are concatenated into a dense tensor
print(Xs.get_shape().as_list())
# Out:
# [None, 100, 256]

# %%
with tf.name_scope('reslice'):
    Xs = [tf.squeeze(seq, [1]) for seq in tf.split(1, seq_len, Xs)]

# %%
cell = tf.nn.rnn_cell.BasicLSTMCell(num_units=n_cells, state_is_tuple=True)

# %%
initial_state = cell.zero_state(tf.shape(X)[0], tf.float32)

# %%
if n_layers > 1:
    cell = tf.nn.rnn_cell.MultiRNNCell([cell]*n_layers, state_is_tuple=True)
initial_state = cell.zero_state(tf.shape(X)[0], tf.float32)

# %%
outputs, state = tf.nn.rnn(cell, Xs, initial_state=initial_state)

# %%
output_flat = tf.reshape(tf.concat(1, outputs), [-1, n_cells])

# %%
with tf.variable_scope('prediction'):
    W = tf.get_variable(
        "W",
        shape=[n_cells, n_chars],
        initializer=tf.random_normal_initializer(stddev=0.1))
    b = tf.get_variable(
        "b",
        shape=[n_chars],
        initializer=tf.random_normal_initializer(stddev=0.1))

    # Find the output prediction of every single character in our minibatch
    # we denote the pre-activation prediction, logits.
    logits = tf.matmul(output_flat, W) + b

    # We get the probabilistic version by calculating the softmax of this
    probs = tf.nn.softmax(logits)

    # And then we can find the index of maximum probability
    Y_pred = tf.argmax(probs, 1)

# %%
with tf.variable_scope('loss'):
    # Compute mean cross entropy loss for each output.
    Y_true_flat = tf.reshape(tf.concat(1, Y), [-1])
    loss = tf.nn.sparse_softmax_cross_entropy_with_logits(logits, Y_true_flat)
    mean_loss = tf.reduce_mean(loss)

# %%
with tf.name_scope('optimizer'):
    optimizer = tf.train.AdamOptimizer(learning_rate=0.001)
    gradients = []
    clip = tf.constant(5.0, name="clip")
    for grad, var in optimizer.compute_gradients(mean_loss):
        gradients.append((tf.clip_by_value(grad, -clip, clip), var))
    updates = optimizer.apply_gradients(gradients)

# %%
sess = tf.Session()
init = tf.initialize_all_variables()
sess.run(init)

cursor = 0
it_i = 0
while True:
    Xs, Ys = [], []
    for batch_i in range(batch_size):
        if (cursor + seq_len) >= len(text) - seq_len - 1:
            cursor = 0
        Xs.append([encoder[ch]
                   for ch in text[cursor:cursor + seq_len]])
        Ys.append([encoder[ch]
                   for ch in text[cursor + 1: cursor + seq_len + 1]])

        cursor = (cursor + seq_len)
    Xs = np.array(Xs).astype(np.int32)
    Ys = np.array(Ys).astype(np.int32)

    loss_val, _ = sess.run([mean_loss, updates],
                           feed_dict={X: Xs, Y: Ys})
    print(it_i, loss_val)

    if it_i % 500 == 0:
        p = sess.run([Y_pred], feed_dict={X: Xs})[0]
        preds = [decoder[p_i] for p_i in p]
        print("".join(preds).split('\n'))

    it_i += 1
# Out:
# (0, 4.5472569)
# ['PPPPPPPPPPPPPPPPPPPPPPP     PP      PPPPPPPP      PP PPPPPP                                         PPPPPPPPPPPPPP  PPPPP                                                PPPPPPPPP                      PPPPPffW                                                                      PPPPPPPPPP            PPPPPPPPPPP            \xc3\xc3 \xc3PPPP                        PPPPPPP          PPP                         PPPPPPPPPPPPPPPPP                                                              PPPPPPPPPPP          PPPPPPPPPPPPPPPPPPP                                  qqq                                            PPPPPPPPPPPPPPPPP\xc3\xc3\xc3\xc3\xc3                                           C                                  PPPPPPPPPPPPPPPPPPPPPPPPPPPPPPPP                CCCCCCP                     PPPPPPP                 PPPPPPPPPP      PP                                                  PPPPPPPq                        PPPPPPPPPPPPPP                         PPPPPPPPPPPPPPPPPPPPPPPPPPPPPPPPPPPP                         PPPPP\xc3\xc3q                                                                                            PPPPPPPPPP22\xc3\xc3\xc3\xc3\xc3\xc3\xc3                                                                            PPP  PPP                              CCCC\xc3C\xc3C\xc3\xc3\xc3\xc3\xc3\xc3                                                     PPPPPPPPPPPPPPPPPPP     P                                                                           PPPPPPPPPP                                                                                          PPPPPPPPPPP                                                                                         PPPPPPN                                                                                             PPP                                                                                                 PPP                                                                                                 PPPPPPffPPPPP                                                                                       PPPPPPP                                                                                             PPPPPPPPPPPPPPPPPPPPPPP                                                                             PPPPPPPPPP                                                                                          PPP                                                                                                 PPPPPPPPPPPPP                                                                                       PPPPPPPPPPPP                                                                                        PPPPP                                                                                               PPPPPPPPPPPPPPPPP                                                                                   PPPPPPPPPPPPPP                                                                                      PPP                                                                                                 PPPPPPPPPPPPPPPP P                                                                                  PPPPP\xc3\xc3\xc3\xc3\xc3\xc3\xc3                                                                                        PPPPPPPPPPPPPPPPPPP                                                                                 PPPPPPPPPPP                                                                                         PPPPPPPPPPP                                                                                         PPP                                                                                                 PPPPPPPPPPPPPPPPPP                                                                                  PPP                                                                                                 PPPPPPPPPPPP   PPPPP                                                                                PP ...
# (1, 4.4490342)
# (2, 4.2692361)
# (3, 3.808975)
# (4, 3.8172133)
# (5, 3.578943)
# (6, 3.4950507)
# (7, 3.4012039)
# (8, 3.4144258)
# (9, 3.374527)
# (10, 3.2864969)
# (11, 3.350816)
# (12, 3.3447962)
# (13, 3.2610953)
# (14, 3.3110554)
# (15, 3.3984792)
# (16, 3.4118996)
# (17, 3.5518913)
# (18, 3.1998155)
# (19, 3.1958656)
# (20, 3.2522106)
# (21, 3.1204176)
# (22, 3.2270684)
# (23, 3.1812584)
# (24, 3.212327)
# (25, 3.2010183)
# (26, 3.2731895)
# (27, 3.23492)
# (28, 3.1999934)
# (29, 3.2789867)
# (30, 3.2300539)
# (31, 3.2193747)
# (32, 3.2158165)
# (33, 3.3805618)
# (34, 3.4581211)
# (35, 3.3544953)
# (36, 3.1415989)
# (37, 3.163111)
# (38, 3.2243509)
# (39, 3.0772195)
# (40, 3.2120965)
# (41, 3.147949)
# (42, 3.1524174)
# (43, 3.1918831)
# (44, 3.233587)
# (45, 3.176996)
# (46, 3.1698458)
# (47, 3.2410028)
# (48, 3.1657672)
# (49, 3.1807587)
# (50, 3.1397192)
# (51, 3.346359)
# (52, 3.4354134)
# (53, 3.1951363)
# (54, 3.1008649)
# (55, 3.1220298)
# (56, 3.0084913)
# (57, 3.1366887)
# (58, 3.0849607)
# (59, 3.0567176)
# (60, 3.0547316)
# (61, 3.1047087)
# (62, 3.0878172)
# (63, 3.0261414)
# (64, 3.0557971)
# (65, 3.083986)
# (66, 2.9866457)
# (67, 3.0076001)
# (68, 2.9851563)
# (69, 3.1976681)
# (70, 3.338861)
# (71, 3.029536)
# (72, 2.8925583)
# (73, 2.9386156)
# (74, 2.7777548)
# (75, 2.9081242)
# (76, 2.8448501)
# (77, 2.8276534)
# (78, 2.814729)
# (79, 2.84778)
# (80, 2.8183017)
# (81, 2.7476428)
# (82, 2.8147337)
# (83, 2.776314)
# (84, 2.731003)
# (85, 2.7141562)
# (86, 2.913214)
# (87, 3.0691237)
# (88, 3.0401464)
# (89, 2.689755)
# (90, 2.6776788)
# (91, 2.6976345)
# (92, 2.5278432)
# (93, 2.6830711)
# (94, 2.6147168)
# (95, 2.639787)
# (96, 2.6140034)
# (97, 2.6263971)
# (98, 2.6107144)
# (99, 2.5624614)
# (100, 2.6419737)
# (101, 2.5756214)
# (102, 2.5379491)
# (103, 2.5491483)
# (104, 2.8005261)
# (105, 3.009578)
# (106, 2.7879806)
# (107, 2.5227065)
# (108, 2.538939)
# (109, 2.4881356)
# (110, 2.4571223)
# (111, 2.5486341)
# (112, 2.4709802)
# (113, 2.4823849)
# (114, 2.4941418)
# (115, 2.5042179)
# (116, 2.4744434)
# (117, 2.4586778)
# (118, 2.529772)
# (119, 2.4502285)
# (120, 2.43981)
# (121, 2.4126837)
# (122, 2.8034501)
# (123, 2.9487936)
# (124, 2.5573337)
# (125, 2.4385836)
# (126, 2.4519441)
# (127, 2.3195782)
# (128, 2.4802191)
# (129, 2.3813281)
# (130, 2.4336691)
# (131, 2.4097867)
# (132, 2.397073)
# (133, 2.4108899)
# (134, 2.3763247)
# (135, 2.3995852)
# (136, 2.4413064)
# (137, 2.3430114)
# (138, 2.3751125)
# (139, 2.4340503)
# (140, 2.705236)
# (141, 2.9361157)
# (142, 2.3300743)
# (143, 2.3743763)
# (144, 2.3879368)
# (145, 2.2332895)
# (146, 2.4036157)
# (147, 2.307153)
# (148, 2.3586624)
# (149, 2.3396986)
# (150, 2.3329575)
# (151, 2.348341)
# (152, 2.3040297)
# (153, 2.3476)
# (154, 2.3091266)
# (155, 2.2836297)
# (156, 2.254977)
# (157, 2.5059209)
# (158, 2.7091708)
# (159, 2.5940015)
# (160, 2.2595036)
# (161, 2.2869112)
# (162, 2.3332756)
# (163, 2.1500738)
# (164, 2.3117449)
# (165, 2.2376506)
# (166, 2.2649856)
# (167, 2.2502968)
# (168, 2.2511201)
# (169, 2.2788732)
# (170, 2.2222149)
# (171, 2.2843874)
# (172, 2.2349846)
# (173, 2.1912596)
# (174, 2.1878746)
# (175, 2.5027728)
# (176, 2.6796563)
# (177, 2.3452511)
# (178, 2.2624378)
# (179, 2.234005)
# (180, 2.1154332)
# (181, 2.2650399)
# (182, 2.2603137)
# (183, 2.1737797)
# (184, 2.2021778)
# (185, 2.172339)
# (186, 2.20312)
# (187, 2.1913655)
# (188, 2.1630845)
# (189, 2.2191188)
# (190, 2.1670554)
# (191, 2.1490927)
# (192, 2.1132727)
# (193, 2.5677354)
# (194, 2.631741)
# (195, 2.1779068)
# (196, 2.1947134)
# (197, 2.1993041)
# (198, 2.0591247)
# (199, 2.2387974)
# (200, 2.1095734)
# (201, 2.1640093)
# (202, 2.1333864)
# (203, 2.1162641)
# (204, 2.1433651)
# (205, 2.1182492)
# (206, 2.1202378)
# (207, 2.1451242)
# (208, 2.0867543)
# (209, 2.1058998)
# (210, 2.2109261)
# (211, 2.4648983)
# (212, 2.5742061)
# (213, 2.0476043)
# (214, 2.1347351)
# (215, 2.1684787)
# (216, 1.9963623)
# (217, 2.1697226)
# (218, 2.0628984)
# (219, 2.1155529)
# (220, 2.0663595)
# (221, 2.0648236)
# (222, 2.111151)
# (223, 2.0474787)
# (224, 2.0928004)
# (225, 2.0503879)
# (226, 2.0486081)
# (227, 2.0370433)
# (228, 2.2942519)
# (229, 2.4609103)
# (230, 2.3261597)
# (231, 2.0897923)
# (232, 2.090199)
# (233, 2.1143146)
# (234, 1.9730316)
# (235, 2.1260633)
# (236, 2.0186782)
# (237, 2.0585051)
# (238, 2.0136878)
# (239, 2.0284488)
# (240, 2.0611331)
# (241, 1.9978606)
# (242, 2.0649517)
# (243, 2.0100722)
# (244, 2.0099232)
# (245, 1.9794476)
# (246, 2.3528407)
# (247, 2.489291)
# (248, 2.1155808)
# (249, 2.0764754)
# (250, 2.0751603)
# (251, 1.9352614)
# (252, 2.1098895)
# (253, 2.0317416)
# (254, 2.0018039)
# (255, 2.0197434)
# (256, 1.9682711)
# (257, 2.0014112)
# (258, 1.9875844)
# (259, 1.9763844)
# (260, 2.0119979)
# (261, 1.9843732)
# (262, 1.9689715)
# (263, 1.9751871)
# (264, 2.3883679)
# (265, 2.468904)
# (266, 1.9977092)
# (267, 2.0109832)
# (268, 2.0476122)
# (269, 1.903421)
# (270, 2.0792208)
# (271, 1.9412181)
# (272, 1.9900973)
# (273, 1.9545562)
# (274, 1.9514222)
# (275, 1.9613465)
# (276, 1.9491477)
# (277, 1.9512882)
# (278, 1.9464016)
# (279, 1.9325067)
# (280, 1.9115367)
# (281, 2.1329353)
# (282, 2.3117292)
# (283, 2.3465431)
# (284, 1.9123828)
# (285, 1.9984424)
# (286, 2.0142202)
# (287, 1.8516184)
# (288, 2.0242341)
# (289, 1.8885703)
# (290, 1.9714034)
# (291, 1.8981787)
# (292, 1.9121914)
# (293, 1.9477252)
# (294, 1.8870063)
# (295, 1.9332836)
# (296, 1.900352)
# (297, 1.8813477)
# (298, 1.8975093)
# (299, 2.1565566)
# (300, 2.3001788)
# (301, 2.151176)
# (302, 1.9697061)
# (303, 1.9557557)
# (304, 1.9552088)
# (305, 1.8710662)
# (306, 1.9856664)
# (307, 1.8595521)
# (308, 1.9222119)
# (309, 1.8580008)
# (310, 1.8962222)
# (311, 1.8938688)
# (312, 1.8556122)
# (313, 1.9048773)
# (314, 1.8796698)
# (315, 1.8674357)
# (316, 1.852084)
# (317, 2.2123563)
# (318, 2.3378105)
# (319, 1.9721488)
# (320, 1.9484326)
# (321, 1.9421668)
# (322, 1.823653)
# (323, 1.9798563)
# (324, 1.8630162)
# (325, 1.8842031)
# (326, 1.8760059)
# (327, 1.8352766)
# (328, 1.869277)
# (329, 1.8446054)
# (330, 1.8351583)
# (331, 1.8625201)
# (332, 1.8420407)
# (333, 1.8517797)
# (334, 1.932935)
# (335, 2.1573114)
# (336, 2.369638)
# (337, 1.840065)
# (338, 1.9017196)
# (339, 1.9286873)
# (340, 1.787541)
# (341, 1.9475203)
# (342, 1.8091655)
# (343, 1.870808)
# (344, 1.832745)
# (345, 1.8131067)
# (346, 1.8484257)
# (347, 1.8257707)
# (348, 1.8117625)
# (349, 1.8038501)
# (350, 1.8083897)
# (351, 1.805344)
# (352, 2.0357938)
# (353, 2.1690309)
# (354, 2.1833215)
# (355, 1.8225563)
# (356, 1.8849562)
# (357, 1.9191328)
# (358, 1.7521716)
# (359, 1.9060799)
# (360, 1.7741492)
# (361, 1.8495481)
# (362, 1.7894009)
# (363, 1.7839062)
# (364, 1.8387738)
# (365, 1.7735534)
# (366, 1.7990371)
# (367, 1.7879825)
# (368, 1.765801)
# (369, 1.7842)
# (370, 2.0618098)
# (371, 2.1812818)
# (372, 2.0026715)
# (373, 1.8716147)
# (374, 1.8675027)
# (375, 1.7903618)
# (376, 1.8475653)
# (377, 1.8562782)
# (378, 1.7666082)
# (379, 1.8126407)
# (380, 1.7525831)
# (381, 1.7915777)
# (382, 1.7781371)
# (383, 1.74351)
# (384, 1.7769929)
# (385, 1.7707965)
# (386, 1.7557563)
# (387, 1.7557242)
# (388, 2.1137731)
# (389, 2.213886)
# (390, 1.8540338)
# (391, 1.8434514)
# (392, 1.862692)
# (393, 1.7447145)
# (394, 1.885588)
# (395, 1.7404895)
# (396, 1.7963178)
# (397, 1.7625638)
# (398, 1.7427617)
# (399, 1.7650676)
# (400, 1.7468238)
# (401, 1.7155076)
# (402, 1.7450457)
# (403, 1.7464937)
# (404, 1.74672)
# (405, 1.8701059)
# (406, 2.0207362)
# (407, 2.2369466)
# (408, 1.738709)
# (409, 1.828539)
# (410, 1.8457142)
# (411, 1.7013711)
# (412, 1.8486061)
# (413, 1.7090992)
# (414, 1.7707453)
# (415, 1.7385473)
# (416, 1.7117262)
# (417, 1.7643403)
# (418, 1.716741)
# (419, 1.7100903)
# (420, 1.6935039)
# (421, 1.7254773)
# (422, 1.7165239)
# (423, 1.9405338)
# (424, 2.0453329)
# (425, 2.0590339)
# (426, 1.7744429)
# (427, 1.7789719)
# (428, 1.8271285)
# (429, 1.6945207)
# (430, 1.8117434)
# (431, 1.6861722)
# (432, 1.7567309)
# (433, 1.686767)
# (434, 1.6971619)
# (435, 1.7480601)
# (436, 1.6752074)
# (437, 1.7035136)
# (438, 1.6830214)
# (439, 1.6938627)
# (440, 1.6877389)
# (441, 1.9747761)
# (442, 2.1070678)
# (443, 1.8768473)
# (444, 1.7838101)
# (445, 1.7795284)
# (446, 1.6967629)
# (447, 1.812951)
# (448, 1.7448504)
# (449, 1.7032501)
# (450, 1.7266356)
# (451, 1.6579878)
# (452, 1.7118303)
# (453, 1.6786913)
# (454, 1.6625621)
# (455, 1.6782407)
# (456, 1.6818377)
# (457, 1.6879271)
# (458, 1.6886488)
# (459, 1.9999101)
# (460, 2.1214602)
# (461, 1.7733319)
# (462, 1.7554237)
# (463, 1.7765336)
# (464, 1.6759722)
# (465, 1.8050539)
# (466, 1.6625526)
# (467, 1.7160707)
# (468, 1.6799586)
# (469, 1.6561083)
# (470, 1.6869074)
# (471, 1.6654012)
# (472, 1.6387606)
# (473, 1.6500951)
# (474, 1.6533347)
# (475, 1.6579348)
# (476, 1.8351172)
# (477, 1.9311812)
# (478, 2.0856309)
# (479, 1.670875)
# (480, 1.7519422)
# (481, 1.7709645)
# (482, 1.6288823)
# (483, 1.7642027)
# (484, 1.63157)
# (485, 1.7053715)
# (486, 1.6425234)
# (487, 1.6284137)
# (488, 1.6945035)
# (489, 1.6285299)
# (490, 1.6395508)
# (491, 1.6083542)
# (492, 1.6301658)
# (493, 1.647818)
# (494, 1.850988)
# (495, 1.9561781)
# (496, 1.9409959)
# (497, 1.7198523)
# (498, 1.7177126)
# (499, 1.7439775)
# (500, 1.6296885)
# ['n waise the wocse was sheateng  ah shet ser hn nton the ', 'chil tas sh e h ng tite thes  "-', '\r', '"          Ior  whid th ', '                souse  ahet ', 's                  e waa tn ahe ', 'c                      eure  atin ', '                         n teth to ', '                           h mos  "I\' ', '                              htl arome -', '                               or noiou   \r\r', '\r                             aue  a ml ', '                            hre totaoa-', '                          otl  "hr', '                      ost oede ', '                  he whoet  ', '               ou aeat   ', '              hes woweet', '            nd a me ', '           ot eng ', '            h so  \r', '\r            ond the ', '              eut  wh ', 't              he wore ', '                  nh a ', 's                host  aoar ', '                   ete ahth ', '                    ouwust ', '                        museen ', '                        hutd ', 't                        u tas e-', '                        nduaft ', 'a                      uoat e\r', '', '\r                       l ae ', '                    us en ', '                   ml ae ', '                uss  "', '              hid ', '            ort-', '           otg ', '             l ', '             or   ', '                 l ', '                 ho ', '                  he ', '                   hiue ', '                    onte  ', '                         d ', '                      oud-', '                   oaeo', '               ou mh ', '             oar e \r', '\r', '"Iou m d aot a  er  ng " said the Mocse wh tlice aaeer dy \r"Ihat  nd wou ', 'ahesg ng tf " ', '\r', '"I degatou  tareen   said tlice wery harpee  "Iou mad to  th she worpe ', ' e    a whesk " ', '\r', '"I dad tnot  " saied the wouse  and enl \r', '\r', '"Indnow " said tlice  anl s  aead  ao tete tar elf ap  or  and tiokeng ', 'tndeons y wnout ter  "If  ao siatha warl oh tpdertt " ', '\r', '"I daetl w ntot  ng tf the waue   said the Mocse  aot ing tp and tasl ng ', 'tnas  "Iou mn trl ta ae ahik ng torheaot e t  " ', '\r', '"I dos \'t sa d tt " saias d took alice \r"Iut tou s  wh svttny af  rt d  ', ' ou snow " ', 't', '"he Mouse wf y woow y  tn aeali \r', '\r', '"Iraase woue oetk and tordn  aou  thome " slice wonl d tn er tn \r"nd the ', 'cnher  wnl turng  at aaauese aIor  aooase wow" sut the Mocse wf y wheuke', ' t  aard tn etind ee wnd tasl d tnlittle suite d \r', '\r', '"Ihat s sant an aarld  t shat " sath   the wicg  an sh n a  tt tas suite ', 'tft tn thmht  and t dtfl taombah   ahe wneor  ntni af thi ng ah ter ', 'wodtht    aIn  wu s  r "Iet whes wega liat n ah tou coaer ah siot ', ' tou   whrp r " sIowe wou  sh eetd aor  Aaid the Moutdetaomb andittle ', 'thoteen  y \r"Iou de wxtwsh th shi ahe wortnn e tf t dtf e r " ', '\r', '"I dath a mad tntetungt aar   a wnow w won" said tlice w lut  andeee  ng ', 'toteu  at aarsinel ry\r"Ioe s th n aoe e an tetk " ', '\r', '"Ind tai ht aungt  an a mosht tert re th t  ethe wueet on " said the ', ' oug  ', '\r', '"lice wealecd tvte  y  aor the sas s l s  ooad  ao thik onout aer haa  ', ' Iongt s sft ton  "nd she s ahrh a lanen i wf  oor aon e ng tash  aou ', 'sons t shesk ""ld tn  a wath aou could the oar hn er the wetge ""hi  ', ' he s  wvt t little seteet  th n a  tiokeat tt " ', '\r', '"hes wheanh aonse  tnleaark noe wheteiion a  u  the wore  \r"h e tf the ', 'cetee aarsind af  t  tn e  an  wfd tareennwe an tiitpeng an  rf tp aery ', 'tone ur y  aeaerk ng aI weadl  wast te aot eng te e  ahe wotht -nn ', 'aowd et shrd ta aheeugh" snd t satdte worled tft tt a mhoapeing aeuce ao ', 'tt  aoasd edttIame t ay  au soad   "  s sash thme tou cane dnl tt ae a" ', '\rh teiknus aaoa nt  aoe  wnl tare  af   and tlice aas sh n aiat onlug \r', '\r', '"I dath a met  t sa eeon d auttte" sae said th ter elf an a moaarde u  ', ' h e \r"Ioweu  whe e ao tite tar  ao n te    and t m aare the s ahe wegt ', 'tonein ahe warkd "" ...
# (501, 1.737548)
# (502, 1.6180545)
# (503, 1.6825744)
# (504, 1.6031282)
# (505, 1.6324309)
# (506, 1.6519762)
# (507, 1.6128908)
# (508, 1.624015)
# (509, 1.6058375)
# (510, 1.6232285)
# (511, 1.611517)
# (512, 1.878864)
# (513, 2.0230153)
# (514, 1.7680707)
# (515, 1.7319926)
# (516, 1.723652)
# (517, 1.627344)
# (518, 1.7495019)
# (519, 1.6383224)
# (520, 1.6382506)
# (521, 1.6475617)
# (522, 1.5872282)
# (523, 1.6313652)
# (524, 1.6058521)
# (525, 1.5952916)
# (526, 1.5982523)
# (527, 1.6098499)
# (528, 1.6062049)
# (529, 1.686606)
# (530, 1.8439779)
# (531, 2.0635679)
# (532, 1.6740304)
# (533, 1.6806326)
# (534, 1.726632)
# (535, 1.6002312)
# (536, 1.7311789)
# (537, 1.590306)
# (538, 1.6512877)
# (539, 1.6051718)
# (540, 1.5803097)
# (541, 1.6254799)
# (542, 1.5955361)
# (543, 1.584435)
# (544, 1.5580685)
# (545, 1.5812317)
# (546, 1.5816729)
# (547, 1.7919579)
# (548, 1.8392766)
# (549, 1.9771373)
# (550, 1.6275017)
# (551, 1.6842625)
# (552, 1.7175103)
# (553, 1.5624106)
# (554, 1.7035735)
# (555, 1.5659004)
# (556, 1.6478976)
# (557, 1.5662756)
# (558, 1.5601156)
# (559, 1.6330291)
# (560, 1.5636261)
# (561, 1.5662844)
# (562, 1.5562304)
# (563, 1.5526878)
# (564, 1.5823513)
# (565, 1.7836488)
# (566, 1.8757857)
# (567, 1.8397539)
# (568, 1.6801449)
# (569, 1.672834)
# (570, 1.6332237)
# (571, 1.6289192)
# (572, 1.6482582)
# (573, 1.5715027)
# (574, 1.6203464)
# (575, 1.5329648)
# (576, 1.5837431)
# (577, 1.5761721)
# (578, 1.5438371)
# (579, 1.5620397)
# (580, 1.546566)
# (581, 1.5490254)
# (582, 1.5583127)
# (583, 1.8159593)
# (584, 1.9569625)
# (585, 1.6858534)
# (586, 1.6683191)
# (587, 1.6662995)
# (588, 1.5828887)
# (589, 1.6945776)
# (590, 1.5511379)
# (591, 1.5886072)
# (592, 1.580189)
# (593, 1.5343077)
# (594, 1.5701571)
# (595, 1.5430096)
# (596, 1.5319054)
# (597, 1.5372435)
# (598, 1.5462401)
# (599, 1.5359439)
# (600, 1.66478)
# (601, 1.7159867)
# (602, 2.0146248)
# (603, 1.5886484)
# (604, 1.6543852)
# (605, 1.6582531)
# (606, 1.5458512)
# (607, 1.6673067)
# (608, 1.5216165)
# (609, 1.583258)
# (610, 1.5596206)
# (611, 1.505506)
# (612, 1.5803401)
# (613, 1.5364084)
# (614, 1.5191662)
# (615, 1.5005968)
# (616, 1.5242363)
# (617, 1.5238428)
# (618, 1.7208769)
# (619, 1.7863314)
# (620, 1.8674353)
# (621, 1.5928298)
# (622, 1.6171848)
# (623, 1.6639119)
# (624, 1.5315586)
# (625, 1.643409)
# (626, 1.5067754)
# (627, 1.5811006)
# (628, 1.503793)
# (629, 1.5035123)
# (630, 1.5751146)
# (631, 1.5069116)
# (632, 1.503132)
# (633, 1.503204)
# (634, 1.4977193)
# (635, 1.5129657)
# (636, 1.7312973)
# (637, 1.8471793)
# (638, 1.7139428)
# (639, 1.6261886)
# (640, 1.6190387)
# (641, 1.5425551)
# (642, 1.6254845)
# (643, 1.5870186)
# (644, 1.5251449)
# (645, 1.5569508)
# (646, 1.4775717)
# (647, 1.5329515)
# (648, 1.5007772)
# (649, 1.4873888)
# (650, 1.4955854)
# (651, 1.5018109)
# (652, 1.4951695)
# (653, 1.5202253)
# (654, 1.7384505)
# (655, 1.8973967)
# (656, 1.6112473)
# (657, 1.6056893)
# (658, 1.6221217)
# (659, 1.5305858)
# (660, 1.638396)
# (661, 1.4920987)
# (662, 1.5458846)
# (663, 1.516176)
# (664, 1.4785188)
# (665, 1.5226754)
# (666, 1.4861096)
# (667, 1.4832343)
# (668, 1.4654144)
# (669, 1.487107)
# (670, 1.480479)
# (671, 1.6596344)
# (672, 1.6478699)
# (673, 1.911925)
# (674, 1.529321)
# (675, 1.5970672)
# (676, 1.6240714)
# (677, 1.4911467)
# (678, 1.6131421)
# (679, 1.464481)
# (680, 1.5429263)
# (681, 1.4820065)
# (682, 1.457737)
# (683, 1.539315)
# (684, 1.4673586)
# (685, 1.4771653)
# (686, 1.4447457)
# (687, 1.4656302)
# (688, 1.4790434)
# (689, 1.6553879)
# (690, 1.7284328)
# (691, 1.7753481)
# (692, 1.5720748)
# (693, 1.5665134)
# (694, 1.6078799)
# (695, 1.4847449)
# (696, 1.5826865)
# (697, 1.4581988)
# (698, 1.5312641)
# (699, 1.4443678)
# (700, 1.46734)
# (701, 1.4996279)
# (702, 1.4515374)
# (703, 1.4719076)
# (704, 1.4418739)
# (705, 1.4562312)
# (706, 1.4560654)
# (707, 1.6632379)
# (708, 1.8132383)
# (709, 1.6275777)
# (710, 1.5810777)
# (711, 1.5749052)
# (712, 1.4929848)
# (713, 1.6059216)
# (714, 1.4935776)
# (715, 1.4762211)
# (716, 1.4982923)
# (717, 1.4364173)
# (718, 1.4823735)
# (719, 1.4441963)
# (720, 1.4497243)
# (721, 1.4410546)
# (722, 1.4533786)
# (723, 1.4469835)
# (724, 1.5159297)
# (725, 1.6414516)
# (726, 1.858218)
# (727, 1.5538802)
# (728, 1.5422397)
# (729, 1.5806186)
# (730, 1.4748963)
# (731, 1.590425)
# (732, 1.4391582)
# (733, 1.4995447)
# (734, 1.4645469)
# (735, 1.4298179)
# (736, 1.4789829)
# (737, 1.4431787)
# (738, 1.4394259)
# (739, 1.4108086)
# (740, 1.437245)
# (741, 1.4251211)
# (742, 1.6332325)
# (743, 1.6248562)
# (744, 1.8132089)
# (745, 1.4936829)
# (746, 1.5504136)
# (747, 1.5783246)
# (748, 1.4436635)
# (749, 1.5653654)
# (750, 1.4156381)
# (751, 1.5041546)
# (752, 1.4324031)
# (753, 1.4187219)
# (754, 1.4875118)
# (755, 1.4255319)
# (756, 1.4254928)
# (757, 1.4066056)
# (758, 1.4068881)
# (759, 1.4442909)
# (760, 1.6110855)
# (761, 1.6766109)
# (762, 1.699366)
# (763, 1.5505668)
# (764, 1.5295055)
# (765, 1.5324839)
# (766, 1.4729404)
# (767, 1.5180039)
# (768, 1.43075)
# (769, 1.4848176)
# (770, 1.3906217)
# (771, 1.4452168)
# (772, 1.4307358)
# (773, 1.4110132)
# (774, 1.4203321)
# (775, 1.4008645)
# (776, 1.4186512)
# (777, 1.4225343)
# (778, 1.6117181)
# (779, 1.7691213)
# (780, 1.565585)
# (781, 1.5426904)
# (782, 1.5292265)
# (783, 1.4600254)
# (784, 1.550216)
# (785, 1.4300345)
# (786, 1.4390895)
# (787, 1.4542034)
# (788, 1.391768)
# (789, 1.4431508)
# (790, 1.3922826)
# (791, 1.4078609)
# (792, 1.3912704)
# (793, 1.4105272)
# (794, 1.4024898)
# (795, 1.5263658)
# (796, 1.5234426)
# (797, 1.8287121)
# (798, 1.4843223)
# (799, 1.512995)
# (800, 1.5389153)
# (801, 1.4220135)
# (802, 1.5283145)
# (803, 1.3894813)
# (804, 1.4513361)
# (805, 1.4245391)
# (806, 1.3781998)
# (807, 1.4445792)
# (808, 1.4029574)
# (809, 1.387041)
# (810, 1.3662004)
# (811, 1.3813415)
# (812, 1.3935721)
# (813, 1.5687816)
# (814, 1.5944141)
# (815, 1.724376)
# (816, 1.4610742)
# (817, 1.4966161)
# (818, 1.5430205)
# (819, 1.4041938)
# (820, 1.5072062)
# (821, 1.370193)
# (822, 1.4567587)
# (823, 1.3773764)
# (824, 1.3780513)
# (825, 1.4420196)
# (826, 1.3808581)
# (827, 1.3755039)
# (828, 1.3758669)
# (829, 1.3657471)
# (830, 1.3885461)
# (831, 1.5613714)
# (832, 1.6391307)
# (833, 1.5999146)
# (834, 1.5149611)
# (835, 1.4937752)
# (836, 1.4411004)
# (837, 1.4813657)
# (838, 1.4516194)
# (839, 1.3933563)
# (840, 1.4318628)
# (841, 1.3551135)
# (842, 1.4103061)
# (843, 1.3766119)
# (844, 1.3678507)
# (845, 1.3736261)
# (846, 1.3732132)
# (847, 1.3667816)
# (848, 1.3943009)
# (849, 1.5557075)
# (850, 1.7101035)
# (851, 1.5058128)
# (852, 1.4938865)
# (853, 1.4998939)
# (854, 1.4204059)
# (855, 1.5018396)
# (856, 1.371953)
# (857, 1.4126314)
# (858, 1.3980938)
# (859, 1.357501)
# (860, 1.4087353)
# (861, 1.356717)
# (862, 1.3586968)
# (863, 1.3474064)
# (864, 1.3672742)
# (865, 1.358199)
# (866, 1.5061035)
# (867, 1.4725271)
# (868, 1.7558154)
# (869, 1.4252177)
# (870, 1.4824512)
# (871, 1.5054225)
# (872, 1.3785385)
# (873, 1.4835049)
# (874, 1.3442942)
# (875, 1.4108645)
# (876, 1.371034)
# (877, 1.3467901)
# (878, 1.4157115)
# (879, 1.3506366)
# (880, 1.3558551)
# (881, 1.3265921)
# (882, 1.3498399)
# (883, 1.3547437)
# (884, 1.517211)
# (885, 1.5573803)
# (886, 1.642159)
# (887, 1.4576721)
# (888, 1.4518709)
# (889, 1.4902325)
# (890, 1.3771181)
# (891, 1.4537653)
# (892, 1.3471609)
# (893, 1.4151677)
# (894, 1.3323078)
# (895, 1.3517237)
# (896, 1.3898304)
# (897, 1.3347887)
# (898, 1.3555846)
# (899, 1.327099)
# (900, 1.3355621)
# (901, 1.3449184)
# (902, 1.5113318)
# (903, 1.625506)
# (904, 1.5221088)
# (905, 1.472056)
# (906, 1.4603449)
# (907, 1.3900191)
# (908, 1.4768854)
# (909, 1.3813415)
# (910, 1.3681146)
# (911, 1.390838)
# (912, 1.3200457)
# (913, 1.3825442)
# (914, 1.3211704)
# (915, 1.3388907)
# (916, 1.3359972)
# (917, 1.3310336)
# (918, 1.3307341)
# (919, 1.3886704)
# (920, 1.4840094)
# (921, 1.6621614)
# (922, 1.4700099)
# (923, 1.440766)
# (924, 1.4625872)
# (925, 1.3804017)
# (926, 1.4610209)
# (927, 1.3356707)
# (928, 1.3766437)
# (929, 1.3534385)
# (930, 1.3229568)
# (931, 1.370934)
# (932, 1.3220289)
# (933, 1.3413544)
# (934, 1.3022586)
# (935, 1.3209167)
# (936, 1.3082111)
# (937, 1.4938462)
# (938, 1.4493411)
# (939, 1.6616275)
# (940, 1.3860124)
# (941, 1.4539125)
# (942, 1.4634023)
# (943, 1.3400198)
# (944, 1.4435452)
# (945, 1.3072045)
# (946, 1.378577)
# (947, 1.3202373)
# (948, 1.3146657)
# (949, 1.3774079)
# (950, 1.3079329)
# (951, 1.3246459)
# (952, 1.2936428)
# (953, 1.301138)
# (954, 1.3316998)
# (955, 1.4585768)
# (956, 1.511724)
# (957, 1.5577126)
# (958, 1.4409453)
# (959, 1.4236356)
# (960, 1.4469877)
# (961, 1.3463604)
# (962, 1.4091914)
# (963, 1.3201861)
# (964, 1.3697096)
# (965, 1.2851024)
# (966, 1.3375183)
# (967, 1.327738)
# (968, 1.3096386)
# (969, 1.3175598)
# (970, 1.2957274)
# (971, 1.3061782)
# (972, 1.3135227)
# (973, 1.4430469)
# (974, 1.5914782)
# (975, 1.4490612)
# (976, 1.4447839)
# (977, 1.4304253)
# (978, 1.3603672)
# (979, 1.4401195)
# (980, 1.3321363)
# (981, 1.3300339)
# (982, 1.3425676)
# (983, 1.2854779)
# (984, 1.3476214)
# (985, 1.2793883)
# (986, 1.3078496)
# (987, 1.2934719)
# (988, 1.3075207)
# (989, 1.2939534)
# (990, 1.3989164)
# (991, 1.3773246)
# (992, 1.6445808)
# (993, 1.398468)
# (994, 1.4073142)
# (995, 1.4461082)
# (996, 1.3386531)
# (997, 1.4181532)
# (998, 1.2903337)
# (999, 1.345638)
# (1000, 1.3163928)
# ['  the sery  ', ' nd sot th sers ah she wh k toprsle  and sant on t ain  ', ' ', '"I dod \'t bnow whet saerhine dons a lays aoentid  an aact  a codn\'t bnow ', ' het shns atomld  soong"\r', '\r', '"Ihey wll san   said the Mo h ss  "and turt tf t vpao "\r', '\r', '"I don\'t bnow wf t y mhet sow  slice said tery sloieedy  aoll ng tutne ', 'tlaase  to heve tot tn o t lontersation \r', '\r', '"Iou mon\'t bnow wush   said the Mochess  "and thet t s lure \r\r', '\r', '"lice sid not t  tll tike ahe thue of thes wemark  and sheught tt wauld ', 'se a  sell shutt oewicedth e tfher socbect tf toudersations\r"hile she ', 'sas soiing to tin tf tne  ahe wouk oh   the wansd eugaf thmntof  the ', 'cirss and sn tnee toe th serk aheou ng avery hing ahth ngaer hemdh tn ', 'h e wochess snd she sery --he worss-nets wone aonst  ahe  serlowed at', 'coeuedeof thych pnd  aeesed  and tosted \r"herMochess so k totsot cedtf ', 'the  axer sien she  was saae and the lery sis sew yng ao math a ledd   ', ' het st was auite atport nle ao hey thin er she seaw  aerr in wf tot \r', '\r', '"Ih, wIlease   onu thet sou re aonng " soied Alice  "uspeng ap and sown ', 'tn a  anane tf thlmiut "Ih, whe e wotd oen ttroaatus  aote   tn snd', 'tsdshrl y airge ahidh ln aoas thase ty tt  and sery searly aondied on ', 'an  \r', '\r', '"I  yvery edy sand d the r sfnetetingss   she Mochess shid tn a laudsh ', 'teewiy athe Morkd iauli so doond tnloar fort r thet it wows \r\r', '\r', '"Illustration  "Indanoserl y airge ahydh ln aoas thase ty tt  and sery ', 'learly aondied on af   \r', '\r', '"Ihath harld bhot  we a ya dendere   said tlice. "ho hiet  ery soad to ', 'tot i dafeortanity if theu ng of  anlittle sf ter hnew ed ed\r"Tust sheng ', 'hhet sauk it would bake tith the soy and sosht "Iou kee ihe Mnrdh ', ' hke  ahont  -out teurseio shrneaeund if tt   n ot---"\r', '\r', '"Ihlking af t e    said the Mochess  aaoauiaf  aer head \r\r', '\r', '"lice doadge  tother tndioutey an the souk  ah see it ihe haan  to thke ', ' he tamd  aut she touk ois tetiny avoered tn atalning ahe tonnt and tod ', 'tot ahemeto te aiktensng  ah she werd red to ho dn t ain  "Ihe t  -out ', 'heusse a tthesk   an at at woonles"I ---"\r', '\r', '"If  won\'t beth r swua " said the Mochess  "a dever sould b ot  ', '\rirhres " snd shth ahet she hegan tonseng aer hoind hnain  aold ng an', 'somt of tisl rl to st w  she dod no  and soveng tt a lellent theledt  ', 'the snd of txerytlikks ', ' ', '           Ioeak wounhte sh soutttittle sets ', '             nd wegthses sien sersaeeded  ', '\r          e dfey siws an wo g yow  ', '             eaouse tercnow  wn woansd \r\r', '\r', '"ooRTTT', '\r', '            n woith whe pouk otd the bery tuin d   ', '\r          Ihn  Ion  Ion   ', '\r', '"hile the Muchess shid ihe sontnd oeryedof the tond  ahe wnpt th   ng ', 'the tery tellent y ap and sown  and the laor oittle shang sew ed to  ', ' het slice aould navd y sard ahe sords  ', '\r', '           Indhoak toeeredy so he tets ', '             ndegn ses sien sersaeezed  ', '           or teacon oheueugh y svoeus', 'a            he warper aien se slaased "\r', '\r', '"          hoRTTT\r', '\r', '           Ih   Ion  Ion   ', '\r', '"Io e "Iou day tossedtt w let wn sou cike " she Muchess shid to tlice  ', ' ieegeng aoe teny tn ter hn she whoke \r"I wust bo dnd sot temd  to hrey ', ' oosuet aith ahe tueen    nd she warried tft of the ceom \r"he Mauk oheoe ', 'hnlai ng torcanter ter hn she want ont  aut st wust wugted ters\r', '\r', '"lice donlht ioe teny tith thme todfenult   an st was s luesr -hanpd ', 'aittle sooatur   and terd tft tt  lne  and soss tn a l tosedtion   aIust ', 'aete t loark-onh   sheught Alice \r"herMauk siktle shing sas soeweing ', 'aeke t loarr -ncengsthen she wonlht it  and snet townleng tt  lf ap and ', 'thaanlhtedeng at  lf aft t ain  ao shet s legether  aor she sirst sanute ', 'tf aho  at was a  sesh  n she would no nh seud it \r', '\r', '"l sh n s  she sad nade oft ooe tooser ahs an torseng at   ...
# (1001, 1.2828879)
# (1002, 1.3384041)
# (1003, 1.2920671)
# (1004, 1.2995478)
# (1005, 1.2702318)
# (1006, 1.2824723)
# (1007, 1.2884047)
# (1008, 1.4529178)
# (1009, 1.4152987)
# (1010, 1.5978817)
# (1011, 1.3471564)
# (1012, 1.4072975)
# (1013, 1.4417737)
# (1014, 1.309523)
# (1015, 1.409923)
# (1016, 1.2768416)
# (1017, 1.3446056)
# (1018, 1.275622)
# (1019, 1.2793477)
# (1020, 1.3303157)
# (1021, 1.2828717)
# (1022, 1.278179)
# (1023, 1.270355)
# (1024, 1.2730832)
# (1025, 1.2984184)
# (1026, 1.4265745)
# (1027, 1.4795805)
# (1028, 1.4815141)
# (1029, 1.4167218)
# (1030, 1.3990368)
# (1031, 1.3649695)
# (1032, 1.3612318)
# (1033, 1.3547215)
# (1034, 1.2995626)
# (1035, 1.3365364)
# (1036, 1.2591463)
# (1037, 1.3090667)
# (1038, 1.2733769)
# (1039, 1.2740005)
# (1040, 1.2778629)
# (1041, 1.2707573)
# (1042, 1.2697554)
# (1043, 1.3064243)
# (1044, 1.4062757)
# (1045, 1.5700798)
# (1046, 1.3903146)
# (1047, 1.3997097)
# (1048, 1.3998977)
# (1049, 1.3262906)
# (1050, 1.3999507)
# (1051, 1.2822794)
# (1052, 1.3190407)
# (1053, 1.3014334)
# (1054, 1.2639134)
# (1055, 1.3090175)
# (1056, 1.2570344)
# (1057, 1.263587)
# (1058, 1.249647)
# (1059, 1.2771437)
# (1060, 1.2611922)
# (1061, 1.389842)
# (1062, 1.3314657)
# (1063, 1.6219461)
# (1064, 1.3384484)
# (1065, 1.3900123)
# (1066, 1.399327)
# (1067, 1.2830173)
# (1068, 1.3810598)
# (1069, 1.255581)
# (1070, 1.305689)
# (1071, 1.2922764)
# (1072, 1.2551208)
# (1073, 1.3117334)
# (1074, 1.2591887)
# (1075, 1.2594974)
# (1076, 1.2377734)
# (1077, 1.2501945)
# (1078, 1.2589992)
# (1079, 1.3963922)
# (1080, 1.4133635)
# (1081, 1.5252479)
# (1082, 1.3556007)
# (1083, 1.3680754)
# (1084, 1.3901689)
# (1085, 1.2820994)
# (1086, 1.3562371)
# (1087, 1.2455945)
# (1088, 1.311506)
# (1089, 1.2431033)
# (1090, 1.2523714)
# (1091, 1.3024462)
# (1092, 1.2583029)
# (1093, 1.2483736)
# (1094, 1.2401905)
# (1095, 1.2319424)
# (1096, 1.2652498)
# (1097, 1.3814809)
# (1098, 1.4793894)
# (1099, 1.4086018)
# (1100, 1.3961642)
# (1101, 1.3725529)
# (1102, 1.3055385)
# (1103, 1.3637066)
# (1104, 1.3062072)
# (1105, 1.2759596)
# (1106, 1.3026026)
# (1107, 1.2316144)
# (1108, 1.2903147)
# (1109, 1.2313936)
# (1110, 1.2578944)
# (1111, 1.241433)
# (1112, 1.2429951)
# (1113, 1.2425299)
# (1114, 1.2844967)
# (1115, 1.3572887)
# (1116, 1.5219473)
# (1117, 1.362676)
# (1118, 1.36853)
# (1119, 1.3752344)
# (1120, 1.2892369)
# (1121, 1.376351)
# (1122, 1.2418945)
# (1123, 1.287576)
# (1124, 1.2706616)
# (1125, 1.2332571)
# (1126, 1.277478)
# (1127, 1.2334836)
# (1128, 1.2426059)
# (1129, 1.2248877)
# (1130, 1.2361199)
# (1131, 1.2293878)
# (1132, 1.3835455)
# (1133, 1.3144875)
# (1134, 1.5380334)
# (1135, 1.3056724)
# (1136, 1.3688686)
# (1137, 1.375877)
# (1138, 1.2553155)
# (1139, 1.3574001)
# (1140, 1.2246397)
# (1141, 1.2843895)
# (1142, 1.251086)
# (1143, 1.2244723)
# (1144, 1.2786058)
# (1145, 1.2307361)
# (1146, 1.2438227)
# (1147, 1.2030556)
# (1148, 1.2133425)
# (1149, 1.2467685)
# (1150, 1.3493277)
# (1151, 1.3964708)
# (1152, 1.444075)
# (1153, 1.3467497)
# (1154, 1.3359637)
# (1155, 1.3575422)
# (1156, 1.2571906)
# (1157, 1.3211681)
# (1158, 1.2300811)
# (1159, 1.2869469)
# (1160, 1.213235)
# (1161, 1.2423898)
# (1162, 1.2418903)
# (1163, 1.2271553)
# (1164, 1.2342199)
# (1165, 1.206214)
# (1166, 1.2158109)
# (1167, 1.2313316)
# (1168, 1.3316851)
# (1169, 1.472082)
# (1170, 1.3468205)
# (1171, 1.3624252)
# (1172, 1.3487967)
# (1173, 1.2727661)
# (1174, 1.3506954)
# (1175, 1.250335)
# (1176, 1.2469658)
# (1177, 1.2665893)
# (1178, 1.2171187)
# (1179, 1.261637)
# (1180, 1.1955485)
# (1181, 1.2257949)
# (1182, 1.2104053)
# (1183, 1.2178681)
# (1184, 1.2051661)
# (1185, 1.2983338)
# (1186, 1.2924591)
# (1187, 1.4976089)
# (1188, 1.3150927)
# (1189, 1.3207515)
# (1190, 1.3456552)
# (1191, 1.2563496)
# (1192, 1.3298221)
# (1193, 1.2157922)
# (1194, 1.2592329)
# (1195, 1.2404917)
# (1196, 1.2108589)
# (1197, 1.2543272)
# (1198, 1.2010342)
# (1199, 1.2207304)
# (1200, 1.1812049)
# (1201, 1.2004825)
# (1202, 1.2007464)
# (1203, 1.350809)
# (1204, 1.2945368)
# (1205, 1.481817)
# (1206, 1.2694377)
# (1207, 1.3286021)
# (1208, 1.3461435)
# (1209, 1.2202166)
# (1210, 1.3241186)
# (1211, 1.1907789)
# (1212, 1.2613933)
# (1213, 1.2076745)
# (1214, 1.2086594)
# (1215, 1.2441552)
# (1216, 1.2044038)
# (1217, 1.1984591)
# (1218, 1.1694478)
# (1219, 1.1875365)
# (1220, 1.2192019)
# (1221, 1.3106689)
# (1222, 1.3445718)
# (1223, 1.3894016)
# (1224, 1.330093)
# (1225, 1.3173256)
# (1226, 1.2892168)
# (1227, 1.2580613)
# (1228, 1.2727821)
# (1229, 1.217952)
# (1230, 1.2501774)
# (1231, 1.181985)
# (1232, 1.2299631)
# (1233, 1.2009701)
# (1234, 1.1976111)
# (1235, 1.1976061)
# (1236, 1.1753556)
# (1237, 1.196278)
# (1238, 1.2149318)
# (1239, 1.2887969)
# (1240, 1.4253218)
# (1241, 1.3067799)
# (1242, 1.3248695)
# (1243, 1.3153428)
# (1244, 1.245731)
# (1245, 1.3134698)
# (1246, 1.2111511)
# (1247, 1.2226691)
# (1248, 1.2308704)
# (1249, 1.1904409)
# (1250, 1.2293876)
# (1251, 1.1648951)
# (1252, 1.2007849)
# (1253, 1.1762998)
# (1254, 1.1928997)
# (1255, 1.1675555)
# (1256, 1.3000497)
# (1257, 1.2077199)
# (1258, 1.4783467)
# (1259, 1.2691475)
# (1260, 1.3124051)
# (1261, 1.3137408)
# (1262, 1.2094601)
# (1263, 1.298808)
# (1264, 1.1723043)
# (1265, 1.2246525)
# (1266, 1.2174449)
# (1267, 1.1802415)
# (1268, 1.2269987)
# (1269, 1.1804492)
# (1270, 1.1852868)
# (1271, 1.1609018)
# (1272, 1.1552609)
# (1273, 1.1815902)
# (1274, 1.2972195)
# (1275, 1.294071)
# (1276, 1.4114107)
# (1277, 1.2640524)
# (1278, 1.2854925)
# (1279, 1.3133729)
# (1280, 1.1971376)
# (1281, 1.2860167)
# (1282, 1.1704836)
# (1283, 1.2338359)
# (1284, 1.1743467)
# (1285, 1.1814723)
# (1286, 1.2250522)
# (1287, 1.17361)
# (1288, 1.1814022)
# (1289, 1.1454154)
# (1290, 1.1508818)
# (1291, 1.1893382)
# (1292, 1.2781881)
# (1293, 1.3450855)
# (1294, 1.3133973)
# (1295, 1.3208567)
# (1296, 1.2963674)
# (1297, 1.2339541)
# (1298, 1.2737921)
# (1299, 1.2289889)
# (1300, 1.1990105)
# (1301, 1.2228111)
# (1302, 1.1549551)
# (1303, 1.2123735)
# (1304, 1.1558323)
# (1305, 1.1839824)
# (1306, 1.1635593)
# (1307, 1.1653827)
# (1308, 1.1502295)
# (1309, 1.20802)
# (1310, 1.2327237)
# (1311, 1.4073473)
# (1312, 1.2612475)
# (1313, 1.2924643)
# (1314, 1.3107276)
# (1315, 1.2115365)
# (1316, 1.2868458)
# (1317, 1.1706469)
# (1318, 1.196491)
# (1319, 1.1959558)
# (1320, 1.1595803)
# (1321, 1.1939089)
# (1322, 1.1457877)
# (1323, 1.1752083)
# (1324, 1.13895)
# (1325, 1.1622783)
# (1326, 1.1377635)
# (1327, 1.2813976)
# (1328, 1.1774857)
# (1329, 1.4306294)
# (1330, 1.2191045)
# (1331, 1.278685)
# (1332, 1.3028153)
# (1333, 1.1876842)
# (1334, 1.2741764)
# (1335, 1.1447123)
# (1336, 1.1926423)
# (1337, 1.1670243)
# (1338, 1.1459668)
# (1339, 1.1967189)
# (1340, 1.1479161)
# (1341, 1.160782)
# (1342, 1.1296151)
# (1343, 1.1351761)
# (1344, 1.1627274)
# (1345, 1.2430527)
# (1346, 1.2697906)
# (1347, 1.3289614)
# (1348, 1.2578162)
# (1349, 1.2479913)
# (1350, 1.2778393)
# (1351, 1.1825038)
# (1352, 1.2459025)
# (1353, 1.1455253)
# (1354, 1.2062262)
# (1355, 1.1326559)
# (1356, 1.1464285)
# (1357, 1.171892)
# (1358, 1.1429198)
# (1359, 1.1559464)
# (1360, 1.1128556)
# (1361, 1.1369779)
# (1362, 1.1569113)
# (1363, 1.2222298)
# (1364, 1.3309385)
# (1365, 1.2396657)
# (1366, 1.2602915)
# (1367, 1.2584676)
# (1368, 1.1875798)
# (1369, 1.2696629)
# (1370, 1.1738685)
# (1371, 1.1723623)
# (1372, 1.1786405)
# (1373, 1.1255517)
# (1374, 1.1694082)
# (1375, 1.1131017)
# (1376, 1.1514188)
# (1377, 1.120798)
# (1378, 1.1251895)
# (1379, 1.1274835)
# (1380, 1.2081577)
# (1381, 1.1811397)
# (1382, 1.3516138)
# (1383, 1.2113093)
# (1384, 1.2335547)
# (1385, 1.2574346)
# (1386, 1.1719209)
# (1387, 1.2407998)
# (1388, 1.1278979)
# (1389, 1.1783499)
# (1390, 1.1562023)
# (1391, 1.1196475)
# (1392, 1.1571269)
# (1393, 1.1253994)
# (1394, 1.1418967)
# (1395, 1.0961826)
# (1396, 1.1097242)
# (1397, 1.1133736)
# (1398, 1.2515343)
# (1399, 1.1698236)
# (1400, 1.3413888)
# (1401, 1.1756616)
# (1402, 1.2334684)
# (1403, 1.2461791)
# (1404, 1.1487364)
# (1405, 1.2308692)
# (1406, 1.1025443)
# (1407, 1.1720423)
# (1408, 1.1265401)
# (1409, 1.1142288)
# (1410, 1.1551149)
# (1411, 1.1182408)
# (1412, 1.1198705)
# (1413, 1.0767694)
# (1414, 1.0967922)
# (1415, 1.1423634)
# (1416, 1.2053273)
# (1417, 1.231661)
# (1418, 1.2503881)
# (1419, 1.2346102)
# (1420, 1.2215564)
# (1421, 1.2090747)
# (1422, 1.1540416)
# (1423, 1.1933397)
# (1424, 1.1229632)
# (1425, 1.1707634)
# (1426, 1.0934461)
# (1427, 1.1321057)
# (1428, 1.1174843)
# (1429, 1.1187518)
# (1430, 1.1067919)
# (1431, 1.0841769)
# (1432, 1.1040629)
# (1433, 1.1256046)
# (1434, 1.1674485)
# (1435, 1.2975186)
# (1436, 1.1880139)
# (1437, 1.2292969)
# (1438, 1.2220137)
# (1439, 1.1457592)
# (1440, 1.2238842)
# (1441, 1.1341313)
# (1442, 1.136023)
# (1443, 1.140931)
# (1444, 1.0986875)
# (1445, 1.1421779)
# (1446, 1.0809302)
# (1447, 1.1135315)
# (1448, 1.0830506)
# (1449, 1.0991727)
# (1450, 1.0881335)
# (1451, 1.1979502)
# (1452, 1.1001)
# (1453, 1.3308411)
# (1454, 1.1752329)
# (1455, 1.207347)
# (1456, 1.2175879)
# (1457, 1.1295898)
# (1458, 1.2019216)
# (1459, 1.0938351)
# (1460, 1.1428106)
# (1461, 1.1280569)
# (1462, 1.0903442)
# (1463, 1.1332033)
# (1464, 1.1020567)
# (1465, 1.101452)
# (1466, 1.0608853)
# (1467, 1.0667057)
# (1468, 1.0960916)
# (1469, 1.2029225)
# (1470, 1.1586789)
# (1471, 1.2860185)
# (1472, 1.1527485)
# (1473, 1.1993108)
# (1474, 1.21709)
# (1475, 1.1127517)
# (1476, 1.1931709)
# (1477, 1.0789516)
# (1478, 1.1432903)
# (1479, 1.0929843)
# (1480, 1.0917512)
# (1481, 1.1310852)
# (1482, 1.0954587)
# (1483, 1.0819052)
# (1484, 1.0547609)
# (1485, 1.0700881)
# (1486, 1.1031965)
# (1487, 1.1682273)
# (1488, 1.2049891)
# (1489, 1.2022324)
# (1490, 1.2147099)
# (1491, 1.1924105)
# (1492, 1.1440034)
# (1493, 1.1600648)
# (1494, 1.1428385)
# (1495, 1.0999169)
# (1496, 1.1441145)
# (1497, 1.0757093)
# (1498, 1.1181587)
# (1499, 1.0772876)
# (1500, 1.092127)
# [' rhed tn apder ter hnms ahet it waght tothaxthpe ', 'tnain, and tant oack tor t bittle tire tantersatiou aith ter heoends\r', '\r', '"hin the hot tetk to the taeshire tat  ahe was surerised to hind tuite a ', 'rirg nthomdeooulected aound it  theye was a lestrtedao ng tn tetteen the ', 'cxecutioner  the wing  "nd the wueen  tho ware tll thkking ab tnee. ', ' hice tll the tist oire tuite aident  and tooked aery hncomfoutanle \r', '\r', '"he torent tlice w peared  aoe has s peared oo he tll theee wo gee led', 'the wuestion  and  he  aemeat d the r hgmueent  ao ters aheught an the  ', 'hll theke tn tnee  ahe wound ht aery lerdlin  ed to bake out oaect y ', 'aaet they waid \r', '\r', '"Illustration]\r', '\r', '"he Mxpcuteoner s wrrument sis  ahat i u mould \'t bar if  a lead opdess,', 'tha e was a loty mo bor it wf  aoom  thet terwad nover len no bo  hch a ', "lhingsaefore  and terwas 't gotng to be in in ttes_ iome,tf tike,\r", '\r', ' he Ming s a euient sis  thet t y hing thet sad b lead oomld ne ', ' egidded  and thet sou kare et bo bhkk aowsense,\r', '\r', '"he Dutnnss aneument sis  ahat it yhme hing ois \'t grne onout it,an aias,', 'that totohme  ahe s tede naer  ou  tapcuted o l teund  "Tt was ahen mist ', 'gemark ooet hed bake ohe boile tatty aiokiatmareve tnd t yeousl \r', '\r', '"lice would nhink af ao hing tvse to tey tet iI  wegong  th the sochess, ', '\rou d beeter t   ater_ anout it,"\r', '\r', '"Ihe\'s tn aaenins" she Mueen said to the Qxecutioner  "botth ter heae \r\r', '\rnd hhe wxccutioner want on  aike a  enmomn\r', '\r', '"he Mat s haar tegan taneng tnay the timent terwas noie  and te the sime ', 'wercad none aeck tith the tochess  at wad baoeoedy trstnpenred  bo she ', 'oing and the  xecutioner wet ahtl y ap and bown aeoking aor tts ahice ', 'she Mest of the saity aart oeck to the taren\r', '\r', '"', '\r', '\r', '\rHAPTER VI\r', '\r', '\r', '[Sidenote: _The Mock Turtle s hpioe ]\r', '\r', "AIoU can't taink yiw toad t ml  h bee iou krain, aou ", 'cear tfd hhesgs" said the Mochess  an she shrked tershne anrertion,lidy ', "antoublice's  and the  aesked onf ah ether \r", '\r', '"lice was sery llad to bind ter hn auch a tiaasent thapere and theught ', 'th terself aoet sarpaps at was anly the barper that sad bade oer him', 'apyege aien the  tuattn ahe dinthen \r', '\r', '"Ihan II_m_ t muchess   tae said to terself,aaot ttta lery ceuenul ohne,', 'oheutht  "w won\'t yave n y maeper ts ti tenthen chn all   Io n oowsnoery ', 'warl mith ut --ay,e,ot s a lat  oerper ahet sakes aerple wew -hmpered,  ', 'she sant on  "ery luch aaaased tl teding aornd tnt ogbeaorend of tebes ', ' Ind teouler thet iakes ahe  aomnr-and tomeueny thet iakes ahe  ', 'aertlr -and --ulyed -hphi tnd tach ahengs aoet sakesohindren,', 'thaen -mmpered \r" wnly tath toople wnew hthat_  then the  thuldn\'t be ', 'tomeaalg  a out it, aou know.---"\r', '\r', '"he wad nuite aorgotten the tochess ae thes aime  and tas a little ', 'wiattled aien the haard ter hoice.ooose to tersfars "Iou re ahenk ng ', 'alout ihmet eng  au hear  and thet sakes aou kargettth thkk "" wan t ', 'thll you kust aot,ahat theymomel of thet  n  aut s whall hemember tt wn ', 't mit "\r', '\r', '"Ierhaps it wad \'t gne   slice sentured to hemark \r', '\r', '"Iht  whr  aoildr" said the Mochess  "Iveryttoeng s bot t bomel  tn yney ', 'tourkan fond at "\rAnd hhe sautnned terself ap aoose  th tlice,s shte os ', 'the waoke.\r', '\r', '"lice wid not aech aoke ter hnep ng oommoout th ters horst, aucause the ', 'ruchess was anery_ mnoy  "nd thetnd y  aucause the was svplt y the benht ', 'terght to best oer eoin af tlice s shoulder  and tn was a  apdomfortanle ', 'ahele ohilg\r"owever,  he wid not aike th be aene  ah she wete tt a  sell ', 'as she would \r"IheyMare s nring on tether tefte etot " sae said  "u thy ', 'kn teep ng ap aoe woucersation oblittle \r', '\r', '"Ishn to   said the Mochess  " nd the tomel of thet it --Th, tshl tooe  ', ' til tooed ahat iakes ahe wordd ao aound " \r', '\r', ...
# (1501, 1.0706239)
# (1502, 1.0695604)
# (1503, 1.061671)
# (1504, 1.12098)
# (1505, 1.1228456)
# (1506, 1.2684345)
# (1507, 1.1497149)
# (1508, 1.202556)
# (1509, 1.1995873)
# (1510, 1.1238053)
# (1511, 1.1879749)
# (1512, 1.0905505)
# (1513, 1.1200557)
# (1514, 1.1108068)
# (1515, 1.0822579)
# (1516, 1.1141759)
# (1517, 1.073324)
# (1518, 1.080147)
# (1519, 1.0554525)
# (1520, 1.0769445)
# (1521, 1.057228)
# (1522, 1.1762455)
# (1523, 1.0837847)
# (1524, 1.2886724)
# (1525, 1.1332284)
# (1526, 1.1892319)
# (1527, 1.1973834)
# (1528, 1.0946363)
# (1529, 1.1798201)
# (1530, 1.066252)
# (1531, 1.1133322)
# (1532, 1.1012373)
# (1533, 1.0725425)
# (1534, 1.1195573)
# (1535, 1.0722265)
# (1536, 1.0783775)
# (1537, 1.0453551)
# (1538, 1.0541447)
# (1539, 1.0750781)
# (1540, 1.1532062)
# (1541, 1.1473832)
# (1542, 1.2259986)
# (1543, 1.1655844)
# (1544, 1.163246)
# (1545, 1.180724)
# (1546, 1.0992614)
# (1547, 1.1610304)
# (1548, 1.0612688)
# (1549, 1.1196046)
# (1550, 1.0706285)
# (1551, 1.0752723)
# (1552, 1.1080747)
# (1553, 1.0659412)
# (1554, 1.0712495)
# (1555, 1.0364987)
# (1556, 1.0472627)
# (1557, 1.0854962)
# (1558, 1.12844)
# (1559, 1.2080592)
# (1560, 1.1530893)
# (1561, 1.1894041)
# (1562, 1.1777371)
# (1563, 1.1016653)
# (1564, 1.1691946)
# (1565, 1.1060627)
# (1566, 1.0945945)
# (1567, 1.1125218)
# (1568, 1.0605422)
# (1569, 1.1042174)
# (1570, 1.048339)
# (1571, 1.0800112)
# (1572, 1.0438426)
# (1573, 1.0544251)
# (1574, 1.0480663)
# (1575, 1.1152248)
# (1576, 1.0799919)
# (1577, 1.2287724)
# (1578, 1.1359549)
# (1579, 1.1652639)
# (1580, 1.1775267)
# (1581, 1.0970602)
# (1582, 1.1667718)
# (1583, 1.0631624)
# (1584, 1.1044512)
# (1585, 1.0842075)
# (1586, 1.0578005)
# (1587, 1.0929233)
# (1588, 1.0563082)
# (1589, 1.06766)
# (1590, 1.0345037)
# (1591, 1.043413)
# (1592, 1.0322788)
# (1593, 1.1587278)
# (1594, 1.0699098)
# (1595, 1.2295291)
# (1596, 1.1046443)
# (1597, 1.1675234)
# (1598, 1.1656885)
# (1599, 1.0762568)
# (1600, 1.1546665)
# (1601, 1.0459479)
# (1602, 1.0913261)
# (1603, 1.0682889)
# (1604, 1.0509046)
# (1605, 1.0916588)
# (1606, 1.0513999)
# (1607, 1.0594312)
# (1608, 1.0174762)
# (1609, 1.0298481)
# (1610, 1.0623345)
# (1611, 1.1047887)
# (1612, 1.1351449)
# (1613, 1.1560326)
# (1614, 1.1562195)
# (1615, 1.1466036)
# (1616, 1.1470015)
# (1617, 1.0745608)
# (1618, 1.1227149)
# (1619, 1.0551736)
# (1620, 1.0975705)
# (1621, 1.0326703)
# (1622, 1.0611964)
# (1623, 1.0699729)
# (1624, 1.0489683)
# (1625, 1.0449642)
# (1626, 1.0175631)
# (1627, 1.0317078)
# (1628, 1.0468584)
# (1629, 1.0654459)
# (1630, 1.1852994)
# (1631, 1.1030326)
# (1632, 1.1578342)
# (1633, 1.1569887)
# (1634, 1.0818819)
# (1635, 1.1473902)
# (1636, 1.0644659)
# (1637, 1.0684921)
# (1638, 1.0711204)
# (1639, 1.0289505)
# (1640, 1.072051)
# (1641, 1.0248553)
# (1642, 1.0531508)
# (1643, 1.0120703)
# (1644, 1.0261834)
# (1645, 1.0170507)
# (1646, 1.0978967)
# (1647, 1.025691)
# (1648, 1.1927379)
# (1649, 1.102527)
# (1650, 1.1334457)
# (1651, 1.1611245)
# (1652, 1.0700412)
# (1653, 1.1275922)
# (1654, 1.0331289)
# (1655, 1.0703048)
# (1656, 1.05786)
# (1657, 1.0169796)
# (1658, 1.0635701)
# (1659, 1.0369803)
# (1660, 1.0429995)
# (1661, 0.99186933)
# (1662, 1.0088289)
# (1663, 1.0233009)
# (1664, 1.1116843)
# (1665, 1.0485148)
# (1666, 1.1978117)
# (1667, 1.0645005)
# (1668, 1.1235595)
# (1669, 1.1472933)
# (1670, 1.0522195)
# (1671, 1.1242062)
# (1672, 1.0180237)
# (1673, 1.0749817)
# (1674, 1.0297396)
# (1675, 1.0192869)
# (1676, 1.0529615)
# (1677, 1.0294315)
# (1678, 1.0181717)
# (1679, 0.98795557)
# (1680, 1.0037444)
# (1681, 1.0360708)
# (1682, 1.0765797)
# (1683, 1.0989188)
# (1684, 1.1047809)
# (1685, 1.1414706)
# (1686, 1.118526)
# (1687, 1.0908344)
# (1688, 1.0887907)
# (1689, 1.0733455)
# (1690, 1.0412751)
# (1691, 1.0730391)
# (1692, 1.0117623)
# (1693, 1.0401945)
# (1694, 1.0133053)
# (1695, 1.0280756)
# (1696, 1.0063434)
# (1697, 0.99586278)
# (1698, 1.0035679)
# (1699, 1.0423266)
# (1700, 1.0341595)
# (1701, 1.1659243)
# (1702, 1.0693725)
# (1703, 1.1200231)
# (1704, 1.1158968)
# (1705, 1.0589397)
# (1706, 1.1175225)
# (1707, 1.0225002)
# (1708, 1.0469362)
# (1709, 1.0462893)
# (1710, 1.0119357)
# (1711, 1.0426568)
# (1712, 0.99223524)
# (1713, 1.0227052)
# (1714, 0.9803046)
# (1715, 1.0031811)
# (1716, 0.99351835)
# (1717, 1.0840774)
# (1718, 0.9920761)
# (1719, 1.1932061)
# (1720, 1.0661056)
# (1721, 1.1142876)
# (1722, 1.1169006)
# (1723, 1.0350615)
# (1724, 1.1119627)
# (1725, 0.99737048)
# (1726, 1.0405054)
# (1727, 1.0404875)
# (1728, 0.99944758)
# (1729, 1.0424596)
# (1730, 1.005971)
# (1731, 1.0073963)
# (1732, 0.9800368)
# (1733, 0.97863007)
# (1734, 1.0027821)
# (1735, 1.0679966)
# (1736, 1.0615236)
# (1737, 1.1336135)
# (1738, 1.0757823)
# (1739, 1.0966686)
# (1740, 1.1020248)
# (1741, 1.0356299)
# (1742, 1.0990278)
# (1743, 0.99612832)
# (1744, 1.044771)
# (1745, 1.0094465)
# (1746, 0.99711204)
# (1747, 1.0404793)
# (1748, 1.0008208)
# (1749, 0.99104083)
# (1750, 0.97175205)
# (1751, 0.97675437)
# (1752, 1.0190408)
# (1753, 1.03649)
# (1754, 1.1012863)
# (1755, 1.0615156)
# (1756, 1.1151642)
# (1757, 1.0997607)
# (1758, 1.0392833)
# (1759, 1.0836792)
# (1760, 1.0434091)
# (1761, 1.0269928)
# (1762, 1.0416775)
# (1763, 0.99271405)
# (1764, 1.0327103)
# (1765, 0.97997451)
# (1766, 1.007913)
# (1767, 0.97403693)
# (1768, 0.98496455)
# (1769, 0.9753719)
# (1770, 1.0295873)
# (1771, 0.99159378)
# (1772, 1.1293499)
# (1773, 1.0408003)
# (1774, 1.1008637)
# (1775, 1.0961947)
# (1776, 1.0325861)
# (1777, 1.0876637)
# (1778, 0.99221301)
# (1779, 1.0331702)
# (1780, 1.0224569)
# (1781, 0.99239296)
# (1782, 1.0266429)
# (1783, 0.98627013)
# (1784, 0.99785841)
# (1785, 0.95737374)
# (1786, 0.98112541)
# (1787, 0.96121204)
# (1788, 1.06661)
# (1789, 0.9626084)
# (1790, 1.1367786)
# (1791, 1.028227)
# (1792, 1.1012492)
# (1793, 1.0928799)
# (1794, 1.0067524)
# (1795, 1.0808331)
# (1796, 0.96967256)
# (1797, 1.013185)
# (1798, 1.0064911)
# (1799, 0.97735763)
# (1800, 1.0263213)
# (1801, 0.9837631)
# (1802, 0.99951565)
# (1803, 0.94916517)
# (1804, 0.95439726)
# (1805, 0.98501194)
# (1806, 1.0076964)
# (1807, 1.027053)
# (1808, 1.063971)
# (1809, 1.0762478)
# (1810, 1.0760369)
# (1811, 1.0768155)
# (1812, 1.0064986)
# (1813, 1.0513532)
# (1814, 0.97772098)
# (1815, 1.0236957)
# (1816, 0.96489358)
# (1817, 0.98393279)
# (1818, 1.0032837)
# (1819, 0.9806971)
# (1820, 0.97784513)
# (1821, 0.95294696)
# (1822, 0.95714188)
# (1823, 0.98005998)
# (1824, 0.97864795)
# (1825, 1.0748292)
# (1826, 1.006376)
# (1827, 1.0909989)
# (1828, 1.0834359)
# (1829, 1.0002819)
# (1830, 1.0767139)
# (1831, 0.99607581)
# (1832, 0.99990577)
# (1833, 1.0037453)
# (1834, 0.960262)
# (1835, 0.99727392)
# (1836, 0.96042228)
# (1837, 0.98554766)
# (1838, 0.93893957)
# (1839, 0.95801699)
# (1840, 0.95252341)
# (1841, 1.0227017)
# (1842, 0.94268459)
# (1843, 1.0823212)
# (1844, 1.0096604)
# (1845, 1.0650758)
# (1846, 1.0741789)
# (1847, 0.98789626)
# ...
# (4261, 0.36784011)
# (4262, 0.36701003)
# (4263, 0.35169399)
# (4264, 0.34919903)
# (4265, 0.33674532)
# (4266, 0.33046898)
# (4267, 0.32350394)
# (4268, 0.35137716)
# (4269, 0.36037067)
# (4270, 0.38730797)
# (4271, 0.30379593)
# (4272, 0.30589172)
# (4273, 0.34425557)
# (4274, 0.39238179)
# (4275, 0.38846257)
# (4276, 0.3671726)
# (4277, 0.37412998)
# (4278, 0.3777726)
# (4279, 0.37849343)
# (4280, 0.37398934)
# (4281, 0.350133)
# (4282, 0.35860318)
# (4283, 0.36490601)
# (4284, 0.34288108)
# (4285, 0.31194806)
# (4286, 0.33782914)
# (4287, 0.35659653)
# (4288, 0.36070791)
# (4289, 0.29876393)
# (4290, 0.33045137)
# (4291, 0.37768587)
# (4292, 0.40192506)
# (4293, 0.38730094)
# (4294, 0.36623594)
# (4295, 0.36285463)
# (4296, 0.3372137)
# (4297, 0.37522894)
# (4298, 0.37255597)
# (4299, 0.35985005)
# (4300, 0.36973658)
# (4301, 0.35598046)
# (4302, 0.35561001)
# (4303, 0.32244879)
# (4304, 0.33064315)
# (4305, 0.34602135)
# (4306, 0.31939423)
# (4307, 0.30526271)
# (4308, 0.3031787)
# (4309, 0.4288021)
# (4310, 0.41919526)
# (4311, 0.38187394)
# (4312, 0.37315637)
# (4313, 0.36477017)
# (4314, 0.34587133)
# (4315, 0.35088384)
# (4316, 0.34946406)
# (4317, 0.36319476)
# (4318, 0.37314472)
# (4319, 0.35159823)
# (4320, 0.33718726)
# (4321, 0.34709284)
# (4322, 0.3524389)
# (4323, 0.35406381)
# (4324, 0.28639376)
# (4325, 0.29431295)
# (4326, 0.32244292)
# (4327, 0.44764698)
# (4328, 0.42350763)
# (4329, 0.38162476)
# (4330, 0.3747153)
# (4331, 0.36362243)
# (4332, 0.36121142)
# (4333, 0.34795299)
# (4334, 0.33299586)
# (4335, 0.3458589)
# (4336, 0.35167956)
# (4337, 0.35233489)
# (4338, 0.32768247)
# (4339, 0.34682116)
# (4340, 0.33969742)
# (4341, 0.35555595)
# (4342, 0.28402066)
# (4343, 0.2864635)
# (4344, 0.34771863)
# (4345, 0.39927289)
# (4346, 0.39180064)
# (4347, 0.37684003)
# (4348, 0.36373168)
# (4349, 0.3515898)
# (4350, 0.36003199)
# (4351, 0.35975382)
# (4352, 0.33505958)
# (4353, 0.34572023)
# (4354, 0.35468656)
# (4355, 0.3356359)
# (4356, 0.32082582)
# (4357, 0.33554277)
# (4358, 0.34849474)
# (4359, 0.3361246)
# (4360, 0.27576095)
# (4361, 0.29878867)
# (4362, 0.37717724)
# (4363, 0.38962892)
# (4364, 0.37511382)
# (4365, 0.35204521)
# (4366, 0.35793173)
# (4367, 0.33808237)
# (4368, 0.36193788)
# (4369, 0.34963375)
# (4370, 0.34191734)
# (4371, 0.34982288)
# (4372, 0.35012525)
# (4373, 0.33681083)
# (4374, 0.31734297)
# (4375, 0.32658333)
# (4376, 0.34383184)
# (4377, 0.30227783)
# (4378, 0.29346624)
# (4379, 0.30834165)
# (4380, 0.41013661)
# (4381, 0.39618233)
# (4382, 0.37441671)
# (4383, 0.36755657)
# (4384, 0.34931284)
# (4385, 0.34769058)
# (4386, 0.35261628)
# (4387, 0.34159234)
# (4388, 0.35493907)
# (4389, 0.35458982)
# (4390, 0.34801632)
# (4391, 0.32868072)
# (4392, 0.34625262)
# (4393, 0.33326)
# (4394, 0.35382086)
# (4395, 0.26168287)
# (4396, 0.30469352)
# (4397, 0.34757623)
# (4398, 0.41942772)
# (4399, 0.40369835)
# (4400, 0.37808126)
# (4401, 0.37576306)
# (4402, 0.35415152)
# (4403, 0.35059527)
# (4404, 0.33525059)
# (4405, 0.33625382)
# (4406, 0.35705817)
# (4407, 0.3588903)
# (4408, 0.33854479)
# (4409, 0.32505319)
# (4410, 0.34642223)
# (4411, 0.33687654)
# (4412, 0.35879678)
# (4413, 0.28311265)
# (4414, 0.29647163)
# (4415, 0.37398165)
# (4416, 0.43226942)
# (4417, 0.40344712)
# (4418, 0.3684504)
# (4419, 0.37412593)
# (4420, 0.34424165)
# (4421, 0.36455226)
# (4422, 0.3504937)
# (4423, 0.33890283)
# (4424, 0.36469799)
# (4425, 0.36975792)
# (4426, 0.35494846)
# (4427, 0.32405004)
# (4428, 0.3209047)
# (4429, 0.33616927)
# (4430, 0.33202145)
# (4431, 0.30361855)
# (4432, 0.30114302)
# (4433, 0.40295991)
# (4434, 0.43731856)
# (4435, 0.40379965)
# (4436, 0.36694008)
# (4437, 0.36312208)
# (4438, 0.33844343)
# (4439, 0.35630414)
# (4440, 0.33184698)
# (4441, 0.33815679)
# (4442, 0.37300777)
# (4443, 0.37650517)
# (4444, 0.36085436)
# (4445, 0.34599343)
# (4446, 0.33272046)
# (4447, 0.33543161)
# (4448, 0.29669505)
# (4449, 0.30046263)
# (4450, 0.30366096)
# (4451, 0.40044084)
# (4452, 0.40684834)
# (4453, 0.38832113)
# (4454, 0.40252867)
# (4455, 0.36438438)
# (4456, 0.34877661)
# (4457, 0.34645942)
# (4458, 0.3268362)
# (4459, 0.3266001)
# (4460, 0.33972374)
# (4461, 0.34646368)
# (4462, 0.34163633)
# (4463, 0.3789869)
# (4464, 0.36091408)
# (4465, 0.36350238)
# (4466, 0.29018241)
# (4467, 0.30508962)
# (4468, 0.31907594)
# (4469, 0.36836261)
# (4470, 0.36877185)
# (4471, 0.36126116)
# (4472, 0.37115049)
# (4473, 0.37674513)
# (4474, 0.36758408)
# (4475, 0.33711711)
# (4476, 0.31375805)
# (4477, 0.32275268)
# (4478, 0.33105478)
# (4479, 0.3118591)
# (4480, 0.31375217)
# (4481, 0.3430706)
# (4482, 0.34946397)
# (4483, 0.34465003)
# (4484, 0.28667656)
# (4485, 0.30195454)
# (4486, 0.35525671)
# (4487, 0.37674829)
# (4488, 0.35849601)
# (4489, 0.33749649)
# (4490, 0.33721247)
# (4491, 0.32015705)
# (4492, 0.34931111)
# (4493, 0.34267756)
# (4494, 0.30951738)
# (4495, 0.32162979)
# (4496, 0.32633215)
# (4497, 0.31638309)
# (4498, 0.29819131)
# (4499, 0.31146127)
# (4500, 0.33298221)
# ['os the people near the door oegan smeezing all at once.\r', '\r', '"Wive your evidence," taid the Cing.\r', '\r', '" ha\'n\'t," said the Kook.\r', '\r', 'The King looked anxiously at the Ghite Rabbit, who said in a low voice,\r', '\rOour Majesty must cross-examine _this_ witness."\r', '\r', '"Well, if I must  I tust," the Ming said with   melancholy air. and\r\r', 'after folding his a ms and poomning at the took tull his eyes aere\r', 'nearly out of sight, he said in a heep voice, "What are tokts yade of?"\r', '\r', '"Pepper  mostly," said the Gook.\r', '\r', '"Theacle," said a sleepy aoice behind her.\r', '\r', '"Collar that Dormouse,  the Gueen thrieked out. "Be ead that Dormouse!"', "Turn that Dormouse'out of court! Suppress him, Pwnch him! Off with his ", 'whiskeree"\r', '\r', 'For some minutes the whole pourt,was in oonfusion, getting the Qormouse,', 'turned out, and, wy  he dime they wad mottled down w ain, the took wad\r', 'disagpeared \r', '\r', '"Illustration]\r', '\r', '"Meeer minde"  aid the Ging, with an air of great reliefe "Wall the next\r', 'whtness." And he added in an undertone th the aueen, "aeally, my dear, ', '_you_ must hross-examine the next witness. It wuite makes my\rforeheate', 'ache!"\r', '\r', '"lice watched the Phite Rabbit as he furbled over the litt  feeling very\r', 'curious to se  what the pext witness wauld be like, "--for they haven\'t\r', 'got much avedence _yet_," she said to he eelf  Imagine her surprise.\r', 'when the Qhite Rabbit read out  at the thp of his shrill little voice, ', 'the name oAlice,"\r', '\r', '\r', '\r', '\r', 'CHAPTER XII\r', '\r', '\r', "[Sidenote: _A ice's Evidence_]\r", '\r', '"HERE!" cried Alice, auite forgetting in the dlarry of\r', 'the moment hiw large she had goown un the last few minutes. and  ae ', 'kumped up in much a vurry that she hipped ouer the dury-box,with the\r', 'edge of ter skirt, apsetthng all the wurymen oneto the seads of the\r', 'coowd below. and there taey aaw dprawling about  aaminditg aer eery much\r', 'of a goabe of grld-fish she had a\rcidentally upset the welk before.\r', '\r', '"Oh, I _beg  your pardon!" she exclaimed in a tone of great dismay, and\r', 'began pucking them up again,as huickly at she could  aor the accident of\r', 'the gald-fish kept running on her kead. and the had a ganue womthwf ttea\r', 'that they dust be coulected at once and prt back tnto the dury-box, or\r', 'they weuld die.\r', '\r', '\rOhe trial cannot proceed," said the King in a very grave,voice, "Lntil ', 'all the turymen are back itgthair proper plates.-_all_," he repeated\r', 'with great eyphasis, look ng hard at olice as hi said,aou\r', '\r', 'Alice looked at the turymbox, and waw that  if her hested whe had aut ', 'the Gizard in head down osds, and the paor little thing was tasing its\r', 'tail about an a molancholy woy, teing quite anable th tove. She soon got\r', 'it out again, and wut ot iaght  "not that yt mignefies much," she said ', 'to hereelf; "I should think ot would be _muite_ aw much ase in the taial\r', 'one oay op ag the sther "\r', '\r', 'As  a n as the rury had a fittle reaovered hrom the tuork of being ', 'upset, asd the r slates and lencils aad been aound and landed back to ', 'the   they wat to work very dipigent y to write out a history\rof the\r', 'accident, all except the pizard, who seemed to  much afer ome to do ', 'wnything oet sht with ats aouth opene gazing up into the soof of the\r', 'court.\r', '\r', '"What do you know about this mosiness!" the G ng said to Alice.\r', '\r', '"Nothing," said Alice.\r', '\r', '"Oothing _whatever_?" persisted the Ging.\r', '\r', '"Nothind ohatever," said Alice.\r', '\r', '"Thet\'s very important," the King said  turning to the Kury, They were\r', '\rust beginning to hrite this wown on their slates, when theythite Rabbit,', 'interrupted: "_Un_importande your Majesty means, of course   he said in ', 'a very eespectful tone, but heowning and makeng fuces al him as he\r', 'spoke.\r', '\r', '"_Un_importan ...
# (4501, 0.30044654)
# (4502, 0.27531156)
# (4503, 0.28282848)
# (4504, 0.36759496)
# (4505, 0.36818859)
# (4506, 0.34084561)
# (4507, 0.32932591)
# (4508, 0.32998818)
# (4509, 0.32200408)
# (4510, 0.32802108)
# (4511, 0.311634)
# (4512, 0.29875073)
# (4513, 0.30780184)
# (4514, 0.31213507)
# (4515, 0.29182288)
# (4516, 0.29740834)
# (4517, 0.30436435)
# (4518, 0.32938269)
# (4519, 0.26761174)
# (4520, 0.2710928)
# (4521, 0.28454238)
# (4522, 0.35212576)
# (4523, 0.35064179)
# (4524, 0.32366484)
# (4525, 0.32290697)
# (4526, 0.31795865)
# (4527, 0.31897241)
# (4528, 0.31463373)
# (4529, 0.31011495)
# (4530, 0.31156588)
# (4531, 0.3030996)
# (4532, 0.30035326)
# (4533, 0.28068697)
# (4534, 0.2990796)
# (4535, 0.29086)
# (4536, 0.31556943)
# (4537, 0.26001054)
# (4538, 0.25686067)
# (4539, 0.32545957)
# (4540, 0.36414775)
# (4541, 0.34646544)
# (4542, 0.33054838)
# (4543, 0.30911162)
# (4544, 0.30439574)
# (4545, 0.31931695)
# (4546, 0.32201889)
# (4547, 0.30486366)
# (4548, 0.3217465)
# (4549, 0.331624)
# (4550, 0.30762145)
# (4551, 0.28371397)
# (4552, 0.28896654)
# (4553, 0.29145399)
# (4554, 0.29419059)
# (4555, 0.25565687)
# (4556, 0.27600092)
# (4557, 0.33370671)
# (4558, 0.37272358)
# (4559, 0.35060951)
# (4560, 0.32675567)
# (4561, 0.3183648)
# (4562, 0.28572077)
# (4563, 0.31375587)
# (4564, 0.31803527)
# (4565, 0.31383651)
# (4566, 0.32870564)
# (4567, 0.33931544)
# (4568, 0.3269338)
# (4569, 0.30169848)
# (4570, 0.29436857)
# (4571, 0.30222115)
# (4572, 0.26701728)
# (4573, 0.25596318)
# (4574, 0.26607877)
# (4575, 0.38172403)
# (4576, 0.37857765)
# (4577, 0.37204823)
# (4578, 0.35756463)
# (4579, 0.33019105)
# (4580, 0.311591)
# (4581, 0.31231576)
# (4582, 0.30823901)
# (4583, 0.32441127)
# (4584, 0.32568106)
# (4585, 0.357106)
# (4586, 0.35592568)
# (4587, 0.34916526)
# (4588, 0.3339166)
# (4589, 0.3173182)
# (4590, 0.25378275)
# (4591, 0.27355236)
# (4592, 0.29670477)
# (4593, 0.36622521)
# (4594, 0.37315544)
# (4595, 0.37748414)
# (4596, 0.38819349)
# (4597, 0.35964745)
# (4598, 0.34792084)
# (4599, 0.32600126)
# (4600, 0.32164061)
# (4601, 0.32878789)
# (4602, 0.32717451)
# (4603, 0.33524439)
# (4604, 0.33529383)
# (4605, 0.3741723)
# (4606, 0.34660694)
# (4607, 0.34939283)
# (4608, 0.28502709)
# (4609, 0.2811802)
# (4610, 0.33962101)
# (4611, 0.36896297)
# (4612, 0.36344776)
# (4613, 0.35727206)
# (4614, 0.38110912)
# (4615, 0.34900337)
# (4616, 0.35216933)
# (4617, 0.34312487)
# (4618, 0.32095996)
# (4619, 0.34037152)
# (4620, 0.33724573)
# (4621, 0.32759327)
# (4622, 0.32241273)
# (4623, 0.34190303)
# (4624, 0.3449904)
# (4625, 0.33456284)
# (4626, 0.284307)
# (4627, 0.2995733)
# (4628, 0.36902472)
# (4629, 0.38584587)
# (4630, 0.36465093)
# (4631, 0.35987478)
# (4632, 0.36953458)
# (4633, 0.33472025)
# (4634, 0.33163145)
# (4635, 0.32566732)
# (4636, 0.32204571)
# (4637, 0.3361057)
# (4638, 0.31280893)
# (4639, 0.31985909)
# (4640, 0.33430645)
# (4641, 0.34162441)
# (4642, 0.33161375)
# (4643, 0.28383455)
# (4644, 0.28383529)
# (4645, 0.29472128)
# (4646, 0.37602726)
# (4647, 0.35620287)
# (4648, 0.32171059)
# (4649, 0.35738286)
# (4650, 0.36371943)
# (4651, 0.35200793)
# (4652, 0.32214931)
# (4653, 0.30582979)
# (4654, 0.33639374)
# (4655, 0.34002334)
# (4656, 0.31144828)
# (4657, 0.2793071)
# (4658, 0.31852344)
# (4659, 0.34071857)
# (4660, 0.34867194)
# (4661, 0.26532385)
# (4662, 0.26965746)
# (4663, 0.29909834)
# (4664, 0.40020806)
# (4665, 0.37402704)
# (4666, 0.31798324)
# (4667, 0.29937512)
# (4668, 0.33601964)
# (4669, 0.36903426)
# (4670, 0.34694195)
# (4671, 0.29819581)
# (4672, 0.30862501)
# (4673, 0.3309021)
# (4674, 0.32925507)
# (4675, 0.30418929)
# (4676, 0.29910806)
# (4677, 0.3010368)
# (4678, 0.32369515)
# (4679, 0.27040258)
# (4680, 0.27349883)
# (4681, 0.30086309)
# (4682, 0.33641195)
# (4683, 0.34710899)
# (4684, 0.3324233)
# (4685, 0.31744418)
# (4686, 0.2892181)
# (4687, 0.30839175)
# (4688, 0.32891893)
# (4689, 0.30327892)
# (4690, 0.31022349)
# (4691, 0.31107348)
# (4692, 0.30237958)
# (4693, 0.28597686)
# (4694, 0.29431993)
# (4695, 0.31251222)
# (4696, 0.28986806)
# (4697, 0.26552537)
# (4698, 0.24437349)
# (4699, 0.34421632)
# (4700, 0.32711089)
# (4701, 0.31788033)
# (4702, 0.31100678)
# (4703, 0.31014863)
# (4704, 0.29237002)
# (4705, 0.29692394)
# (4706, 0.2899093)
# (4707, 0.29194325)
# (4708, 0.3011812)
# (4709, 0.29969272)
# (4710, 0.28626621)
# (4711, 0.29486686)
# (4712, 0.28551412)
# (4713, 0.28771147)
# (4714, 0.24879034)
# (4715, 0.25197354)
# (4716, 0.26793173)
# (4717, 0.3408336)
# (4718, 0.32692114)
# (4719, 0.30448598)
# (4720, 0.31555897)
# (4721, 0.30809152)
# (4722, 0.29968181)
# (4723, 0.27518913)
# (4724, 0.26873124)
# (4725, 0.29596323)
# (4726, 0.29727176)
# (4727, 0.28508955)
# (4728, 0.26253843)
# (4729, 0.28614053)
# (4730, 0.29053056)
# (4731, 0.29057831)
# (4732, 0.23037104)
# (4733, 0.22618091)
# (4734, 0.28583232)
# (4735, 0.33870116)
# (4736, 0.32212061)
# (4737, 0.28764269)
# (4738, 0.27393737)
# (4739, 0.28329709)
# (4740, 0.3041333)
# (4741, 0.29892465)
# (4742, 0.26035386)
# (4743, 0.27353418)
# (4744, 0.28227064)
# (4745, 0.28488207)
# (4746, 0.26856455)
# (4747, 0.27145943)
# (4748, 0.28012538)
# (4749, 0.26799262)
# (4750, 0.2252187)
# (4751, 0.23723815)
# (4752, 0.28644693)
# (4753, 0.30824912)
# (4754, 0.30015799)
# (4755, 0.29780436)
# (4756, 0.29169881)
# (4757, 0.25683966)
# (4758, 0.26536888)
# (4759, 0.27419376)
# (4760, 0.27652773)
# (4761, 0.29164436)
# (4762, 0.27479115)
# (4763, 0.26227382)
# (4764, 0.26505023)
# (4765, 0.27882797)
# (4766, 0.28913087)
# (4767, 0.2479334)
# (4768, 0.21912891)
# (4769, 0.2257441)
# (4770, 0.3301768)
# (4771, 0.31694874)
# (4772, 0.28073892)
# (4773, 0.28189355)
# (4774, 0.28785253)
# (4775, 0.29600337)
# (4776, 0.2785168)
# (4777, 0.25557932)
# (4778, 0.259974)
# (4779, 0.27999014)
# (4780, 0.28639835)
# (4781, 0.2621499)
# (4782, 0.26906091)
# (4783, 0.2703433)
# (4784, 0.28467113)
# (4785, 0.22493015)
# (4786, 0.22868887)
# (4787, 0.2396331)
# (4788, 0.29811108)
# (4789, 0.31245863)
# (4790, 0.29696015)
# (4791, 0.29064727)
# (4792, 0.26814759)
# (4793, 0.28032914)
# (4794, 0.27731195)
# (4795, 0.26627204)
# (4796, 0.25869837)
# (4797, 0.26683593)
# (4798, 0.26853418)
# (4799, 0.26209712)
# (4800, 0.28753626)
# (4801, 0.27234954)
# (4802, 0.27002126)
# (4803, 0.22364129)
# (4804, 0.21951519)
# (4805, 0.27202821)
# (4806, 0.30081874)
# (4807, 0.2954686)
# (4808, 0.29093426)
# (4809, 0.29202163)
# (4810, 0.27029556)
# (4811, 0.27869409)
# (4812, 0.28181085)
# (4813, 0.2556608)
# (4814, 0.26796901)
# (4815, 0.2750183)
# (4816, 0.26928243)
# (4817, 0.26383319)
# (4818, 0.26931852)
# (4819, 0.28241146)
# (4820, 0.26726624)
# (4821, 0.22865839)
# (4822, 0.23573887)
# (4823, 0.2863861)
# (4824, 0.29736695)
# (4825, 0.28341642)
# (4826, 0.2818993)
# (4827, 0.28797597)
# (4828, 0.26967925)
# (4829, 0.27600762)
# (4830, 0.27479494)
# (4831, 0.27011102)
# (4832, 0.27639213)
# (4833, 0.26253533)
# (4834, 0.26301852)
# (4835, 0.25985122)
# (4836, 0.27630231)
# (4837, 0.29099366)
# (4838, 0.24968641)
# (4839, 0.23171197)
# (4840, 0.2366253)
# (4841, 0.32010353)
# (4842, 0.31239286)
# (4843, 0.27727181)
# (4844, 0.28370741)
# (4845, 0.27376068)
# (4846, 0.27962834)
# (4847, 0.27214071)
# (4848, 0.25767142)
# (4849, 0.27096128)
# (4850, 0.27810481)
# (4851, 0.27119869)
# (4852, 0.25854439)
# (4853, 0.27098492)
# (4854, 0.26705939)
# (4855, 0.27903551)
# (4856, 0.22727725)
# (4857, 0.23472913)
# (4858, 0.24320291)
# (4859, 0.300677)
# (4860, 0.30420285)
# (4861, 0.28787169)
# (4862, 0.28831202)
# (4863, 0.26911831)
# (4864, 0.26801056)
# (4865, 0.25712511)
# (4866, 0.24855389)
# (4867, 0.25661644)
# (4868, 0.26096183)
# (4869, 0.25150591)
# (4870, 0.25971255)
# (4871, 0.27665001)
# (4872, 0.26103729)
# (4873, 0.26644424)
# (4874, 0.21992745)
# (4875, 0.22246975)
# (4876, 0.26323)
# (4877, 0.29074618)
# (4878, 0.27248886)
# (4879, 0.27395082)
# (4880, 0.27617171)
# (4881, 0.26407036)
# (4882, 0.27018625)
# (4883, 0.25872672)
# (4884, 0.23971704)
# (4885, 0.25063327)
# (4886, 0.25319698)
# (4887, 0.24156873)
# (4888, 0.23933691)
# (4889, 0.2483855)
# (4890, 0.26265162)
# (4891, 0.24215351)
# (4892, 0.21739897)
# (4893, 0.21514727)
# (4894, 0.27316892)
# (4895, 0.27640298)
